# %% [markdown]
# **Note:** The code may not appear flawless due to multiple iterations and repeated attempts during development. We have removed redundant sections and retained only the core, essential parts.

# %% [markdown]
# **Dataset Preparation**
#
# In this stage, we extracted plagiarized text segments from the **PAN corpora** using the metadata provided in XML files (such as offset and length values). These English text segments were then **translated into Kazakh** using machine translation techniques. The resulting the foundation for building a **Kazakh dataset** specifically tailored for **text similarity detection tasks**.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import xml.etree.ElementTree as ET

# Path to the suspicious documents folder
suspicious_folder = "/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents"

total_xml_files = 0
has_plagiarism_count = 0
no_plagiarism_count = 0

for filename in os.listdir(suspicious_folder):
    if filename.endswith(".xml"):
        total_xml_files += 1
        file_path = os.path.join(suspicious_folder, filename)

        tree = ET.parse(file_path)
        root = tree.getroot()

        # We'll scan all <feature> elements until we find a plagiarism element
        file_has_plagiarism = False
        for feature in root.findall(".//feature"):
            if feature.get("name") == "plagiarism":
                file_has_plagiarism = True
                # As soon as we find one plagiarism feature, we can skip checking the rest
                break

        if file_has_plagiarism:
            has_plagiarism_count += 1
        else:
            no_plagiarism_count += 1

print("Total XML files in the folder:", total_xml_files)
print("Number of XML files with a plagiarism feature:", has_plagiarism_count)
print("Number of XML files without a plagiarism feature:", no_plagiarism_count)
# Out:
# Total XML files in the folder: 11148
# Number of XML files with a plagiarism feature: 5581
# Number of XML files without a plagiarism feature: 5567

# %%
import os
import shutil
import xml.etree.ElementTree as ET

# Path to the suspicious documents folder
suspicious_folder = "/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents"

# Paths to the new folders you want to create
plagiarised_folder = "/content/drive/MyDrive/experimental-models/plagiarised_xml"
none_plagiarised_folder = "/content/drive/MyDrive/experimental-models/none_plagiarised_xml"

# Create the new folders if they don't exist
os.makedirs(plagiarised_folder, exist_ok=True)
os.makedirs(none_plagiarised_folder, exist_ok=True)

# Loop over each XML file, check for plagiarism, then copy to the correct folder
for filename in os.listdir(suspicious_folder):
    if filename.endswith(".xml"):
        file_path = os.path.join(suspicious_folder, filename)

        # Parse the XML to see if it has any plagiarism features
        tree = ET.parse(file_path)
        root = tree.getroot()

        file_has_plagiarism = False
        for feature in root.findall(".//feature"):
            if feature.get("name") == "plagiarism":
                file_has_plagiarism = True
                break

        # Copy the file to the appropriate folder
        if file_has_plagiarism:
            shutil.copy2(file_path, plagiarised_folder)
        else:
            shutil.copy2(file_path, none_plagiarised_folder)

print("Finished copying files!")
print("Files with plagiarism have been copied to:", plagiarised_folder)
print("Files without plagiarism have been copied to:", none_plagiarised_folder)
# Out:
# Finished copying files!
# Files with plagiarism have been copied to: /content/drive/MyDrive/experimental-models/plagiarised_xml
# Files without plagiarism have been copied to: /content/drive/MyDrive/experimental-models/none_plagiarised_xml

# %%
import os

# Path to the folder
folder_path1 = "/content/drive/MyDrive/experimental-models/plagiarised_xml"
folder_path2 = "/content/drive/MyDrive/experimental-models/none_plagiarised_xml"

# Function to count files in a folder
def count_files_in_folder(folder_path):
    try:
        # List all entries in the directory
        entries = os.listdir(folder_path)

        # Filter out directories, keeping only files
        files = [entry for entry in entries if os.path.isfile(os.path.join(folder_path, entry))]

        # Count the number of files
        file_count = len(files)

        return file_count

    except FileNotFoundError:
        print(f"Folder not found: {folder_path}")
        return 0

# Call the function to count files in the folder
print(f"The total number of files in the folder '{folder_path1}' is: {count_files_in_folder(folder_path1)}")
print(f"The total number of files in the folder '{folder_path2}' is: {count_files_in_folder(folder_path2)}")
# Out:
# The total number of files in the folder '/content/drive/MyDrive/experimental-models/plagiarised_xml' is: 5581
# The total number of files in the folder '/content/drive/MyDrive/experimental-models/none_plagiarised_xml' is: 5567

# %%
import os
import xml.etree.ElementTree as ET

# A) Folders we want to scan
plagiarised_folder = "/content/drive/MyDrive/experimental-models/plagiarised_xml"
none_plagiarised_folder = "/content/drive/MyDrive/experimental-models/none_plagiarised_xml"

# A) Counters for the plagiarised folder
#    1) no this_offset + no source_offset
#    2) yes this_offset + no source_offset
#    3) no this_offset + yes source_offset
#    4) yes this_offset + yes source_offset
p_noT_noS = 0
p_yesT_noS = 0
p_noT_yesS = 0
p_yesT_yesS = 0

# B) Counters for the non-plagiarised folder
#    1) no this_offset + no source_offset
#    2) yes this_offset + no source_offset
#    3) no this_offset + yes source_offset
#    4) yes this_offset + yes source_offset
np_noT_noS = 0
np_yesT_noS = 0
np_noT_yesS = 0
np_yesT_yesS = 0

# ---------- PART A: Analyze plagiarised_folder ----------
for filename in os.listdir(plagiarised_folder):
    if filename.endswith(".xml"):
        file_path = os.path.join(plagiarised_folder, filename)

        # Track if we find any this_offset or source_offset
        has_this_offset = False
        has_source_offset = False

        # Parse only as far as needed
        tree = ET.parse(file_path)
        root = tree.getroot()

        for feature in root.findall(".//feature"):
            if feature.get("this_offset") is not None:
                has_this_offset = True
            if feature.get("source_offset") is not None:
                has_source_offset = True

            # If we've found both, no need to keep checking
            if has_this_offset and has_source_offset:
                break

        # Classify this file into one of the four categories
        if not has_this_offset and not has_source_offset:
            p_noT_noS += 1
        elif has_this_offset and not has_source_offset:
            p_yesT_noS += 1
        elif not has_this_offset and has_source_offset:
            p_noT_yesS += 1
        else:
            # has_this_offset and has_source_offset
            p_yesT_yesS += 1

# ---------- PART B: Analyze none_plagiarised_folder ----------
for filename in os.listdir(none_plagiarised_folder):
    if filename.endswith(".xml"):
        file_path = os.path.join(none_plagiarised_folder, filename)

        # Track if we find any this_offset or source_offset
        has_this_offset = False
        has_source_offset = False

        # Parse only as far as needed
        tree = ET.parse(file_path)
        root = tree.getroot()

        for feature in root.findall(".//feature"):
            if feature.get("this_offset") is not None:
                has_this_offset = True
            if feature.get("source_offset") is not None:
                has_source_offset = True

            # If we've found both, no need to keep checking
            if has_this_offset and has_source_offset:
                break

        # Classify this file into one of the four categories
        if not has_this_offset and not has_source_offset:
            np_noT_noS += 1
        elif has_this_offset and not has_source_offset:
            np_yesT_noS += 1
        elif not has_this_offset and has_source_offset:
            np_noT_yesS += 1
        else:
            # has_this_offset and has_source_offset
            np_yesT_yesS += 1

# ---------- Print the results ----------
print("----- Plagiarised Folder -----")
print("1) No this_offset, No source_offset:", p_noT_noS)
print("2) Yes this_offset, No source_offset:", p_yesT_noS)
print("3) No this_offset, Yes source_offset:", p_noT_yesS)
print("4) Yes this_offset, Yes source_offset:", p_yesT_yesS)

print("\n----- None-Plagiarised Folder -----")
print("1) No this_offset, No source_offset:", np_noT_noS)
print("2) Yes this_offset, No source_offset:", np_yesT_noS)
print("3) No this_offset, Yes source_offset:", np_noT_yesS)
print("4) Yes this_offset, Yes source_offset:", np_yesT_yesS)
# Out:
# ----- Plagiarised Folder -----
# 1) No this_offset, No source_offset: 0
# 2) Yes this_offset, No source_offset: 1659
# 3) No this_offset, Yes source_offset: 0
# 4) Yes this_offset, Yes source_offset: 3922
#
# ----- None-Plagiarised Folder -----
# 1) No this_offset, No source_offset: 5567
# 2) Yes this_offset, No source_offset: 0
# 3) No this_offset, Yes source_offset: 0
# 4) Yes this_offset, Yes source_offset: 0

# %% [markdown]
# **Plagiarised Folder:**
# 1.   No this_offset, No source_offset: 0
# 2.   Yes this_offset, No source_offset: 1659
# 3.   No this_offset, Yes source_offset: 0
# 4.   Yes this_offset, Yes source_offset: 3922
#
# Total in plagiarised_folder = 1659 + 3922 = 5581
#
# **None-Plagiarised Folder:**
# 1.   No this_offset, No source_offset: 5567
# 2.   Yes this_offset, No source_offset: 0
# 3.   No this_offset, Yes source_offset: 0
# 4.   Yes this_offset, Yes source_offset: 0
#
# Total in none_plagiarised_folder = 5567
#
# **Total files (plagiarised and none plagiarised) 5581 + 5567 = 11148**

# %%
import os
import shutil
import xml.etree.ElementTree as ET

# Existing folders (already split by plagiarism presence)
plagiarised_folder = "/content/drive/MyDrive/experimental-models/plagiarised_xml"
none_plagiarised_folder = "/content/drive/MyDrive/experimental-models/none_plagiarised_xml"

# New folders you want to create for each category
category_plag_su1_so1 = "/content/drive/MyDrive/experimental-models/su1_so1"
category_plag_su1_so0 = "/content/drive/MyDrive/experimental-models/su1_so0"
category_nonplag_su0_so0 = "/content/drive/MyDrive/experimental-models/su0_so0"

# Make sure these folders exist
os.makedirs(category_plag_su1_so1, exist_ok=True)
os.makedirs(category_plag_su1_so0, exist_ok=True)
os.makedirs(category_nonplag_su0_so0, exist_ok=True)

def has_offsets(file_path):
    """
    Parse the given XML file quickly to see whether it has
    any 'this_offset' or 'source_offset' in any <feature>.
    Returns (has_this_offset, has_source_offset).
    """
    tree = ET.parse(file_path)
    root = tree.getroot()
    found_this_offset = False
    found_source_offset = False
    for feature in root.findall(".//feature"):
        if feature.get("this_offset") is not None:
            found_this_offset = True
        if feature.get("source_offset") is not None:
            found_source_offset = True
        # If both are found, no need to keep checking
        if found_this_offset and found_source_offset:
            break
    return (found_this_offset, found_source_offset)

# ----- A) Plagiarised Folder -----
# We know from your counts that there should be only two real sub-cases here:
#   1) yes this_offset & yes source_offset
#   2) yes this_offset & no source_offset
for filename in os.listdir(plagiarised_folder):
    if filename.endswith(".xml"):
        file_path = os.path.join(plagiarised_folder, filename)
        (has_T, has_S) = has_offsets(file_path)

        # Check which sub-category
        if has_T and has_S:
            # 1) Plagiarised_su1_so1
            shutil.copy2(file_path, category_plag_su1_so1)
        elif has_T and not has_S:
            # 2) Plagiarised_su1_so0
            shutil.copy2(file_path, category_plag_su1_so0)
        else:
            # According to your counts, you don't actually have
            # other categories in the plagiarised folder. But if
            # something was off, you'd handle it here.
            pass

# ----- B) None-Plagiarised Folder -----
# We know from your counts that all are no T & no S.
for filename in os.listdir(none_plagiarised_folder):
    if filename.endswith(".xml"):
        file_path = os.path.join(none_plagiarised_folder, filename)
        (has_T, has_S) = has_offsets(file_path)

        # The only sub-category we expect in non-plagiarised is no T & no S
        if not has_T and not has_S:
            shutil.copy2(file_path, category_nonplag_su0_so0)
        else:
            # If you unexpectedly find any other combos, you'd handle them here
            pass

print("Finished copying files into the three categories:")
print(f"1) plagiarised_su1_so1 -> {category_plag_su1_so1}")
print(f"2) plagiarised_su1_so0 -> {category_plag_su1_so0}")
print(f"3) not_plagiarised_su0_so0 -> {category_nonplag_su0_so0}")
# Out:
# Finished copying files into the three categories:
# 1) plagiarised_su1_so1 -> /content/drive/MyDrive/experimental-models/su1_so1
# 2) plagiarised_su1_so0 -> /content/drive/MyDrive/experimental-models/su1_so0
# 3) not_plagiarised_su0_so0 -> /content/drive/MyDrive/experimental-models/su0_so0

# %%
import os

# Paths to the three folders
folder_path1 = "/content/drive/MyDrive/experimental-models/su1_so1"
folder_path2 = "/content/drive/MyDrive/experimental-models/su1_so0"
folder_path3 = "/content/drive/MyDrive/experimental-models/su0_so0"

def count_xml_files_in_folder(folder_path):
    """Count only .xml files in the given folder."""
    try:
        # List all entries in the directory
        entries = os.listdir(folder_path)

        # Filter out anything that's not a file or doesn't end with .xml
        xml_files = [
            entry for entry in entries
            if entry.endswith(".xml") and os.path.isfile(os.path.join(folder_path, entry))
        ]

        return len(xml_files)

    except FileNotFoundError:
        print(f"Folder not found: {folder_path}")
        return 0

# Print the count of .xml files in each folder
print(f"The total number of XML files in the folder '{folder_path1}' is: {count_xml_files_in_folder(folder_path1)}")
print(f"The total number of XML files in the folder '{folder_path2}' is: {count_xml_files_in_folder(folder_path2)}")
print(f"The total number of XML files in the folder '{folder_path3}' is: {count_xml_files_in_folder(folder_path3)}")
# Out:
# The total number of XML files in the folder '/content/drive/MyDrive/experimental-models/su1_so1' is: 3922
# The total number of XML files in the folder '/content/drive/MyDrive/experimental-models/su1_so0' is: 1659
# The total number of XML files in the folder '/content/drive/MyDrive/experimental-models/su0_so0' is: 5567

# %%
import os
import shutil

su1_so1_folder = "/content/drive/MyDrive/experimental-models/su1_so1"

for entry in os.listdir(su1_so1_folder):
    # We only care about files ending with ".xml"
    if entry.endswith(".xml"):
        xml_file_path = os.path.join(su1_so1_folder, entry)

        # Remove the ".xml" extension to get something like "suspicious-documentABCDE"
        base_name = os.path.splitext(entry)[0]

        # Build the path to the subfolder with the same base name
        subfolder_path = os.path.join(su1_so1_folder, base_name)

        # If that subfolder exists, copy the XML file into it
        if os.path.isdir(subfolder_path):
            dst_path = os.path.join(subfolder_path, entry)
            shutil.copy2(xml_file_path, dst_path)
            print(f"Copied: {xml_file_path} -> {dst_path}")
        else:
            print(f"No matching subfolder found for {entry}")

print("Finished copying matching XML files to their subfolders.")
# Out:
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document
xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02288/suspicious-document02288.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02313.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02313/suspicious-document02313.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02319.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02319/suspicious-document02319.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02289.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02289/suspicious-document02289.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02411.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02411/suspicious-document02411.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02157.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02157/suspicious-document02157.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02234.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02234/suspicious-document02234.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02162.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02162/suspicious-document02162.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02249.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02249/suspicious-document02249.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02393.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02393/suspicious-document02393.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02172.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02172/suspicious-document02172.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02295.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02295/suspicious-document02295.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02440.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02440/suspicious-document02440.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02351.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02351/suspicious-document02351.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02165.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02165/suspicious-document02165.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02255.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02255/suspicious-document02255.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02180.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02180/suspicious-document02180.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02350.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02350/suspicious-document02350.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02395.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02395/suspicious-document02395.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02406.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02406/suspicious-document02406.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02182.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02182/suspicious-document02182.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02308.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02308/suspicious-document02308.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02398.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02398/suspicious-document02398.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02268.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02268/suspicious-document02268.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02174.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02174/suspicious-document02174.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02252.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02252/suspicious-document02252.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02245.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02245/suspicious-document02245.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02408.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02408/suspicious-document02408.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02191.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02191/suspicious-document02191.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02192.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02192/suspicious-document02192.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02321.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02321/suspicious-document02321.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02251.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02251/suspicious-document02251.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02305.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02305/suspicious-document02305.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02438.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02438/suspicious-document02438.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02385.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02385/suspicious-document02385.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02179.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02179/suspicious-document02179.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02345.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02345/suspicious-document02345.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02177.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02177/suspicious-document02177.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02173.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02173/suspicious-document02173.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02307.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02307/suspicious-document02307.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02407.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02407/suspicious-document02407.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02147.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02147/suspicious-document02147.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02247.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02247/suspicious-document02247.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02257.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02257/suspicious-document02257.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02433.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02433/suspicious-document02433.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02415.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02415/suspicious-document02415.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02170.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02170/suspicious-document02170.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02343.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02343/suspicious-document02343.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02366.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02366/suspicious-document02366.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02178.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02178/suspicious-document02178.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02378.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02378/suspicious-document02378.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02322.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02322/suspicious-document02322.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02213.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02213/suspicious-document02213.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02158.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02158/suspicious-document02158.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02197.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02197/suspicious-document02197.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02441.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02441/suspicious-document02441.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02349.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02349/suspicious-document02349.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02254.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02254/suspicious-document02254.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02224.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02224/suspicious-document02224.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02448.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02448/suspicious-document02448.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02150.xml -> /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document02150/suspicious-document02150.xml
# Finished copying matching XML files to their subfolders.

# %%
import os
import shutil

su1_so1_folder = "/content/drive/MyDrive/experimental-models/su1_so0"

for entry in os.listdir(su1_so1_folder):
    # We only care about files ending with ".xml"
    if entry.endswith(".xml"):
        xml_file_path = os.path.join(su1_so1_folder, entry)

        # Remove the ".xml" extension to get something like "suspicious-documentABCDE"
        base_name = os.path.splitext(entry)[0]

        # Build the path to the subfolder with the same base name
        subfolder_path = os.path.join(su1_so1_folder, base_name)

        # If that subfolder exists, copy the XML file into it
        if os.path.isdir(subfolder_path):
            dst_path = os.path.join(subfolder_path, entry)
            shutil.copy2(xml_file_path, dst_path)
            print(f"Copied: {xml_file_path} -> {dst_path}")
        else:
            print(f"No matching subfolder found for {entry}")

print("Finished copying matching XML files to their subfolders.")
# Out:
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08695.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08695/suspicious-document08695.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08748.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08748/suspicious-document08748.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08809.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08809/suspicious-document08809.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08692.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08692/suspicious-document08692.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08775.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08775/suspicious-document08775.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08837.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document08837/suspicious-document08837.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document
xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01728.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01728/suspicious-document01728.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01767.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01767/suspicious-document01767.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01824.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01824/suspicious-document01824.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01747.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01747/suspicious-document01747.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01746.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01746/suspicious-document01746.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01786.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01786/suspicious-document01786.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01730.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01730/suspicious-document01730.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01881.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01881/suspicious-document01881.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01714.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01714/suspicious-document01714.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01709.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01709/suspicious-document01709.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01718.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01718/suspicious-document01718.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02095.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02095/suspicious-document02095.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02133.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02133/suspicious-document02133.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02109.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02109/suspicious-document02109.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02080.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02080/suspicious-document02080.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02051.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02051/suspicious-document02051.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01980.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01980/suspicious-document01980.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02088.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02088/suspicious-document02088.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02113.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02113/suspicious-document02113.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02039.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02039/suspicious-document02039.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02052.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02052/suspicious-document02052.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01965.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01965/suspicious-document01965.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02026.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02026/suspicious-document02026.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01924.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01924/suspicious-document01924.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01982.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01982/suspicious-document01982.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02021.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02021/suspicious-document02021.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02050.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02050/suspicious-document02050.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02036.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02036/suspicious-document02036.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01949.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01949/suspicious-document01949.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02018.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02018/suspicious-document02018.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01940.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01940/suspicious-document01940.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02004.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02004/suspicious-document02004.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02086.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02086/suspicious-document02086.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02132.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02132/suspicious-document02132.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01988.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01988/suspicious-document01988.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02103.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02103/suspicious-document02103.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01981.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01981/suspicious-document01981.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02135.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02135/suspicious-document02135.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01929.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01929/suspicious-document01929.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02136.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02136/suspicious-document02136.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02005.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02005/suspicious-document02005.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01935.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01935/suspicious-document01935.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02006.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02006/suspicious-document02006.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02125.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02125/suspicious-document02125.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01973.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document01973/suspicious-document01973.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02169.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02169/suspicious-document02169.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02320.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02320/suspicious-document02320.xml
# Copied: /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02397.xml -> /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document02397/suspicious-document02397.xml
# Finished copying matching XML files to their subfolders.

# %%
import os
import shutil
import xml.etree.ElementTree as ET

# Folders containing the original suspicious and source documents
suspicious_docs_folder = "/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents"
source_docs_folder = "/content/drive/MyDrive/experimental-models/pan2010/source-documents"

# Folder containing the .xml files we want to parse
plagiarised_xml_folder = "/content/drive/MyDrive/experimental-models/su1_so1"

for filename in os.listdir(plagiarised_xml_folder):
    if filename.endswith(".xml"):
        xml_path = os.path.join(plagiarised_xml_folder, filename)

        # --- Parse the XML to extract references ---
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # The top-level document reference, e.g., suspicious-document00123.txt
        suspicious_doc_txt_name = root.get("reference")
        if suspicious_doc_txt_name is None:
            print(f"[WARNING] No 'reference' attribute in {filename}, skipping.")
            continue

        # Gather all source references from <feature name="plagiarism" source_reference="...">
        source_doc_names = []
        for feature in root.findall(".//feature"):
            if feature.get("name") == "plagiarism":
                source_ref = feature.get("source_reference")
                if source_ref is not None and source_ref not in source_doc_names:
                    source_doc_names.append(source_ref)

        # --- Create a new folder named without the .xml extension ---
        # e.g., from suspicious-document00123.xml -> suspicious-document00123
        base_name = os.path.splitext(filename)[0]  # "suspicious-document00123"
        new_subfolder_path = os.path.join(plagiarised_xml_folder, base_name)
        os.makedirs(new_subfolder_path, exist_ok=True)

        # --- Copy the suspicious document .txt as-is into the new folder ---
        # e.g., suspicious-document00123.txt stays suspicious-document00123.txt
        suspicious_src_path = os.path.join(suspicious_docs_folder, suspicious_doc_txt_name)
        suspicious_dst_path = os.path.join(new_subfolder_path, suspicious_doc_txt_name)

        if os.path.isfile(suspicious_src_path):
            shutil.copy2(suspicious_src_path, suspicious_dst_path)
        else:
            print(f"[WARNING] Could not find suspicious doc: {suspicious_src_path}")

        # --- Copy each source doc as-is (keeping its .txt name) ---
        for src_doc_name in source_doc_names:
            source_src_path = os.path.join(source_docs_folder, src_doc_name)
            source_dst_path = os.path.join(new_subfolder_path, src_doc_name)

            if os.path.isfile(source_src_path):
                shutil.copy2(source_src_path, source_dst_path)
            else:
                print(f"[WARNING] Could not find source doc: {source_src_path}")

print("Finished copying suspicious and source documents into subfolders (with .txt intact).")
# Out:
# Finished copying suspicious and source documents into subfolders (with .txt intact).

# %%
import os
import shutil
import xml.etree.ElementTree as ET

# Folders containing the original suspicious and source documents
suspicious_docs_folder = "/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents"

# Folder containing the .xml files we want to parse
plagiarised_xml_folder = "/content/drive/MyDrive/experimental-models/su1_so0"

for filename in os.listdir(plagiarised_xml_folder):
    if filename.endswith(".xml"):
        xml_path = os.path.join(plagiarised_xml_folder, filename)

        # --- Parse the XML to extract references ---
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # The top-level document reference, e.g., suspicious-document00123.txt
        suspicious_doc_txt_name = root.get("reference")
        if suspicious_doc_txt_name is None:
            print(f"[WARNING] No 'reference' attribute in {filename}, skipping.")
            continue

        # --- Create a new folder named without the .xml extension ---
        # e.g., from suspicious-document00123.xml -> suspicious-document00123
        base_name = os.path.splitext(filename)[0]  # "suspicious-document00123"
        new_subfolder_path = os.path.join(plagiarised_xml_folder, base_name)
        os.makedirs(new_subfolder_path, exist_ok=True)

        # --- Copy the suspicious document .txt as-is into the new folder ---
        # e.g., suspicious-document00123.txt stays suspicious-document00123.txt
        suspicious_src_path = os.path.join(suspicious_docs_folder, suspicious_doc_txt_name)
        suspicious_dst_path = os.path.join(new_subfolder_path, suspicious_doc_txt_name)

        if os.path.isfile(suspicious_src_path):
            shutil.copy2(suspicious_src_path, suspicious_dst_path)
        else:
            print(f"[WARNING] Could not find suspicious doc: {suspicious_src_path}")

print("Finished copying suspicious and source documents into subfolders (with .txt intact).")
# Out:
# Finished copying suspicious and source documents into subfolders (with .txt intact).

# %%
import os

# Paths to the three folders
folder_path1 = "/content/drive/MyDrive/experimental-models/su1_so1"
folder_path2 = "/content/drive/MyDrive/experimental-models/su1_so0"
folder_path3 = "/content/drive/MyDrive/experimental-models/su0_so0"

def count_xml_files_and_subfolders(folder_path):
    """
    Returns a tuple (num_xml_files, num_subfolders) for the given folder.
    - num_xml_files: count of all .xml files (not directories) in the folder
    - num_subfolders: count of subdirectories in the folder
    """
    try:
        entries = os.listdir(folder_path)

        # Count .xml files (ensure each entry is a file that ends with .xml)
        xml_files = [
            entry
            for entry in entries
            if entry.endswith(".xml") and os.path.isfile(os.path.join(folder_path, entry))
        ]
        num_xml_files = len(xml_files)

        # Count subfolders (directories within this folder)
        subfolders = [
            entry
            for entry in entries
            if os.path.isdir(os.path.join(folder_path, entry))
        ]
        num_subfolders = len(subfolders)

        return num_xml_files, num_subfolders

    except FileNotFoundError:
        print(f"Folder not found: {folder_path}")
        return 0, 0

# Now let's retrieve and print the info for each folder
for folder_path in [folder_path1, folder_path2, folder_path3]:
    xml_count, subfolder_count = count_xml_files_and_subfolders(folder_path)
    print(f"Folder: {folder_path}")
    print(f"  Total number of XML files: {xml_count}")
    print(f"  Total number of subfolders: {subfolder_count}")
    print("--------------------------------------------------")
# Out:
# Folder: /content/drive/MyDrive/experimental-models/su1_so1
#   Total number of XML files: 3922
#   Total number of subfolders: 3922
# --------------------------------------------------
# Folder: /content/drive/MyDrive/experimental-models/su1_so0
#   Total number of XML files: 1659
#   Total number of subfolders: 1659
# --------------------------------------------------
# Folder: /content/drive/MyDrive/experimental-models/su0_so0
#   Total number of XML files: 5567
#   Total number of subfolders: 0
# --------------------------------------------------

# %%
import os
import shutil
import xml.etree.ElementTree as ET

# Folder containing the .txt suspicious documents (original location)
suspicious_docs_folder = "/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents"

# Folder containing the XML files (where we also want to place the .txt files)
not_plagiarised_xml_files = "/content/drive/MyDrive/experimental-models/su0_so0"

for filename in os.listdir(not_plagiarised_xml_files):
    if filename.endswith(".xml"):
        xml_path = os.path.join(not_plagiarised_xml_files, filename)

        # Parse the XML
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # e.g. suspicious-document00123.txt
        suspicious_doc_txt_name = root.get("reference")
        if suspicious_doc_txt_name is None:
            print(f"[WARNING] No 'reference' attribute in {filename}, skipping.")
            continue

        # Where the suspicious text file currently lives
        suspicious_src_path = os.path.join(suspicious_docs_folder, suspicious_doc_txt_name)

        # Where we want to copy the suspicious text file
        # (Same folder as the XML, keep the same .txt name)
        suspicious_dst_path = os.path.join(not_plagiarised_xml_files, suspicious_doc_txt_name)

        if os.path.isfile(suspicious_src_path):
            shutil.copy2(suspicious_src_path, suspicious_dst_path)
            print(f"Copied {suspicious_src_path} to {suspicious_dst_path}")
        else:
            print(f"[WARNING] Could not find suspicious doc: {suspicious_src_path}")

print("Finished copying suspicious .txt documents next to their .xml files.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09263.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09263.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09217.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09217.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09241.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09241.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09203.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09203.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09229.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09229.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09318.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09318.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09310.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09310.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09319.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09319.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09311.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09311.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09242.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09242.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09304.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09304.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09190.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09190.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09300.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09300.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09306.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09306.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09234.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09234.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09221.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09221.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09331.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09331.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09243.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09243.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09197.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09197.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09275.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09275.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09266.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09266.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09504.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09504.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09419.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09419.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09394.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09394.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09415.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09415.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09495.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09495.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09476.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09476.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09448.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09448.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09514.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09514.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09497.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09497.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09375.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09375.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09403.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09403.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09401.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09401.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09385.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09385.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09437.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09437.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09478.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09478.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09433.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09433.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09340.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09340.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09491.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09491.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09374.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09374.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09441.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09441.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09405.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document
txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09676.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09676.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09812.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09812.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09768.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09768.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09721.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09721.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09733.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09733.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09700.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09700.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09761.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09761.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09728.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09728.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09742.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09742.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09821.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09821.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09765.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09765.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09815.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09815.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09763.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09763.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09826.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09826.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09793.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09793.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09806.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09806.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document09805.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document09805.txt
# ...
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01200.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01200.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01098.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01098.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01068.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01068.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01221.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01221.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01184.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01184.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01166.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01166.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01087.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01087.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01227.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01227.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01256.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01256.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01162.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01162.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document01201.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document01201.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00004.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00004.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00003.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00003.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00134.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00134.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00018.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00018.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00012.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00012.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00127.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00127.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00079.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00079.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00076.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00076.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00082.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00082.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00124.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00124.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00049.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00049.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00149.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00149.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00148.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00148.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00102.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00102.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00125.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00125.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00077.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00077.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00180.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00180.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00112.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00112.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00060.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00060.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00066.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00066.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00091.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00091.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00072.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00072.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00133.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00133.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00020.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00020.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00137.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00137.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00062.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00062.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00130.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00130.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00017.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00017.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00065.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00065.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00172.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00172.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00045.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00045.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00042.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00042.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00143.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00143.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00174.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00174.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00030.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00030.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00057.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00057.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00092.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00092.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00085.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00085.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00161.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00161.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00099.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00099.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00144.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00144.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00088.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00088.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00022.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00022.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00128.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00128.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00023.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00023.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00153.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00153.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00041.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00041.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00031.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00031.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00013.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00013.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00163.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00163.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00083.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00083.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00151.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00151.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00136.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00136.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00034.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00034.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00123.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00123.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00046.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00046.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00189.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00189.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00010.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00010.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00119.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00119.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00071.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00071.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00188.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00188.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00179.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00179.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00110.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00110.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00109.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00109.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00025.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00025.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00181.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00181.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00028.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00028.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00139.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00139.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00090.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00090.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00145.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00145.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00118.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00118.txt
# Copied /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents/suspicious-document00035.txt to /content/drive/MyDrive/experimental-models/su0_so0/suspicious-document00035.txt
# Finished copying suspicious .txt documents next to their .xml files.

# %%
import os

folder_path = "/content/drive/MyDrive/experimental-models/su0_so0"

# Initialize counters
xml_count = 0
txt_count = 0

for entry in os.listdir(folder_path):
    file_path = os.path.join(folder_path, entry)
    if os.path.isfile(file_path):
        if entry.endswith(".xml"):
            xml_count += 1
        elif entry.endswith(".txt"):
            txt_count += 1

print(f"Number of .xml files in '{folder_path}': {xml_count}")
print(f"Number of .txt files in '{folder_path}': {txt_count}")
# Out:
# Number of .xml files in '/content/drive/MyDrive/experimental-models/su0_so0': 5567
# Number of .txt files in '/content/drive/MyDrive/experimental-models/su0_so0': 5567

# %%
import os
import shutil

# 1) Path to the master source-documents folder
source_docs_folder = "/content/drive/MyDrive/experimental-models/pan2010/source-documents"

# 2) Path to the folder containing subfolders for plagiarised_su1_so1
plagiarised_su1_so1 = "/content/drive/MyDrive/experimental-models/su1_so1"

# 3) Path to the folder where we want to copy the remaining source files
not_plagiarised_su0_so0 = "/content/drive/MyDrive/experimental-models/su0_so0"

# -------------------------------------------------------------------
# A) Gather all .txt file names from source_docs_folder into list_1
# -------------------------------------------------------------------
list_1 = []
for item in os.listdir(source_docs_folder):
    if item.endswith(".txt"):
        list_1.append(item)

# Alternatively, make it a set to simplify difference operations
list_1 = set(list_1)

# -------------------------------------------------------------------
# B) Gather all .txt file names from ALL subfolders in plagiarised_su1_so1 into list_2
#    We'll use os.walk(...) to recurse subdirectories
# -------------------------------------------------------------------
list_2 = []
for root_dir, subdirs, files in os.walk(plagiarised_su1_so1):
    for file_name in files:
        if file_name.endswith(".txt"):
            list_2.append(file_name)

# Convert to a set to handle duplicates and allow easy difference
list_2 = set(list_2)

# -------------------------------------------------------------------
# C) Compute the difference
# -------------------------------------------------------------------
remaining_source_files = list_1 - list_2  # all .txt files in source_docs not used in plagiarised_su1_so1

# -------------------------------------------------------------------
# D) Copy the remaining source files into not_plagiarised_su0_so0
# -------------------------------------------------------------------
for txt_file in remaining_source_files:
    src_path = os.path.join(source_docs_folder, txt_file)
    dst_path = os.path.join(not_plagiarised_su0_so0, txt_file)

    # Double-check the file actually exists in source_docs_folder
    if os.path.isfile(src_path):
        shutil.copy2(src_path, dst_path)
        print(f"Copied: {txt_file} -> {not_plagiarised_su0_so0}")
    else:
        print(f"[WARNING] Missing file in source_docs_folder: {txt_file}")

print("\nDone! Copied all remaining source .txt files to:", not_plagiarised_su0_so0)
# Out:
# Streaming output truncated to the last 5000 lines.
# Copied: source-document04013.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08325.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09486.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01867.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00739.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09157.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06568.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07072.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07647.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03150.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07151.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10172.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01495.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05840.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10063.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03602.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10114.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00520.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06348.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08789.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07646.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10022.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05478.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10769.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01461.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08751.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05782.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02183.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02054.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10520.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05593.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09514.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02039.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06042.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09163.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02800.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06679.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07190.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07061.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07181.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03637.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00454.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02224.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05124.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10019.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06000.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10966.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05827.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02657.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document11048.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05208.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document11144.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04941.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06777.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04570.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02957.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00991.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09082.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04686.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document11037.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02757.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03729.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08998.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05313.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06915.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00432.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10053.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03057.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04566.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06428.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05554.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04331.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04971.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03693.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10716.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10525.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09795.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04860.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08594.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05106.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00388.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09583.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00167.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09535.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00671.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02155.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06596.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04996.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06516.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08257.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04189.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02398.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03877.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10793.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09366.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document11036.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01924.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04159.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00156.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04853.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06548.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08863.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10686.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10944.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05468.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08498.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07723.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06823.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03394.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10760.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02281.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02909.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03508.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03145.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01657.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03265.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09851.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03711.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06521.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06260.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05158.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05224.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08385.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02910.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07218.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03889.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08561.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08585.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00444.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10758.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10306.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00715.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00133.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05882.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09033.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02806.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10557.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01095.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08172.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05000.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04444.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03162.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09185.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06262.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04105.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10189.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00652.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01604.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06912.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09305.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05031.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05459.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00643.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02388.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04660.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05369.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10327.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01235.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01813.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07320.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09229.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03185.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01090.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03669.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04946.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09845.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00006.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09261.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09423.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08238.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09465.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00120.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10778.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08151.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01839.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01138.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07523.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10682.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05511.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06992.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07819.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00926.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00464.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02690.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00222.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08694.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08233.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07761.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09603.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09439.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01834.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03993.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09067.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02020.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04365.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06667.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06423.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07575.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02215.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07023.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00793.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05599.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09507.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00390.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04240.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06351.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07661.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02009.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05279.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00530.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04679.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05097.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08339.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10489.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01758.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05962.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04059.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06943.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09059.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05166.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03504.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08923.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02602.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09999.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01356.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07879.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01397.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01491.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08729.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08420.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04457.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07188.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00256.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08916.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document
txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01620.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05960.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06006.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05586.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06200.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08104.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06171.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01632.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06453.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05620.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09432.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04237.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09869.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07186.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06763.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01492.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09899.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06485.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00315.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03279.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04018.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10394.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08196.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07629.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10252.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10752.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00323.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05390.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05838.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06688.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08302.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06062.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08283.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10176.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04911.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08451.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04234.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05052.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05336.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05216.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04349.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10287.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06998.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04586.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02745.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00258.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03019.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02609.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00923.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08288.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08468.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01833.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01004.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06307.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00570.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10070.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04800.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09982.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01789.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07593.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05019.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02867.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02468.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10167.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03151.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07973.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01439.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06530.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04939.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10082.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05559.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01741.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04836.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09122.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07782.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04434.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10853.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09949.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05913.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09554.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00453.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01167.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03056.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08749.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04312.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04395.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09573.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04965.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09544.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10472.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00395.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06619.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09560.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03465.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07901.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03596.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08476.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02863.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04845.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00905.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09353.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06755.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01284.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document04197.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document02515.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08234.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document05132.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document09225.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08430.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07911.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document06899.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document07752.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document03847.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document01800.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00118.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document08194.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document00161.txt -> /content/drive/MyDrive/experimental-models/su0_so0
# Copied: source-document10693.txt -> /content/drive/MyDrive/experimental-models/su0_so0
#
# Done! Copied all remaining source .txt files to: /content/drive/MyDrive/experimental-models/su0_so0

# %%
import os

# --- Folder paths ---
folder_1 = "/content/drive/MyDrive/experimental-models/pan2010/source-documents"
folder_2 = "/content/drive/MyDrive/experimental-models/su1_so1"
folder_3 = "/content/drive/MyDrive/experimental-models/su0_so0"

# ----------------------------------------------------------------------------
# A) Count all source files (.txt) in folder_1 that start with "source-"
#    We'll do a simple listdir for a flat directory.
# ----------------------------------------------------------------------------
all_source_files = [
    f for f in os.listdir(folder_1)
    if f.startswith("source-") and f.endswith(".txt")
       and os.path.isfile(os.path.join(folder_1, f))
]
count_1 = len(all_source_files)

# ----------------------------------------------------------------------------
# B) Count all *unique* source-*.txt files in folder_2 (including subfolders)
#    We'll use os.walk(...) to gather them recursively.
# ----------------------------------------------------------------------------
unique_files_folder_2 = set()
for root_dir, sub_dirs, files in os.walk(folder_2):
    for f in files:
        if f.startswith("source-") and f.endswith(".txt"):
            unique_files_folder_2.add(f)
count_2 = len(unique_files_folder_2)

# ----------------------------------------------------------------------------
# C) Count all source-*.txt files in folder_3 (no recursion needed here)
# ----------------------------------------------------------------------------
files_folder_3 = [
    f for f in os.listdir(folder_3)
    if f.startswith("source-") and f.endswith(".txt")
       and os.path.isfile(os.path.join(folder_3, f))
]
count_3 = len(files_folder_3)

# ----------------------------------------------------------------------------
# D) Print all three counts & check if (count_2 + count_3 == count_1)
# ----------------------------------------------------------------------------
print(f"Total 'source-*.txt' files in folder-1 ({folder_1}): {count_1}")
print(f"Unique 'source-*.txt' files in subfolders of folder-2 ({folder_2}): {count_2}")
print(f"Total 'source-*.txt' files in folder-3 ({folder_3}): {count_3}")

if (count_2 + count_3) == count_1:
    print("\nSUCCESS: (count_2 + count_3) == count_1. The sum matches exactly.")
else:
    print("\nWARNING: (count_2 + count_3) != count_1. The sum does NOT match.")
# Out:
# Total 'source-*.txt' files in folder-1 (/content/drive/MyDrive/experimental-models/pan2010/source-documents): 11148
# Unique 'source-*.txt' files in subfolders of folder-2 (/content/drive/MyDrive/experimental-models/su1_so1): 4195
# Total 'source-*.txt' files in folder-3 (/content/drive/MyDrive/experimental-models/su0_so0): 6953
#
# SUCCESS: (count_2 + count_3) == count_1. The sum matches exactly.

# %%
import os

# --- Folder paths ---
folder_1 = "/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents"
folder_2 = "/content/drive/MyDrive/experimental-models/su1_so1"
folder_3 = "/content/drive/MyDrive/experimental-models/su1_so0"
folder_4 = "/content/drive/MyDrive/experimental-models/su0_so0"

# ----------------------------------------------------------------------------
# A) Count all suspicious files (.txt) in folder_1 that start with "suspicious-"
#    We'll do a simple listdir for a flat directory.
# ----------------------------------------------------------------------------
all_source_files = [
    f for f in os.listdir(folder_1)
    if f.startswith("suspicious-") and f.endswith(".txt")
       and os.path.isfile(os.path.join(folder_1, f))
]
count_1 = len(all_source_files)

# ----------------------------------------------------------------------------
# B) Count all *unique* suspicious-*.txt files in folder_2 (including subfolders)
#    We'll use os.walk(...) to gather them recursively.
# ----------------------------------------------------------------------------
unique_files_folder_2 = set()
for root_dir, sub_dirs, files in os.walk(folder_2):
    for f in files:
        if f.startswith("suspicious-") and f.endswith(".txt"):
            unique_files_folder_2.add(f)
count_2 = len(unique_files_folder_2)

# ----------------------------------------------------------------------------
# C) Count all *unique* suspicious-*.txt files in folder_3 (including subfolders)
#    We'll use os.walk(...) to gather them recursively.
# ----------------------------------------------------------------------------
unique_files_folder_3 = set()
for root_dir, sub_dirs, files in os.walk(folder_3):
    for f in files:
        if f.startswith("suspicious-") and f.endswith(".txt"):
            unique_files_folder_3.add(f)
count_3 = len(unique_files_folder_3)

# ----------------------------------------------------------------------------
# D) Count all susupicious-*.txt files in folder_4 (no recursion needed here)
# ----------------------------------------------------------------------------
files_folder_4 = [
    f for f in os.listdir(folder_4)
    if f.startswith("suspicious-") and f.endswith(".txt")
       and os.path.isfile(os.path.join(folder_4, f))
]
count_4 = len(files_folder_4)

# ----------------------------------------------------------------------------
# D) Print all three counts & check if (count_2 + count_3 == count_1)
# ----------------------------------------------------------------------------
print(f"Total 'suspicious-*.txt' files in folder-1 ({folder_1}): {count_1}")
print(f"Unique 'suspicious-*.txt' files in subfolders of folder-2 ({folder_2}): {count_2}")
print(f"Unique 'suspicious-*.txt' files in subfolders of folder-3 ({folder_3}): {count_3}")
print(f"Total 'suspicious-*.txt' files in folder-3 ({folder_4}): {count_4}")

if (count_2 + count_3 + count_4) == count_1:
    print("\nSUCCESS: (count_2 + count_3 + count_4) == count_1. The sum matches exactly.")
else:
    print("\nWARNING: (count_2 + count_3 + count_4) != count_1. The sum does NOT match.")
# Out:
# Total 'suspicious-*.txt' files in folder-1 (/content/drive/MyDrive/experimental-models/pan2010/suspicious-documents): 11148
# Unique 'suspicious-*.txt' files in subfolders of folder-2 (/content/drive/MyDrive/experimental-models/su1_so1): 3922
# Unique 'suspicious-*.txt' files in subfolders of folder-3 (/content/drive/MyDrive/experimental-models/su1_so0): 1659
# Total 'suspicious-*.txt' files in folder-3 (/content/drive/MyDrive/experimental-models/su0_so0): 5567
#
# SUCCESS: (count_2 + count_3 + count_4) == count_1. The sum matches exactly.

# %%
import os
import xml.etree.ElementTree as ET

# Path to your main directory containing subfolders like "suspicious-document00001"
base_dir = "/content/drive/MyDrive/experimental-models/su1_so1"

# -------------------------------------------------------------------------
# Process every subfolder in base_dir (no skipping based on previous runs)
# -------------------------------------------------------------------------
for subfolder in os.listdir(base_dir):
    doc_folder = os.path.join(base_dir, subfolder)

    # Only handle directories whose names start with "suspicious-document"
    if os.path.isdir(doc_folder) and subfolder.startswith("suspicious-document"):
        doc_name = subfolder  # e.g. "suspicious-document00192"

        xml_file = os.path.join(doc_folder, f"{doc_name}.xml")
        txt_file = os.path.join(doc_folder, f"{doc_name}.txt")

        # We'll store extracted snippets in a new subfolder named "suspicious-documentXXXX-XML-parts"
        parts_folder = os.path.join(doc_folder, f"{doc_name}-parts")
        os.makedirs(parts_folder, exist_ok=True)

        # Check if required files exist. If not, skip
        if not (os.path.isfile(xml_file) and os.path.isfile(txt_file)):
            print(f"[WARNING] {subfolder} missing .xml or .txt file, skipping.")
            continue

        print(f"\nProcessing subfolder: {subfolder} ...")

        # Parse the XML
        tree = ET.parse(xml_file)
        root = tree.getroot()
        features = root.findall(".//feature")

        # Read the entire suspicious doc text
        with open(txt_file, "r", encoding="utf-8") as f:
            suspicious_full_text = f.read()

        # For each <feature>, extract from suspicious & source if present
        for feature in features:
            this_offset = feature.get("this_offset")
            this_length = feature.get("this_length")

            source_reference = feature.get("source_reference")
            source_offset = feature.get("source_offset")
            source_length = feature.get("source_length")

            # --------- A) Suspicious snippet ---------
            if this_offset and this_length:
                offset_val = int(this_offset)
                length_val = int(this_length)

                # Take the raw substring, unmodified
                raw_snippet = suspicious_full_text[offset_val : offset_val + length_val]

                out_filename = f"{doc_name}-{offset_val}-{length_val}.txt"
                out_path = os.path.join(parts_folder, out_filename)

                with open(out_path, "w", encoding="utf-8") as out_f:
                    out_f.write(raw_snippet)

                print(f"  Suspicious snippet saved: {out_filename}")

            # --------- B) Source snippet ---------
            if source_reference and source_offset and source_length:
                source_doc_path = os.path.join(doc_folder, source_reference)
                if os.path.isfile(source_doc_path):
                    with open(source_doc_path, "r", encoding="utf-8") as src_f:
                        source_full_text = src_f.read()

                    src_offset_val = int(source_offset)
                    src_length_val = int(source_length)

                    # Again, take the raw substring
                    raw_src_snippet = source_full_text[src_offset_val : src_offset_val + src_length_val]

                    source_basename = os.path.splitext(source_reference)[0]
                    out_source_filename = f"{source_basename}-{src_offset_val}-{src_length_val}.txt"
                    out_source_path = os.path.join(parts_folder, out_source_filename)

                    with open(out_source_path, "w", encoding="utf-8") as src_out_f:
                        src_out_f.write(raw_src_snippet)

                    print(f"  Source snippet saved: {out_source_filename}")
                else:
                    print(f"  [WARNING] Source file not found: {source_doc_path}")

        print(f"Finished processing {subfolder}. Extracted snippets are in {parts_folder}")

print("\nAll subfolders processed.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   Source snippet saved: source-document00867-1732-15222.txt
#   Suspicious snippet saved: suspicious-document08803-218715-4655.txt
#   Source snippet saved: source-document05650-239463-4410.txt
#   Suspicious snippet saved: suspicious-document08803-224688-21241.txt
#   Source snippet saved: source-document01295-421158-21229.txt
#   Suspicious snippet saved: suspicious-document08803-247303-15273.txt
#   Source snippet saved: source-document00867-1732-15222.txt
#   Suspicious snippet saved: suspicious-document08803-264346-266.txt
#   Source snippet saved: source-document06878-310421-273.txt
#   Suspicious snippet saved: suspicious-document08803-264628-264.txt
#   Source snippet saved: source-document06606-278671-262.txt
# Finished processing suspicious-document08803. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so1/suspicious-document08803/suspicious-document08803-parts
#
# All subfolders processed.

# %%
import os
import xml.etree.ElementTree as ET

base_dir = "/content/drive/MyDrive/experimental-models/su1_so0"

# -------------------------------------------------------------------------
# Process every subfolder in base_dir (no skipping based on previous runs)
# -------------------------------------------------------------------------
for subfolder in os.listdir(base_dir):
    doc_folder = os.path.join(base_dir, subfolder)

    # Only handle directories whose names start with "suspicious-document"
    if os.path.isdir(doc_folder) and subfolder.startswith("suspicious-document"):
        doc_name = subfolder  # e.g. "suspicious-document00192"

        xml_file = os.path.join(doc_folder, f"{doc_name}.xml")
        txt_file = os.path.join(doc_folder, f"{doc_name}.txt")

        # We'll store extracted snippets in a new subfolder named "suspicious-documentXXXX-parts"
        parts_folder = os.path.join(doc_folder, f"{doc_name}-parts")
        os.makedirs(parts_folder, exist_ok=True)

        # Check if required files exist. If not, skip
        if not (os.path.isfile(xml_file) and os.path.isfile(txt_file)):
            print(f"[WARNING] {subfolder} missing .xml or .txt file, skipping.")
            continue

        print(f"\nProcessing subfolder: {subfolder} ...")

        # Parse the XML
        tree = ET.parse(xml_file)
        root = tree.getroot()
        features = root.findall(".//feature")

        # Read the entire suspicious doc text
        with open(txt_file, "r", encoding="utf-8") as f:
            suspicious_full_text = f.read()

        # For each <feature>, extract the raw substring from suspicious doc
        for feature in features:
            this_offset = feature.get("this_offset")
            this_length = feature.get("this_length")

            if this_offset and this_length:
                offset_val = int(this_offset)
                length_val = int(this_length)

                # Take the raw substring without adjustments
                raw_snippet = suspicious_full_text[offset_val : offset_val + length_val]

                out_filename = f"{doc_name}-{offset_val}-{length_val}.txt"
                out_path = os.path.join(parts_folder, out_filename)

                # Write the raw snippet as-is
                with open(out_path, "w", encoding="utf-8") as out_f:
                    out_f.write(raw_snippet)

                print(f"  Suspicious snippet saved: {out_filename}")

        print(f"Finished processing {subfolder}. Extracted snippets are in {parts_folder}")

print("\nAll subfolders processed.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   Suspicious snippet saved: suspicious-document10673-31865-249.txt
# Finished processing suspicious-document10673. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10673/suspicious-document10673-parts
#
# Processing subfolder: suspicious-document10711 ...
#   Suspicious snippet saved: suspicious-document10711-40829-17536.txt
#   Suspicious snippet saved: suspicious-document10711-153206-21359.txt
#   Suspicious snippet saved: suspicious-document10711-295941-1731.txt
#   Suspicious snippet saved: suspicious-document10711-340053-22837.txt
#   Suspicious snippet saved: suspicious-document10711-478580-244.txt
# Finished processing suspicious-document10711. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document
Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10910/suspicious-document10910-parts
#
# Processing subfolder: suspicious-document10826 ...
#   Suspicious snippet saved: suspicious-document10826-3272-230.txt
# Finished processing suspicious-document10826. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10826/suspicious-document10826-parts
#
# Processing subfolder: suspicious-document10947 ...
#   Suspicious snippet saved: suspicious-document10947-5114-4083.txt
#   Suspicious snippet saved: suspicious-document10947-84111-17506.txt
#   Suspicious snippet saved: suspicious-document10947-193377-2322.txt
#   Suspicious snippet saved: suspicious-document10947-208820-1664.txt
#   Suspicious snippet saved: suspicious-document10947-230750-2730.txt
#   Suspicious snippet saved: suspicious-document10947-245982-1564.txt
# Finished processing suspicious-document10947. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10947/suspicious-document10947-parts
#
# Processing subfolder: suspicious-document10888 ...
#   Suspicious snippet saved: suspicious-document10888-30988-1494.txt
#   Suspicious snippet saved: suspicious-document10888-59410-1478.txt
#   Suspicious snippet saved: suspicious-document10888-86532-478.txt
# Finished processing suspicious-document10888. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10888/suspicious-document10888-parts
#
# Processing subfolder: suspicious-document10807 ...
#   Suspicious snippet saved: suspicious-document10807-16996-20274.txt
#   Suspicious snippet saved: suspicious-document10807-201176-15059.txt
#   Suspicious snippet saved: suspicious-document10807-259919-20522.txt
#   Suspicious snippet saved: suspicious-document10807-378442-776.txt
#   Suspicious snippet saved: suspicious-document10807-386311-2309.txt
#   Suspicious snippet saved: suspicious-document10807-412157-4015.txt
#   Suspicious snippet saved: suspicious-document10807-427492-1858.txt
#   Suspicious snippet saved: suspicious-document10807-439782-1553.txt
#   Suspicious snippet saved: suspicious-document10807-448151-702.txt
#   Suspicious snippet saved: suspicious-document10807-451617-235.txt
# Finished processing suspicious-document10807. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10807/suspicious-document10807-parts
#
# Processing subfolder: suspicious-document10865 ...
#   Suspicious snippet saved: suspicious-document10865-2273-785.txt
#   Suspicious snippet saved: suspicious-document10865-8140-234.txt
#   Suspicious snippet saved: suspicious-document10865-9777-498.txt
#   Suspicious snippet saved: suspicious-document10865-14452-265.txt
# Finished processing suspicious-document10865. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10865/suspicious-document10865-parts
#
# Processing subfolder: suspicious-document10878 ...
#   Suspicious snippet saved: suspicious-document10878-9744-704.txt
#   Suspicious snippet saved: suspicious-document10878-16369-753.txt
#   Suspicious snippet saved: suspicious-document10878-69272-3916.txt
#   Suspicious snippet saved: suspicious-document10878-110032-260.txt
#   Suspicious snippet saved: suspicious-document10878-119802-2210.txt
#   Suspicious snippet saved: suspicious-document10878-161374-547.txt
#   Suspicious snippet saved: suspicious-document10878-173273-254.txt
# Finished processing suspicious-document10878. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10878/suspicious-document10878-parts
#
# Processing subfolder: suspicious-document10867 ...
#   Suspicious snippet saved: suspicious-document10867-19450-4052.txt
# Finished processing suspicious-document10867. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10867/suspicious-document10867-parts
#
# Processing subfolder: suspicious-document10945 ...
#   Suspicious snippet saved: suspicious-document10945-4789-263.txt
#   Suspicious snippet saved: suspicious-document10945-13434-809.txt
# Finished processing suspicious-document10945. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document10945/suspicious-document10945-parts
#
# Processing subfolder: suspicious-document10877 ...
#   Suspicious snippet saved: suspicious-document10877-18136-4395.txt
#   Suspicious snippet saved: suspicious-document10877-31927-458.txt
# Finished processing suspicious-document10877. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document
Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document06488/suspicious-document06488-parts
#
# Processing subfolder: suspicious-document06474 ...
#   Suspicious snippet saved: suspicious-document06474-11487-4701.txt
#   Suspicious snippet saved: suspicious-document06474-38683-1721.txt
#   Suspicious snippet saved: suspicious-document06474-44778-492.txt
# Finished processing suspicious-document06474. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document06474/suspicious-document06474-parts
#
# Processing subfolder: suspicious-document06703 ...
#   Suspicious snippet saved: suspicious-document06703-4712-2993.txt
#   Suspicious snippet saved: suspicious-document06703-15936-228.txt
#   Suspicious snippet saved: suspicious-document06703-17753-534.txt
# Finished processing suspicious-document06703. Extracted snippets are in /content/drive/MyDrive/experimental-models/su1_so0/suspicious-document06703/suspicious-document06703-parts
#
# All subfolders processed.

# %%
import os
import shutil

# Parent folder containing "suspicious-document" and "source-document"
pan2010_folder = "/content/drive/MyDrive/experimental-models/pan2010"

# Subfolders we want to copy
subfolders = ["suspicious-documents", "source-documents"]

# Destination folder for all files
destination_folder = "/content/drive/MyDrive/experimental-models/all-suspicious-and-source-files"

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Extensions to skip – these are not real files but Google Doc placeholders
skip_extensions = {".gdoc", ".gsheet", ".gslides", ".gdraw"}

for subfolder in subfolders:
    current_subfolder_path = os.path.join(pan2010_folder, subfolder)
    if os.path.isdir(current_subfolder_path):
        # Copy every *file* in this subfolder, skipping .gdoc etc.
        for file_name in os.listdir(current_subfolder_path):
            source_file_path = os.path.join(current_subfolder_path, file_name)

            if not os.path.isfile(source_file_path):
                # Skip directories or anything not a file
                continue

            # Check if file extension is in our skip list
            ext = os.path.splitext(file_name)[1].lower()
            if ext in skip_extensions:
                print(f"Skipping Google placeholder file: {file_name}")
                continue

            # Otherwise, copy it
            destination_file_path = os.path.join(destination_folder, file_name)
            shutil.copy2(source_file_path, destination_file_path)

        print(f"Copied all supported files from {current_subfolder_path} to {destination_folder}")
    else:
        print(f"[WARNING] Subfolder not found: {current_subfolder_path}")

print("Done copying all suspicious and source documents (skipping .gdoc, etc.)!")
# Out:
# Skipping Google placeholder file: suspicious-document00036.gdoc
# Copied all supported files from /content/drive/MyDrive/experimental-models/pan2010/suspicious-documents to /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
# Copied all supported files from /content/drive/MyDrive/experimental-models/pan2010/source-documents to /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
# Done copying all suspicious and source documents (skipping .gdoc, etc.)!

# %%
import os
import xml.etree.ElementTree as ET

# -------------------------------------------------------------------------
# Main configuration
# -------------------------------------------------------------------------
su1_so1_base = "/content/drive/MyDrive/experimental-models/su1_so1"

# In all-suspicious-and-source-documents, we have:
all_susp_folder = "/content/drive/MyDrive/experimental-models/all-suspicious-and-source-files"
all_src_folder = "/content/drive/MyDrive/experimental-models/all-suspicious-and-source-files"

def annotate_snippet_in_text(full_text, snippet, offset_val, length_val):

    # Build the annotated snippet
    annotation = f" . {offset_val}-{length_val} . "
    annotated_version = f"{annotation}{snippet}{annotation}"

    # Step 3: Replace only the first occurrence
    index = full_text.find(snippet)
    if index == -1:
        # Not found; we could try searching for snippet_adjusted instead if needed
        print(f"    [WARNING] Could not find snippet in text for offset={offset_val}, length={length_val}")
        return full_text

    # Replace the first occurrence
    new_text = (full_text[:index]
                + annotated_version
                + full_text[index + len(snippet):])
    return new_text

def process_subfolder(folder_name):
    """
    Given a subfolder in su1_so1 (e.g. suspicious-document00192),
    parse the .xml, then for each <feature>:
      - read suspicious snippet from the -parts .txt,
      - find & annotate in all-suspicious .txt,
      - if source snippet exists, read from -parts, find & annotate in all-source .txt
    """
    doc_folder = os.path.join(su1_so1_base, folder_name)
    doc_name = folder_name  # e.g. "suspicious-document00192"

    xml_file = os.path.join(doc_folder, f"{doc_name}.xml")
    if not os.path.isfile(xml_file):
        print(f"[WARNING] No XML file found in {doc_folder}, skipping.")
        return

    # Parse the XML
    tree = ET.parse(xml_file)
    root = tree.getroot()
    features = root.findall(".//feature")

    # Find the suspicious doc reference
    # (Might also be in <document reference="suspicious-document00192.txt">, etc.)
    # But we can assume it matches the subfolder naming:
    suspicious_txt_name = f"{doc_name}.txt"  # "suspicious-document00192.txt"
    suspicious_main_path = os.path.join(all_susp_folder, suspicious_txt_name)

    # Read the existing suspicious doc text from the main folder
    if not os.path.isfile(suspicious_main_path):
        print(f"[WARNING] Suspicious doc {suspicious_txt_name} not in {all_susp_folder}")
        suspicious_main_text = ""
    else:
        with open(suspicious_main_path, "r", encoding="utf-8") as f:
            suspicious_main_text = f.read()

    # We'll accumulate changes in memory and overwrite at the end
    updated_susp_text = suspicious_main_text

    # For each <feature>, we might have this_offset/length + source_reference/offset/length
    for feature in features:
        this_offset = feature.get("this_offset")
        this_length = feature.get("this_length")

        # If suspicious snippet is defined
        if this_offset and this_length:
            snippet_file = os.path.join(doc_folder, f"{doc_name}-parts",
                                        f"{doc_name}-{this_offset}-{this_length}.txt")
            if os.path.isfile(snippet_file):
                with open(snippet_file, "r", encoding="utf-8") as sf:
                    snippet_text = sf.read()

                # Attempt to annotate in the suspicious document
                updated_susp_text = annotate_snippet_in_text(
                    updated_susp_text,
                    snippet_text,
                    this_offset,
                    this_length
                )
            else:
                print(f"    [WARNING] Suspicious snippet file not found: {snippet_file}")

        # If source snippet is defined
        source_reference = feature.get("source_reference")
        source_offset = feature.get("source_offset")
        source_length = feature.get("source_length")

        if source_reference and source_offset and source_length:
            # The snippet file for the source in the -XML-parts folder
            source_snippet_file = os.path.join(
                doc_folder,
                f"{doc_name}-parts",
                f"{os.path.splitext(source_reference)[0]}-{source_offset}-{source_length}.txt"
            )
            if os.path.isfile(source_snippet_file):
                with open(source_snippet_file, "r", encoding="utf-8") as sf:
                    source_snippet_text = sf.read()

                # Now we want to annotate in the "all-suspicious-and-source-documents/source-documents"
                source_main_path = os.path.join(all_src_folder, source_reference)
                if os.path.isfile(source_main_path):
                    with open(source_main_path, "r", encoding="utf-8") as fsrc:
                        source_main_text = fsrc.read()

                    # Annotate
                    updated_source_text = annotate_snippet_in_text(
                        source_main_text,
                        source_snippet_text,
                        source_offset,
                        source_length
                    )

                    # Overwrite the source doc with the updated text
                    with open(source_main_path, "w", encoding="utf-8") as fsrc:
                        fsrc.write(updated_source_text)
                    print(f"    Updated source doc {source_reference} with offset={source_offset}, length={source_length}")
                else:
                    print(f"    [WARNING] Source doc {source_reference} not found in {all_src_folder}")
            else:
                print(f"    [WARNING] Source snippet file not found: {source_snippet_file}")

    # Finally, overwrite the suspicious doc with the updated text
    with open(suspicious_main_path, "w", encoding="utf-8") as f:
        f.write(updated_susp_text)

    print(f"Done updating suspicious doc: {suspicious_txt_name} in {all_susp_folder}")

# -------------------------------------------------------------------------
# MAIN LOOP: Process each subfolder in su1_so1
# -------------------------------------------------------------------------
for entry in os.listdir(su1_so1_base):
    subfolder_path = os.path.join(su1_so1_base, entry)
    if os.path.isdir(subfolder_path) and entry.startswith("suspicious-document"):
        print(f"\n>>> Processing subfolder: {entry}")
        process_subfolder(entry)

print("\nAll subfolders processed!")

# %%
import os
import xml.etree.ElementTree as ET

# -------------------------------------------------------------------------
# Folders where we read the original suspicious and source docs
# -------------------------------------------------------------------------
all_susp_folder = "/content/drive/MyDrive/experimental-models/all-suspicious-and-source-files"
all_src_folder  = "/content/drive/MyDrive/experimental-models/all-suspicious-and-source-files"

# -------------------------------------------------------------------------
# The base folder with subfolders like "suspicious-document00192"
# -------------------------------------------------------------------------
su1_so1_base = "/content/drive/MyDrive/experimental-models/su1_so1"

# Subfolders to process (here we'll process all that start with "suspicious-document")
subfolders_to_process = [entry for entry in os.listdir(su1_so1_base)
                         if os.path.isdir(os.path.join(su1_so1_base, entry))
                         and entry.startswith("suspicious-document")]

# Global list to accumulate missing file names (only the file names or paths)
missing_files = []

def log_missing(file_info):
    missing_files.append(file_info)

def annotate_snippet_in_text(full_text, snippet, offset_val, length_val):
    """
    Wrap the snippet (as-is) with offset-length tags on both ends,
    and replace only the first occurrence of the snippet in full_text.
    """
    annotation = f" . {offset_val}-{length_val} . "
    annotated_version = f"{annotation}{snippet}{annotation}"

    index = full_text.find(snippet)
    if index == -1:
        # If snippet is not found, log its information.
        print(f"    [WARNING] Snippet not found for offset={offset_val}, length={length_val}")
        # (Not a missing file, so we do not log the file name here.)
        return full_text

    new_text = full_text[:index] + annotated_version + full_text[index + len(snippet):]
    return new_text

def process_subfolder(folder_name):
    doc_folder = os.path.join(su1_so1_base, folder_name)
    doc_name = folder_name  # e.g., "suspicious-document00192"

    # Check XML file
    xml_file = os.path.join(doc_folder, f"{doc_name}.xml")
    if not os.path.isfile(xml_file):
        log_missing(f"XML file missing: {doc_name}.xml (in {doc_folder})")
        return

    # Parse the XML to get snippet references
    tree = ET.parse(xml_file)
    root = tree.getroot()
    features = root.findall(".//feature")

    # Suspicious doc file name (should be .txt)
    suspicious_txt_name = f"{doc_name}.txt"
    original_susp_path = os.path.join(all_susp_folder, suspicious_txt_name)
    if not os.path.isfile(original_susp_path):
        log_missing(f"Suspicious doc missing: {suspicious_txt_name} (in {all_susp_folder})")
        suspicious_main_text = ""
    else:
        with open(original_susp_path, "r", encoding="utf-8") as f:
            suspicious_main_text = f.read()

    updated_susp_text = suspicious_main_text

    for feature in features:
        # Process suspicious snippet
        this_offset = feature.get("this_offset")
        this_length = feature.get("this_length")
        if this_offset and this_length:
            snippet_file = os.path.join(
                doc_folder,
                f"{doc_name}-parts",
                f"{doc_name}-{this_offset}-{this_length}.txt"
            )
            if os.path.isfile(snippet_file):
                with open(snippet_file, "r", encoding="utf-8") as sf:
                    snippet_text = sf.read()
                updated_susp_text = annotate_snippet_in_text(
                    updated_susp_text,
                    snippet_text,
                    this_offset,
                    this_length
                )
            else:
                log_missing(f"Suspicious snippet missing: {snippet_file}")

        # Process source snippet
        source_reference = feature.get("source_reference")
        source_offset = feature.get("source_offset")
        source_length = feature.get("source_length")
        if source_reference and source_offset and source_length:
            snippet_file_src = os.path.join(
                doc_folder,
                f"{doc_name}-parts",
                f"{os.path.splitext(source_reference)[0]}-{source_offset}-{source_length}.txt"
            )
            if os.path.isfile(snippet_file_src):
                with open(snippet_file_src, "r", encoding="utf-8") as sf:
                    source_snippet_text = sf.read()
                original_source_path = os.path.join(all_src_folder, source_reference)
                if os.path.isfile(original_source_path):
                    with open(original_source_path, "r", encoding="utf-8") as fsrc:
                        source_main_text = fsrc.read()
                    updated_source_text = annotate_snippet_in_text(
                        source_main_text,
                        source_snippet_text,
                        source_offset,
                        source_length
                    )
                    # Overwrite the original source doc with the updated text
                    with open(original_source_path, "w", encoding="utf-8") as fsrc:
                        fsrc.write(updated_source_text)
                    print(f"    Updated source doc '{source_reference}' with offset={source_offset}, length={source_length}")
                else:
                    log_missing(f"Source doc missing: {source_reference} (in {all_src_folder})")
            else:
                log_missing(f"Source snippet missing: {os.path.splitext(source_reference)[0]}-{source_offset}-{source_length}.txt (in {doc_folder})")

    # Overwrite the original suspicious doc with the updated text
    with open(original_susp_path, "w", encoding="utf-8") as f:
        f.write(updated_susp_text)
    print(f"Done updating suspicious doc: {suspicious_txt_name} in {all_susp_folder}")

# MAIN: Process each subfolder in su1_so1 that starts with "suspicious-document"
for entry in os.listdir(su1_so1_base):
    subfolder_path = os.path.join(su1_so1_base, entry)
    if os.path.isdir(subfolder_path) and entry.startswith("suspicious-document"):
        print(f"\n>>> Processing subfolder: {entry}")
        process_subfolder(entry)

# Save the log file with missing file names to a new folder
log_folder = "/content/drive/MyDrive/experimental-models/update_logs"
os.makedirs(log_folder, exist_ok=True)
log_file_path = os.path.join(log_folder, "missing_files_log.txt")
with open(log_file_path, "w", encoding="utf-8") as log_f:
    log_f.write("\n".join(missing_files))

print("\nAll subfolders processed!")
print(f"Log of missing files saved to: {log_file_path}")
# Out:
# >>> Processing subfolder: suspicious-document02708
#     Updated source doc 'source-document00216.txt' with offset=115094, length=4959
#     Updated source doc 'source-document06124.txt' with offset=1715, length=273
#     Updated source doc 'source-document06124.txt' with offset=706, length=242
# Done updating suspicious doc: suspicious-document02708.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02630
#     Updated source doc 'source-document05999.txt' with offset=176156, length=2454
#     Updated source doc 'source-document05999.txt' with offset=117535, length=1565
#     Updated source doc 'source-document05999.txt' with offset=103171, length=1469
# Done updating suspicious doc: suspicious-document02630.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document
txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02475
#     Updated source doc 'source-document03007.txt' with offset=1124, length=24970
#     Updated source doc 'source-document09738.txt' with offset=23195, length=3118
#     Updated source doc 'source-document05909.txt' with offset=62081, length=15296
#     Updated source doc 'source-document09738.txt' with offset=788, length=16195
#     Updated source doc 'source-document05909.txt' with offset=16393, length=21468
#     Updated source doc 'source-document05909.txt' with offset=90968, length=1508
#     Updated source doc 'source-document05909.txt' with offset=94661, length=16226
#     Updated source doc 'source-document03007.txt' with offset=623, length=501
#     Updated source doc 'source-document03007.txt' with offset=157, length=235
#     Updated source doc 'source-document05909.txt' with offset=82040, length=697
#     Updated source doc 'source-document09738.txt' with offset=27808, length=499
#     Updated source doc 'source-document03007.txt' with offset=392, length=231
#     Updated source doc 'source-document05909.txt' with offset=45661, length=244
# Done updating suspicious doc: suspicious-document02475.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02467
#     Updated source doc 'source-document09518.txt' with offset=11731, length=262
# Done updating suspicious doc: suspicious-document02467.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02535
#     Updated source doc 'source-document08066.txt' with offset=225871, length=777
#     Updated source doc 'source-document02870.txt' with offset=243161, length=450
#     Updated source doc 'source-document09718.txt' with offset=17882, length=239
# Done updating suspicious doc: suspicious-document02535.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02539
#     Updated source doc 'source-document04053.txt' with offset=2262, length=15473
#     Updated source doc 'source-document02036.txt' with offset=112055, length=20551
#     Updated source doc 'source-document00163.txt' with offset=17085, length=4020
#     Updated source doc 'source-document05958.txt' with offset=4204, length=495
#     Updated source doc 'source-document04088.txt' with offset=138624, length=2023
#     Updated source doc 'source-document09502.txt' with offset=642365, length=19836
#     Updated source doc 'source-document05151.txt' with offset=593270, length=4803
#     Updated source doc 'source-document10009.txt' with offset=295209, length=1486
#     Updated source doc 'source-document06400.txt' with offset=3141, length=16101
#     Updated source doc 'source-document08758.txt' with offset=334957, length=24015
#     Updated source doc 'source-document08018.txt' with offset=15131, length=22702
#     Updated source doc 'source-document00483.txt' with offset=7849, length=4743
#     Updated source doc 'source-document02116.txt' with offset=14045, length=271
#     Updated source doc 'source-document10009.txt' with offset=330415, length=1467
#     Updated source doc 'source-document10194.txt' with offset=6220, length=19231
#     Updated source doc 'source-document08637.txt' with offset=35752, length=18486
#     Updated source doc 'source-document10819.txt' with offset=89018, length=1577
#     Updated source doc 'source-document00483.txt' with offset=12735, length=4025
#     Updated source doc 'source-document04757.txt' with offset=193241, length=252
# Done updating suspicious doc: suspicious-document02539.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02702
#     Updated source doc 'source-document10138.txt' with offset=5345, length=15267
#     Updated source doc 'source-document05176.txt' with offset=3754, length=1560
#     Updated source doc 'source-document06699.txt' with offset=205674, length=542
#     Updated source doc 'source-document01846.txt' with offset=128356, length=4500
#     Updated source doc 'source-document03789.txt' with offset=6873, length=481
#     Updated source doc 'source-document05578.txt' with offset=87801, length=780
# Done updating suspicious doc: suspicious-document02702.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document
txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02875
#     Updated source doc 'source-document00867.txt' with offset=1732, length=15222
#     Updated source doc 'source-document04762.txt' with offset=813, length=1834
#     Updated source doc 'source-document02759.txt' with offset=69511, length=243
#     Updated source doc 'source-document10144.txt' with offset=58516, length=255
#     Updated source doc 'source-document03574.txt' with offset=2435, length=794
# Done updating suspicious doc: suspicious-document02875.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02883
#     Updated source doc 'source-document09145.txt' with offset=168958, length=2500
#     Updated source doc 'source-document00512.txt' with offset=275035, length=3509
#     Updated source doc 'source-document04985.txt' with offset=52646, length=2232
#     Updated source doc 'source-document06279.txt' with offset=4206, length=513
#     Updated source doc 'source-document06279.txt' with offset=4206, length=513
#     Updated source doc 'source-document06606.txt' with offset=278671, length=262
# Done updating suspicious doc: suspicious-document02883.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02761
#     Updated source doc 'source-document08732.txt' with offset=31851, length=15440
#     Updated source doc 'source-document09088.txt' with offset=17517, length=20116
#     Updated source doc 'source-document05572.txt' with offset=5375, length=1467
#     Updated source doc 'source-document09088.txt' with offset=2188, length=15093
#     Updated source doc 'source-document02257.txt' with offset=4068, length=17981
#     Updated source doc 'source-document08214.txt' with offset=111714, length=24877
#     Updated source doc 'source-document08214.txt' with offset=6950, length=20349
#     Updated source doc 'source-document08051.txt' with offset=80027, length=3800
#     Updated source doc 'source-document01149.txt' with offset=119860, length=20553
#     Updated source doc 'source-document06240.txt' with offset=882028, length=18905
#     Updated source doc 'source-document01149.txt' with offset=33131, length=1504
#     [WARNING] Snippet not found for offset=951, length=4255
#     Updated source doc 'source-document05572.txt' with offset=951, length=4255
#     Updated source doc 'source-document08214.txt' with offset=53525, length=17471
#     Updated source doc 'source-document08732.txt' with offset=103041, length=3248
#     Updated source doc 'source-document02257.txt' with offset=29361, length=529
#     Updated source doc 'source-document01149.txt' with offset=1159, length=16183
#     Updated source doc 'source-document08051.txt' with offset=93003, length=250
#     Updated source doc 'source-document06240.txt' with offset=611316, length=18995
#     Updated source doc 'source-document08051.txt' with offset=121436, length=1461
#     Updated source doc 'source-document08051.txt' with offset=46974, length=21000
#     Updated source doc 'source-document08732.txt' with offset=155591, length=17283
#     Updated source doc 'source-document01149.txt' with offset=180959, length=1478
#     Updated source doc 'source-document06240.txt' with offset=386543, length=18626
#     Updated source doc 'source-document01149.txt' with offset=215946, length=17964
#     Updated source doc 'source-document02257.txt' with offset=22837, length=4793
#     Updated source doc 'source-document08214.txt' with offset=171404, length=2237
#     Updated source doc 'source-document01149.txt' with offset=109999, length=3735
#     Updated source doc 'source-document08732.txt' with offset=121456, length=15960
#     Updated source doc 'source-document06240.txt' with offset=645738, length=2254
#     Updated source doc 'source-document08214.txt' with offset=277648, length=3474
#     Updated source doc 'source-document08051.txt' with offset=73804, length=2280
#     Updated source doc 'source-document08051.txt' with offset=14775, length=15776
#     Updated source doc 'source-document08214.txt' with offset=217286, length=22325
#     Updated source doc 'source-document08732.txt' with offset=182880, length=24262
#     Updated source doc 'source-document08051.txt' with offset=98235, length=18688
#     Updated source doc 'source-document08051.txt' with offset=124397, length=18986
#     Updated source doc 'source-document08214.txt' with offset=179514, length=18997
#     Updated source doc 'source-document01149.txt' with offset=100672, length=480
#     Updated source doc 'source-document01149.txt' with offset=43171, length=507
#     Updated source doc 'source-document08051.txt' with offset=91129, length=513
#     Updated source doc 'source-document09088.txt' with offset=854, length=497
#     Updated source doc 'source-document02257.txt' with offset=31688, length=238
# Done updating suspicious doc: suspicious-document02761.txt in /content/drive/MyDrive/experimental-models/all-suspicious-and-source-files
#
# >>> Processing subfolder: suspicious-document02891
#     Updated source doc 'source-document03857.txt' with offset=93780, length=20751
#     Updated source doc 'source-document04735.txt' with offset=0, length=3354
#     Updated source doc 'source-document06720.txt' with offset=593937, length=24569
#     Updated source doc 'source-document08584.txt' with offset=64645, length=19782
#     Updated source doc 'source-document08134.txt' with offset=10468, length=4511
#     Updated source doc 'source-document04453.txt' with offset=188869, length=3251
#     Updated source doc 'source-document03115.txt' with offset=154428, length=535
#     Updated source doc 'source-document09880.txt' with offset=49858, length=17333
#     Updated source doc 'source-document10582.txt' with offset=28469, length=2507
#     Updated source doc 'source-document02869.txt' with offset=201128, length=15506
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c72028c04e08> in <cell line: 0>()
#     133     if os.path.isdir(subfolder_path) and entry.startswith("suspicious-document"):
#     134         print(f"\n>>> Processing subfolder: {entry}")
# --> 135         process_subfolder(entry)
#     136
#     137 # Save the log file with missing file names to a new folder
#
# <ipython-input-10-c72028c04e08> in process_subfolder(folder_name)
#     103             if os.path.isfile(snippet_file_src):
#     104                 with open(snippet_file_src, "r", encoding="utf-8") as sf:
# --> 105                     source_snippet_text = sf.read()
#     106                 original_source_path = os.path.join(all_src_folder, source_reference)
#     107                 if os.path.isfile(original_source_path):
#
# /usr/lib/python3.11/codecs.py in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
import os
import xml.etree.ElementTree as ET
import itertools

# -------------------------------------------------------------------------
# Folders for example files
# -------------------------------------------------------------------------
susp_xml_folder = "/content/drive/MyDrive/example-three-xml-files/selected-files/suspicious-xml"
source_files_folder = "/content/drive/MyDrive/example-three-xml-files/selected-files/source-files"

# -------------------------------------------------------------------------
# Get list of XML files in the suspicious-xml folder
# -------------------------------------------------------------------------
xml_files = [f for f in os.listdir(susp_xml_folder)
             if f.lower().endswith(".xml") and os.path.isfile(os.path.join(susp_xml_folder, f))]

print("Found the following XML files in suspicious-xml folder:")
for xml_file in sorted(xml_files):
    print("  " + xml_file)

# -------------------------------------------------------------------------
# Get list of available source file names (only TXT files) from source-files folder
# -------------------------------------------------------------------------
available_source_files = set(f for f in os.listdir(source_files_folder)
                             if f.lower().endswith(".txt"))

print("\nAvailable source files (from source-files folder):")
for src in sorted(available_source_files):
    print("  " + src)

# -------------------------------------------------------------------------
# For each XML file, parse it and extract its referenced source file names
# -------------------------------------------------------------------------
xml_sources = {}  # key: XML file name, value: set of referenced source file names (that exist)

for xml_file in xml_files:
    xml_path = os.path.join(susp_xml_folder, xml_file)
    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
        # Find all <feature> elements and collect their source_reference attribute
        sources = { feature.get("source_reference")
                    for feature in root.findall(".//feature")
                    if feature.get("source_reference") is not None }
        # Retain only those that exist in the source-files folder
        sources = sources.intersection(available_source_files)
        xml_sources[xml_file] = sources
        print(f"{xml_file} references {len(sources)} source file(s).")
    except Exception as e:
        print(f"[ERROR] Could not parse {xml_file}: {e}")

# -------------------------------------------------------------------------
# Compute pairwise intersections
# -------------------------------------------------------------------------
xml_files_list = list(xml_sources.keys())
print("\nPairwise intersections (2-wise):")
for combo in itertools.combinations(xml_files_list, 2):
    common = set.intersection(*(xml_sources[f] for f in combo))
    print(f"{combo[0]} & {combo[1]}: {len(common)} common source file(s)")

# -------------------------------------------------------------------------
# Compute intersections for 3-wise up to 10-wise (or n-wise if n<10)
# -------------------------------------------------------------------------
n = len(xml_files_list)
for k in range(3, n+1):
    print(f"\n{k}-wise intersections:")
    for combo in itertools.combinations(xml_files_list, k):
        common = set.intersection(*(xml_sources[f] for f in combo))
        combo_str = ", ".join(combo)
        print(f"{combo_str}: {len(common)} common source file(s)")
# Out:
# Found the following XML files in suspicious-xml folder:
#   suspicious-document02849.xml
#   suspicious-document03110.xml
#   suspicious-document07293.xml
#
# Available source files (from source-files folder):
#   source-document00026.txt
#   source-document00114.txt
#   source-document00117.txt
#   source-document00129.txt
#   source-document00181.txt
#   source-document00209.txt
#   source-document00250.txt
#   source-document00280.txt
#   source-document00291.txt
#   source-document00440.txt
#   source-document00455.txt
#   source-document00479.txt
#   source-document00483.txt
#   source-document00495.txt
#   source-document00503.txt
#   source-document00677.txt
#   source-document00829.txt
#   source-document00867.txt
#   source-document00942.txt
#   source-document00955.txt
#   source-document01012.txt
#   source-document01113.txt
#   source-document01258.txt
#   source-document01277.txt
#   source-document01390.txt
#   source-document01436.txt
#   source-document01649.txt
#   source-document01666.txt
#   source-document01704.txt
#   source-document01718.txt
#   source-document01744.txt
#   source-document01782.txt
#   source-document01846.txt
#   source-document01919.txt
#   source-document01957.txt
#   source-document01999.txt
#   source-document02036.txt
#   source-document02082.txt
#   source-document02205.txt
#   source-document02436.txt
#   source-document02594.txt
#   source-document02679.txt
#   source-document02728.txt
#   source-document02740.txt
#   source-document02996.txt
#   source-document03346.txt
#   source-document03528.txt
#   source-document03535.txt
#   source-document03582.txt
#   source-document03608.txt
#   source-document03629.txt
#   source-document03699.txt
#   source-document03724.txt
#   source-document03728.txt
#   source-document03789.txt
#   source-document03804.txt
#   source-document03819.txt
#   source-document03975.txt
#   source-document04027.txt
#   source-document04053.txt
#   source-document04093.txt
#   source-document04274.txt
#   source-document04288.txt
#   source-document04333.txt
#   source-document04370.txt
#   source-document04426.txt
#   source-document04430.txt
#   source-document04483.txt
#   source-document04527.txt
#   source-document04544.txt
#   source-document04545.txt
#   source-document04600.txt
#   source-document04618.txt
#   source-document04933.txt
#   source-document04988.txt
#   source-document05176.txt
#   source-document05263.txt
#   source-document05268.txt
#   source-document05270.txt
#   source-document05420.txt
#   source-document05487.txt
#   source-document05665.txt
#   source-document05699.txt
#   source-document05722.txt
#   source-document05757.txt
#   source-document05768.txt
#   source-document05784.txt
#   source-document05787.txt
#   source-document05788.txt
#   source-document05800.txt
#   source-document05880.txt
#   source-document06076.txt
#   source-document06323.txt
#   source-document06400.txt
#   source-document06483.txt
#   source-document06547.txt
#   source-document06658.txt
#   source-document06892.txt
#   source-document06929.txt
#   source-document06941.txt
#   source-document06994.txt
#   source-document07140.txt
#   source-document07147.txt
#   source-document07189.txt
#   source-document07211.txt
#   source-document07250.txt
#   source-document07268.txt
#   source-document07303.txt
#   source-document07311.txt
#   source-document07352.txt
#   source-document07359.txt
#   source-document07485.txt
#   source-document07644.txt
#   source-document07914.txt
#   source-document07922.txt
#   source-document08000.txt
#   source-document08018.txt
#   source-document08072.txt
#   source-document08098.txt
#   source-document08171.txt
#   source-document08176.txt
#   source-document08229.txt
#   source-document08250.txt
#   source-document08317.txt
#   source-document08460.txt
#   source-document08581.txt
#   source-document08584.txt
#   source-document08600.txt
#   source-document08637.txt
#   source-document08758.txt
#   source-document08874.txt
#   source-document09014.txt
#   source-document09169.txt
#   source-document09334.txt
#   source-document09374.txt
#   source-document09427.txt
#   source-document09502.txt
#   source-document09534.txt
#   source-document09545.txt
#   source-document09660.txt
#   source-document09718.txt
#   source-document09818.txt
#   source-document09827.txt
#   source-document10011.txt
#   source-document10075.txt
#   source-document10107.txt
#   source-document10152.txt
#   source-document10194.txt
#   source-document10253.txt
#   source-document10369.txt
#   source-document10393.txt
#   source-document10410.txt
#   source-document10500.txt
#   source-document10509.txt
#   source-document10540.txt
#   source-document10616.txt
#   source-document10795.txt
#   source-document10870.txt
#   source-document10903.txt
# suspicious-document03110.xml references 83 source file(s).
# suspicious-document07293.xml references 72 source file(s).
# suspicious-document02849.xml references 71 source file(s).
#
# Pairwise intersections (2-wise):
# suspicious-document03110.xml & suspicious-document07293.xml: 29 common source file(s)
# suspicious-document03110.xml & suspicious-document02849.xml: 24 common source file(s)
# suspicious-document07293.xml & suspicious-document02849.xml: 27 common source file(s)
#
# 3-wise intersections:
# suspicious-document03110.xml, suspicious-document07293.xml, suspicious-document02849.xml: 13 common source file(s)

# %%
import os
import re
import xml.etree.ElementTree as ET
import itertools
from collections import defaultdict

# -------------------------------------------------------------------------
# Base folders (adjust these paths as needed)
# -------------------------------------------------------------------------
# Folder with three subfolders: suspicious-xml, suspicious-files, source-files.
selected_files_folder = "/content/drive/MyDrive/example-three-xml-files/selected-files-1"

susp_xml_folder = os.path.join(selected_files_folder, "suspicious-xml")
susp_main_folder = os.path.join(selected_files_folder, "suspicious-files")
source_main_folder = os.path.join(selected_files_folder, "source-files")

# The folder that contains the "parts" subfolders (external folder structure)
parts_base_folder = "/content/drive/MyDrive/example-three-xml-files"

# -------------------------------------------------------------------------
# Summary data structures
# -------------------------------------------------------------------------
summary = {
    "found": [],
    "missing": []
}

# -------------------------------------------------------------------------
# Step 1: Get list of XML files from suspicious-xml folder
# -------------------------------------------------------------------------
xml_files = [os.path.join(susp_xml_folder, f)
             for f in os.listdir(susp_xml_folder)
             if f.lower().endswith(".xml") and os.path.isfile(os.path.join(susp_xml_folder, f))]
print(f"Found {len(xml_files)} XML files in {susp_xml_folder}")

if not xml_files:
    print("No XML files found. Exiting.")
    exit()

# Process all XML files (or you can adjust if needed)
for xml_path in xml_files:
    xml_filename = os.path.basename(xml_path)            # e.g., suspicious-document02849.xml
    base_name = os.path.splitext(xml_filename)[0]          # e.g., suspicious-document02849
    print(f"\nProcessing XML file: {xml_filename}")

    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
    except Exception as e:
        print(f"Error parsing {xml_filename}: {e}")
        continue

    # ---------------------------------------------------------------------
    # Step 2: Collect snippet information (each <feature> element)
    # ---------------------------------------------------------------------
    snippet_infos = []  # List of dicts.
    for feature in root.findall(".//feature"):
        # Suspicious snippet details (if available)
        this_offset = feature.get("this_offset")
        this_length = feature.get("this_length")
        if this_offset and this_length:
            snippet_infos.append({
                "type": "suspicious",
                "offset": this_offset,
                "length": this_length
            })
        # Source snippet details (if available)
        source_reference = feature.get("source_reference")
        source_offset = feature.get("source_offset")
        source_length = feature.get("source_length")
        if source_reference and source_offset and source_length:
            snippet_infos.append({
                "type": "source",
                "source_reference": source_reference,
                "offset": source_offset,
                "length": source_length
            })

    # ---------------------------------------------------------------------
    # Step 3: Create expected snippet file names from the XML snippet info.
    # ---------------------------------------------------------------------
    expected_files = []
    for info in snippet_infos:
        if info["type"] == "suspicious":
            expected_filename = f"{base_name}-{info['offset']}-{info['length']}.txt"
        else:
            expected_filename = f"{os.path.splitext(info['source_reference'])[0]}-{info['offset']}-{info['length']}.txt"
        expected_files.append((info["type"], expected_filename))

    # ---------------------------------------------------------------------
    # Step 4: Find the corresponding parts folder.
    # We assume that in parts_base_folder there is a subfolder whose name
    # starts with base_name (e.g., suspicious-document02849) and inside it,
    # there is a subfolder ending with "-parts".
    # ---------------------------------------------------------------------
    matched_parts_folder = None
    for candidate in os.listdir(parts_base_folder):
        candidate_path = os.path.join(parts_base_folder, candidate)
        if os.path.isdir(candidate_path) and candidate.startswith(base_name):
            for sub_candidate in os.listdir(candidate_path):
                if sub_candidate.endswith("-parts"):
                    matched_parts_folder = os.path.join(candidate_path, sub_candidate)
                    break
            if matched_parts_folder:
                break

    if not matched_parts_folder:
        summary["missing"].append(f"{base_name}: Parts folder not found in {parts_base_folder}")
        continue

    # List files in the matched parts folder.
    parts_files = os.listdir(matched_parts_folder)

    # ---------------------------------------------------------------------
    # Step 5: For each expected snippet file, match with files in parts folder.
    # ---------------------------------------------------------------------
    for snip_type, expected_filename in expected_files:
        matched = [f for f in parts_files if f.startswith(expected_filename)]
        if matched:
            matched_file = matched[0]
            parts_file_path = os.path.join(matched_parts_folder, matched_file)
            with open(parts_file_path, "r", encoding="utf-8") as pf:
                parts_text = pf.read()

            # Update: Take text starting from the second character up to the second-to-last character.
            if len(parts_text) > 2:
                parts_text = parts_text[0:-1]

            # Determine the corresponding main file based on snippet type.
            if snip_type == "suspicious":
                main_file_path = os.path.join(susp_main_folder, f"{base_name}.txt")
            else:
                src_ref = None
                for info in snippet_infos:
                    if info["type"] == "source":
                        exp_fn = f"{os.path.splitext(info['source_reference'])[0]}-{info['offset']}-{info['length']}.txt"
                        if exp_fn == expected_filename:
                            src_ref = info["source_reference"]
                            break
                if src_ref is None:
                    main_file_path = None
                else:
                    main_file_path = os.path.join(source_main_folder, src_ref)

            if main_file_path and os.path.isfile(main_file_path):
                with open(main_file_path, "r", encoding="utf-8") as mf:
                    main_text = mf.read()
                # Compare the parts text with the main text without any whitespace normalization.
                if parts_text in main_text:
                    summary["found"].append(f"{matched_file} found in {os.path.basename(main_file_path)}")
                else:
                    summary["missing"].append(f"{matched_file} NOT found in {os.path.basename(main_file_path)}")
            else:
                summary["missing"].append(f"{matched_file}: Main file not found (expected: {main_file_path})")
        else:
            summary["missing"].append(f"Expected parts file with prefix '{expected_filename}' not found in {matched_parts_folder} for {base_name}")

# -------------------------------------------------------------------------
# Step 6: Print the summary
# -------------------------------------------------------------------------
print("\nSummary of matched files:")
print("Found:")
for line in summary["found"]:
    print("  " + line)
print("\nMissing:")
for line in summary["missing"]:
    print("  " + line)
# Out:
# Found 3 XML files in /content/drive/MyDrive/example-three-xml-files/selected-files-1/suspicious-xml
#
# Processing XML file: suspicious-document03110.xml
#
# Processing XML file: suspicious-document07293.xml
#
# Processing XML file: suspicious-document02849.xml
#
# Summary of matched files:
# Found:
#   suspicious-document03110-5514-14996.txt found in suspicious-document03110.txt
#   source-document04483-161-15034.txt found in source-document04483.txt
#   suspicious-document03110-25140-20998.txt found in suspicious-document03110.txt
#   source-document04288-1380-21016.txt found in source-document04288.txt
#   suspicious-document03110-54013-18561.txt found in suspicious-document03110.txt
#   source-document10795-154980-18552.txt found in source-document10795.txt
#   suspicious-document03110-86274-23949.txt found in suspicious-document03110.txt
#   source-document08758-334957-24015.txt found in source-document08758.txt
#   suspicious-document03110-111731-3752.txt found in suspicious-document03110.txt
#   source-document07250-85333-3744.txt found in source-document07250.txt
#   suspicious-document03110-119372-20273.txt found in suspicious-document03110.txt
#   source-document09014-388116-20609.txt found in source-document09014.txt
#   suspicious-document03110-145481-679.txt found in suspicious-document03110.txt
#   source-document08250-37474-713.txt found in source-document08250.txt
#   suspicious-document03110-151814-14996.txt found in suspicious-document03110.txt
#   source-document01436-13175-14971.txt found in source-document01436.txt
#   suspicious-document03110-167917-2418.txt found in suspicious-document03110.txt
#   source-document06892-22984-2413.txt found in source-document06892.txt
#   suspicious-document03110-170434-752.txt found in suspicious-document03110.txt
#   source-document07311-1037-750.txt found in source-document07311.txt
#   suspicious-document03110-172024-3461.txt found in suspicious-document03110.txt
#   source-document00955-7169-3453.txt found in source-document00955.txt
#   suspicious-document03110-178823-23826.txt found in suspicious-document03110.txt
#   source-document01718-9190-23761.txt found in source-document01718.txt
#   suspicious-document03110-210873-3773.txt found in suspicious-document03110.txt
#   source-document06658-1899-3766.txt found in source-document06658.txt
#   suspicious-document03110-217955-22792.txt found in suspicious-document03110.txt
#   source-document00677-185101-22717.txt found in source-document00677.txt
#   suspicious-document03110-254133-18808.txt found in suspicious-document03110.txt
#   source-document06483-9599-16197.txt found in source-document06483.txt
#   suspicious-document02849-1453743-24701.txt found in suspicious-document02849.txt
#   source-document07644-2427-24504.txt found in source-document07644.txt
#   suspicious-document02849-1483627-16513.txt found in suspicious-document02849.txt
#   source-document04093-5463-16448.txt found in source-document04093.txt
#   suspicious-document02849-1508878-16255.txt found in suspicious-document02849.txt
#   source-document06483-9599-16197.txt found in source-document06483.txt
#   suspicious-document02849-1528202-19040.txt found in suspicious-document02849.txt
#   source-document07359-380134-19011.txt found in source-document07359.txt
#   suspicious-document02849-1556664-19278.txt found in suspicious-document02849.txt
#   source-document10194-6220-19231.txt found in source-document10194.txt
#
# Missing:

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.11/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.11/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2025.1.31)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2025.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)

# %% [markdown]
# Next code is for translation the extracted plagiarised texts and also it checks before doing translation whether the document has been already translated before.

# %%
import os
import re
import time
from googletrans import Translator

base_folder = "/content/drive/MyDrive/xml-files"

translator = Translator()

def chunk_text_by_paragraph(text, max_size=2000):
    """
    Splits 'text' into chunks of up to 'max_size' characters,
    splitting by paragraphs without adding extra newlines.
    """
    # Split text into paragraphs by identifying natural paragraph breaks
    paragraphs = re.split(r'\n\s*\n', text)

    # Combine paragraphs into chunks without adding extra newlines
    chunks = []
    current_chunk = []
    current_length = 0
    for paragraph in paragraphs:
        if current_length + len(paragraph) <= max_size:
            current_chunk.append(paragraph)
            current_length += len(paragraph)
        else:
            if current_chunk:
                chunks.append(" ".join(current_chunk))
            current_chunk = [paragraph]
            current_length = len(paragraph)
    if current_chunk:
        chunks.append(" ".join(current_chunk))
    return chunks

# Walk through each folder under base_folder
for root, dirs, files in os.walk(base_folder):
    # Only process folders that end with '-parts'
    if root.endswith("-parts"):
        print(f"Processing folder: {root}")
        for file in files:
            if file.lower().endswith(".txt"):
                original_file_path = os.path.join(root, file)
                # Build the expected translated file name "kz-" + original file name
                translated_file_name = "kz-" + file
                translated_file_path = os.path.join(root, translated_file_name)

                # Check if "kz-" version already exists
                if os.path.isfile(translated_file_path):
                    print(f"Skipping '{file}', already translated as '{translated_file_name}'")
                    continue

                try:
                    with open(original_file_path, "r", encoding="utf-8") as f:
                        content = f.read()

                    max_retries = 3
                    wait_time = 2
                    translated_text = None

                    for attempt in range(max_retries):
                        try:
                            # Chunk the text by paragraph boundaries (max ~2000 chars each)
                            chunks = chunk_text_by_paragraph(content, max_size=2000)

                            outchunks = []
                            for c in chunks:
                                # Attempt translation for each chunk
                                res = translator.translate(c, dest='kk')
                                if not res or not res.text:
                                    raise ValueError("Translation result is None.")
                                outchunks.append(res.text)

                            # Join translated chunks with a single space between them
                            translated_text = " ".join(outchunks)
                            break  # Successful translation; break out of retry loop
                        except Exception as e:
                            print(f"[{file}] Attempt {attempt+1} failed: {e}")
                            time.sleep(wait_time)

                    if translated_text is None:
                        print(f"[ERROR] Could not translate '{file}' after {max_retries} attempts.")
                        continue

                    # Save the result with "kz-" prepended to the original file name
                    with open(translated_file_path, "w", encoding="utf-8") as out_f:
                        out_f.write(translated_text)
                    print(f"Translated {file} -> {translated_file_name}")

                except Exception as e:
                    print(f"Error reading or translating {file}: {e}")

# %%
import os
import shutil

# Base folder to search (adjust as needed)
base_folder = "/content/drive/MyDrive/xml-files"

# Destination folder for all unique translated Kazakh documents
dest_folder = "/content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents"
os.makedirs(dest_folder, exist_ok=True)

# Walk through the directory tree in the base folder
for root, dirs, files in os.walk(base_folder):
    # Skip if we're already in the destination folder to avoid moving files repeatedly
    if dest_folder in root:
        continue
    for file in files:
        # Identify files that are translated (prefix "kz-" and ending with .txt)
        if file.startswith("kz-") and file.lower().endswith(".txt"):
            source_path = os.path.join(root, file)
            dest_path = os.path.join(dest_folder, file)
            print(f"Moving {source_path} to {dest_path}")
            shutil.move(source_path, dest_path)

print("All translated files have been moved to the destination folder.")
# Out:
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-5514-14996.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-5514-14996.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-25140-20998.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-25140-20998.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-54013-18561.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-54013-18561.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document10795-154980-18552.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document10795-154980-18552.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-86274-23949.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-86274-23949.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-111731-3752.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-111731-3752.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-119372-20273.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-119372-20273.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document09014-388116-20609.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document09014-388116-20609.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-145481-679.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-145481-679.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document08250-37474-713.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document08250-37474-713.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-151814-14996.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-151814-14996.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document01436-13175-14971.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document01436-13175-14971.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-167917-2418.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-167917-2418.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document06892-22984-2413.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document06892-22984-2413.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-170434-752.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-170434-752.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document07311-1037-750.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document07311-1037-750.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-172024-3461.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-172024-3461.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document00955-7169-3453.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00955-7169-3453.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-178823-23826.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-178823-23826.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-210873-3773.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-210873-3773.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document06658-1899-3766.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document06658-1899-3766.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-217955-22792.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-217955-22792.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-254133-18808.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-254133-18808.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document08600-113045-18739.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document08600-113045-18739.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-275379-17249.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-275379-17249.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-300199-20277.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-300199-20277.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document00114-180540-20271.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00114-180540-20271.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-327657-467.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-327657-467.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-328681-2239.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-328681-2239.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document06941-534-2221.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document06941-534-2221.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-337311-19261.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-337311-19261.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document10194-6220-19231.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document10194-6220-19231.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-368301-22795.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-368301-22795.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document00677-185101-22717.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00677-185101-22717.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-396259-14992.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-396259-14992.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-413575-23237.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-413575-23237.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-448560-3705.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-448560-3705.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-453800-17243.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-453800-17243.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-source-document00117-7658-17220.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00117-7658-17220.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-612904-1855.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-612904-1855.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-620210-16793.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110-620210-16793.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document03110/suspicious-document03110-parts/kz-suspicious-document03110-640304-3699.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document03110
txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document08098-145544-22259.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1231783-18043.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1231783-18043.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document00942-260-18029.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00942-260-18029.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1253476-21583.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1253476-21583.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document04333-73238-21533.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document04333-73238-21533.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1283041-15701.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1283041-15701.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document09169-586832-15741.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document09169-586832-15741.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1300521-3880.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1300521-3880.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document00291-2008-3987.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00291-2008-3987.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1305639-3250.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1305639-3250.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document00114-180540-20271.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00114-180540-20271.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document00829-30746-3157.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00829-30746-3157.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1313722-22834.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1313722-22834.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document08018-15131-22702.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document08018-15131-22702.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1343545-17374.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1343545-17374.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document00117-7658-17220.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document00117-7658-17220.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1367553-24903.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1367553-24903.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1398218-24218.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1398218-24218.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document08000-226942-24184.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document08000-226942-24184.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1430016-16221.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1430016-16221.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1453743-24701.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1453743-24701.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document07644-2427-24504.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document07644-2427-24504.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1483627-16513.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1483627-16513.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1508878-16255.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1508878-16255.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1528202-19040.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1528202-19040.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document07359-380134-19011.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document07359-380134-19011.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-suspicious-document02849-1556664-19278.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-suspicious-document02849-1556664-19278.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document10194-6220-19231.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document10194-6220-19231.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document08176-158594-24741.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document08176-158594-24741.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document04093-5463-16448.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document04093-5463-16448.txt
# Moving /content/drive/MyDrive/example-three-xml-files/suspicious-document02849/suspicious-document02849-parts/kz-source-document06483-9599-16197.txt to /content/drive/MyDrive/example-three-xml-files/all-unique-translated-kazakh-documents/kz-source-document06483-9599-16197.txt
# All translated files have been moved to the destination folder.

# %%
import os
import re
import time
import xml.etree.ElementTree as ET
from collections import defaultdict
from googletrans import Translator

# -------------------------------------------------------------------------
# Base folders (adjust these paths as needed)
# -------------------------------------------------------------------------
selected_files_folder = "/content/drive/MyDrive/xml-files"

susp_xml_folder = os.path.join(selected_files_folder, "suspicious-xml")
susp_main_folder = os.path.join(selected_files_folder, "suspicious-files")
source_main_folder = os.path.join(selected_files_folder, "source-files")

# Folder with all the Kazakh translated snippet files (unique translated documents)
kazakh_folder = "/content/drive/MyDrive/xml-files/all-unique-translated-kazakh-documents"

# The folder that contains the "parts" subfolders (external folder structure)
parts_base_folder = "/content/drive/MyDrive/xml-files"

# -------------------------------------------------------------------------
# Summary data structures
# -------------------------------------------------------------------------
summary = {
    "found": [],
    "skipped": [],
    "missing": []
}

# Dictionary to track which snippet (expected filename) has been updated in a main file.
updated_snippets = defaultdict(set)

translator = Translator()

# -------------------------------------------------------------------------
# Step 1: Get list of XML files from suspicious-xml folder
# -------------------------------------------------------------------------
xml_files = [os.path.join(susp_xml_folder, f)
             for f in os.listdir(susp_xml_folder)
             if f.lower().endswith(".xml") and os.path.isfile(os.path.join(susp_xml_folder, f))]
print(f"Found {len(xml_files)} XML files in {susp_xml_folder}")

if not xml_files:
    print("No XML files found. Exiting.")
    exit()

# Process all XML files
for xml_path in xml_files:
    xml_filename = os.path.basename(xml_path)            # e.g., suspicious-document02849.xml
    base_name = os.path.splitext(xml_filename)[0]          # e.g., suspicious-document02849
    print(f"\nProcessing XML file: {xml_filename}")

    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
    except Exception as e:
        print(f"Error parsing {xml_filename}: {e}")
        continue

    # ---------------------------------------------------------------------
    # Step 2: Collect snippet information (each <feature> element)
    # ---------------------------------------------------------------------
    snippet_infos = []  # List of dicts.
    for feature in root.findall(".//feature"):
        # Suspicious snippet details (if available)
        this_offset = feature.get("this_offset")
        this_length = feature.get("this_length")
        if this_offset and this_length:
            snippet_infos.append({
                "type": "suspicious",
                "offset": this_offset,
                "length": this_length
            })
        # Source snippet details (if available)
        source_reference = feature.get("source_reference")
        source_offset = feature.get("source_offset")
        source_length = feature.get("source_length")
        if source_reference and source_offset and source_length:
            snippet_infos.append({
                "type": "source",
                "source_reference": source_reference,
                "offset": source_offset,
                "length": source_length
            })

    # ---------------------------------------------------------------------
    # Step 3: Create expected snippet file names from the XML snippet info.
    # ---------------------------------------------------------------------
    expected_files = []
    for info in snippet_infos:
        if info["type"] == "suspicious":
            expected_filename = f"{base_name}-{info['offset']}-{info['length']}.txt"
        else:
            expected_filename = f"{os.path.splitext(info['source_reference'])[0]}-{info['offset']}-{info['length']}.txt"
        expected_files.append((info["type"], expected_filename))

    # ---------------------------------------------------------------------
    # Step 4: Find the corresponding parts folder.
    # We assume that in parts_base_folder there is a subfolder whose name
    # starts with base_name and inside it, there is a subfolder ending with "-parts".
    # ---------------------------------------------------------------------
    matched_parts_folder = None
    for candidate in os.listdir(parts_base_folder):
        candidate_path = os.path.join(parts_base_folder, candidate)
        if os.path.isdir(candidate_path) and candidate.startswith(base_name):
            for sub_candidate in os.listdir(candidate_path):
                if sub_candidate.endswith("-parts"):
                    matched_parts_folder = os.path.join(candidate_path, sub_candidate)
                    break
            if matched_parts_folder:
                break

    if not matched_parts_folder:
        summary["missing"].append(f"{base_name}: Parts folder not found in {parts_base_folder}")
        continue

    # List files in the matched parts folder.
    parts_files = os.listdir(matched_parts_folder)

    # ---------------------------------------------------------------------
    # Step 5: For each expected snippet file, match with files in parts folder and update main file.
    # ---------------------------------------------------------------------
    for snip_type, expected_filename in expected_files:
        # Skip if already updated in this main file.
        # Determine main file path.
        if snip_type == "suspicious":
            main_file_path = os.path.join(susp_main_folder, f"{base_name}.txt")
        else:
            src_ref = None
            for info in snippet_infos:
                if info["type"] == "source":
                    exp_fn = f"{os.path.splitext(info['source_reference'])[0]}-{info['offset']}-{info['length']}.txt"
                    if exp_fn == expected_filename:
                        src_ref = info["source_reference"]
                        break
            if src_ref is None:
                main_file_path = None
            else:
                main_file_path = os.path.join(source_main_folder, src_ref)

        if main_file_path is None or not os.path.isfile(main_file_path):
            summary["missing"].append(f"{expected_filename}: Main file not found (expected: {main_file_path})")
            continue

        if expected_filename in updated_snippets[main_file_path]:
            summary["skipped"].append(f"{expected_filename} already updated in {os.path.basename(main_file_path)}")
            continue

        matched = [f for f in parts_files if f.startswith(expected_filename)]
        if not matched:
            summary["missing"].append(f"Expected parts file with prefix '{expected_filename}' not found in {matched_parts_folder} for {base_name}")
            continue

        matched_file = matched[0]
        parts_file_path = os.path.join(matched_parts_folder, matched_file)
        with open(parts_file_path, "r", encoding="utf-8") as pf:
            parts_text = pf.read()

        # Take text starting from the second character up to the second-to-last character (if long enough)
        if len(parts_text) > 2:
            parts_text = parts_text[0:0]

        with open(main_file_path, "r", encoding="utf-8") as mf:
            main_text = mf.read()

        # Load the corresponding Kazakh snippet file
        kazakh_file = os.path.join(kazakh_folder, "kz-" + expected_filename)
        if not os.path.isfile(kazakh_file):
            summary["missing"].append(f"Translated Kazakh file not found: {kazakh_file}")
            continue
        with open(kazakh_file, "r", encoding="utf-8") as kf:
            kazakh_snippet = kf.read()

        # Add a leading and trailing space to the Kazakh snippet
        kazakh_snippet = " " + kazakh_snippet + " "

        # Check if the main text already contains the Kazakh snippet
        if kazakh_snippet in main_text:
            summary["skipped"].append(f"{expected_filename} already replaced in {os.path.basename(main_file_path)}")
            updated_snippets[main_file_path].add(expected_filename)
            continue

        # Otherwise, try to find the original snippet in the main text.
        if parts_text in main_text:
            updated_main_text = main_text.replace(parts_text, kazakh_snippet, 1)
            with open(main_file_path, "w", encoding="utf-8") as mf:
                mf.write(updated_main_text)
            summary["found"].append(f"{matched_file} replaced in {os.path.basename(main_file_path)}")
            updated_snippets[main_file_path].add(expected_filename)
        else:
            summary["missing"].append(f"{matched_file} (original snippet) NOT found in {os.path.basename(main_file_path)}")

# -------------------------------------------------------------------------
# Step 6: Print the summary
# -------------------------------------------------------------------------
print("\nSummary of updated files:")
print("Replaced:")
for line in summary["found"]:
    print("  " + line)
print("\nSkipped (already updated):")
for line in summary["skipped"]:
    print("  " + line)
print("\nMissing:")
for line in summary["missing"]:
    print("  " + line)
# Out:
# Found 3 XML files in /content/drive/MyDrive/example-three-xml-files/selected-files-1/suspicious-xml
#
# Processing XML file: suspicious-document03110.xml
#
# Processing XML file: suspicious-document07293.xml
#
# Processing XML file: suspicious-document02849.xml
#
# Summary of updated files:
# Replaced:
#   source-document05880-7640-1951.txt replaced in source-document05880.txt
#   source-document08018-12475-15603.txt replaced in source-document08018.txt
#
# Skipped (already updated):
#   suspicious-document03110-5514-14996.txt already replaced in suspicious-document03110.txt
#   source-document04483-161-15034.txt already replaced in source-document04483.txt
#   suspicious-document03110-25140-20998.txt already replaced in suspicious-document03110.txt
#   source-document04288-1380-21016.txt already replaced in source-document04288.txt
#   suspicious-document03110-54013-18561.txt already replaced in suspicious-document03110.txt
#   source-document10795-154980-18552.txt already replaced in source-document10795.txt
#   suspicious-document03110-86274-23949.txt already replaced in suspicious-document03110.txt
#   source-document08758-334957-24015.txt already replaced in source-document08758.txt
#   suspicious-document03110-111731-3752.txt already replaced in suspicious-document03110.txt
#   suspicious-document02849-1231783-18043.txt already replaced in suspicious-document02849.txt
#   source-document00942-260-18029.txt already updated in source-document00942.txt
#   suspicious-document02849-1253476-21583.txt already replaced in suspicious-document02849.txt
#   source-document04333-73238-21533.txt already updated in source-document04333.txt
#   suspicious-document02849-1283041-15701.txt already replaced in suspicious-document02849.txt
#   source-document09169-586832-15741.txt already updated in source-document09169.txt
#   suspicious-document02849-1300521-3880.txt already replaced in suspicious-document02849.txt
#   source-document00291-2008-3987.txt already replaced in source-document00291.txt
#   suspicious-document02849-1305639-3250.txt already replaced in suspicious-document02849.txt
#   source-document00829-30746-3157.txt already replaced in source-document00829.txt
#   suspicious-document02849-1313722-22834.txt already replaced in suspicious-document02849.txt
#   source-document08018-15131-22702.txt already updated in source-document08018.txt
#   suspicious-document02849-1343545-17374.txt already replaced in suspicious-document02849.txt
#   source-document00117-7658-17220.txt already updated in source-document00117.txt
#   suspicious-document02849-1367553-24903.txt already replaced in suspicious-document02849.txt
#   source-document08176-158594-24741.txt already updated in source-document08176.txt
#   suspicious-document02849-1398218-24218.txt already replaced in suspicious-document02849.txt
#   source-document08000-226942-24184.txt already replaced in source-document08000.txt
#   suspicious-document02849-1430016-16221.txt already replaced in suspicious-document02849.txt
#   source-document06483-9599-16197.txt already updated in source-document06483.txt
#   suspicious-document02849-1453743-24701.txt already replaced in suspicious-document02849.txt
#   source-document07644-2427-24504.txt already updated in source-document07644.txt
#   suspicious-document02849-1483627-16513.txt already replaced in suspicious-document02849.txt
#   source-document04093-5463-16448.txt already updated in source-document04093.txt
#   suspicious-document02849-1508878-16255.txt already replaced in suspicious-document02849.txt
#   source-document06483-9599-16197.txt already updated in source-document06483.txt
#   suspicious-document02849-1528202-19040.txt already replaced in suspicious-document02849.txt
#   source-document07359-380134-19011.txt already updated in source-document07359.txt
#   suspicious-document02849-1556664-19278.txt already replaced in suspicious-document02849.txt
#   source-document10194-6220-19231.txt already updated in source-document10194.txt
#
# Missing:

# %%
import os
import re
import time
from googletrans import Translator

base_folder = "/content/drive/MyDrive/xml-files/suspicious-files"

translator = Translator()

def chunk_text_by_paragraph(text, max_size=2000):
    """
    Splits 'text' into chunks up to 'max_size' characters,
    splitting by paragraphs without adding newlines.
    """
    # Split text into paragraphs by natural paragraph breaks
    paragraphs = re.split(r'\n\s*\n', text)

    # Combine paragraphs into chunks without adding extra newlines
    chunks = []
    current_chunk = []
    current_length = 0
    for paragraph in paragraphs:
        if current_length + len(paragraph) <= max_size:
            current_chunk.append(paragraph)
            current_length += len(paragraph)
        else:
            if current_chunk:
                chunks.append(" ".join(current_chunk))
            current_chunk = [paragraph]
            current_length = len(paragraph)
    if current_chunk:
        chunks.append(" ".join(current_chunk))
    return chunks

# Walk through each folder under base_folder
for root, dirs, files in os.walk(base_folder):
    # Only process folders that end with '-parts'
    if startswith("suspiciosus-document"):
        print(f"Processing folder: {root}")
        for file in files:
            if file.lower().endswith(".txt"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, "r", encoding="utf-8") as f:
                        content = f.read()

                    max_retries = 3
                    wait_time = 2
                    translated_text = None

                    for attempt in range(max_retries):
                        try:
                            # Chunk the text by paragraph boundaries (max ~2000 chars each)
                            chunks = chunk_text_by_paragraph(content, max_size=2000)

                            outchunks = []
                            for c in chunks:
                                # Attempt translation for each chunk
                                res = translator.translate(c, dest='kk')
                                if not res or not res.text:
                                    raise ValueError("Translation result is None.")
                                outchunks.append(res.text)

                            # Join translated chunks with a single space between them
                            translated_text = " ".join(outchunks)
                            break  # Successful translation; break out of retry loop
                        except Exception as e:
                            print(f"[{file}] Attempt {attempt+1} failed: {e}")
                            time.sleep(wait_time)

                    if translated_text is None:
                        print(f"[ERROR] Could not translate '{file}' after {max_retries} attempts.")
                        continue

                    # Save the result with "kz-" prepended to the original file name
                    new_file_name = "kz-" + file
                    new_file_path = os.path.join(root, new_file_name)
                    with open(new_file_path, "w", encoding="utf-8") as out_f:
                        out_f.write(translated_text)
                    print(f"Translated {file} -> {new_file_name}")

                except Exception as e:
                    print(f"Error reading or translating {file}: {e}")

# %% [markdown]
# Next code is for translation the whole documents and also it checks before doing translation whether the document has been already translated before.
#
# If you see repeated failures with 2,000, you can reduce it to 1,000 or even 500 to lower the chance of hitting unexpected rate limits or long-response issues. But in many workflows, 2,000 characters per chunk is a good balance to keep translation context while minimizing request failures.

# %%
import os
import re
import time
from googletrans import Translator

# Folders containing files you want to translate
susp_main_folder = "/content/drive/MyDrive/xml-files/suspicious-files"
source_main_folder = "/content/drive/MyDrive/xml-files/source-files"

folders_to_translate = [susp_main_folder, source_main_folder]
translator = Translator()

def chunk_text_by_paragraph(text, max_size=2000):
    paragraphs = re.split(r'\n\s*\n', text)
    chunks = []
    current_chunk = []
    current_length = 0
    for paragraph in paragraphs:
        if current_length + len(paragraph) <= max_size:
            current_chunk.append(paragraph)
            current_length += len(paragraph)
        else:
            if current_chunk:
                chunks.append(" ".join(current_chunk))
            current_chunk = [paragraph]
            current_length = len(paragraph)
    if current_chunk:
        chunks.append(" ".join(current_chunk))
    return chunks

max_retries = 3
wait_time = 2

for folder_path in folders_to_translate:
    print(f"\n=== Now processing folder: {folder_path} ===\n")
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Only handle .txt and skip files already named "kz-..."
            if file.lower().endswith(".txt") and not file.startswith("kz-"):
                original_file_path = os.path.join(root, file)

                # If "kz-" version already exists, skip
                translated_file_name = "kz-" + file
                translated_file_path = os.path.join(root, translated_file_name)
                if os.path.isfile(translated_file_path):
                    print(f"Skipping {file}, already translated as {translated_file_name}")
                    continue

                try:
                    with open(original_file_path, "r", encoding="utf-8") as f:
                        content = f.read()

                    translated_text = None
                    for attempt in range(max_retries):
                        try:
                            chunks = chunk_text_by_paragraph(content, max_size=2000)
                            outchunks = []
                            for c in chunks:
                                res = translator.translate(c, dest='kk')
                                if not res or not res.text:
                                    raise ValueError("Translation result is None.")
                                outchunks.append(res.text)
                            translated_text = " ".join(outchunks)
                            break
                        except Exception as e:
                            print(f"[{file}] Attempt {attempt+1} failed: {e}")
                            time.sleep(wait_time)

                    if translated_text is None:
                        print(f"[ERROR] Could not translate '{file}' after {max_retries} attempts.")
                        continue

                    # Save the result
                    with open(translated_file_path, "w", encoding="utf-8") as out_f:
                        out_f.write(translated_text)

                    print(f"Translated {file} -> {translated_file_name}")

                except Exception as e:
                    print(f"Error reading or translating {file}: {e}")

# %% [markdown]
# This one is for translating the whole text one by one, and also this code is good for controlling when google translate stops unexpectedly, then you will know from which document to start to translate.

# %%
# !pip install googletrans==3.1.0a0

import os
import os.path
import time
from googletrans import Translator
from google.colab import drive

target_language = "kk"

#path for google drive
googledrive='/content/drive'
drive.mount(googledrive)

#folders' paths in the google-drive from where files are going to be read
path1=googledrive+'/MyDrive/PAN2010/suspicious-files/'
path2=googledrive+'/MyDrive/PAN2010/suspicious-translated-files/'

#counting the number of documents for translation
#n=len([entry for entry in os.listdir(path1) if os.path.isfile(os.path.join(path1, entry))])

# Desired chunk size
chunk_size = 4040

m=15820
n=15926

#function for translation
def translate_text(text):
  translator = Translator()
  if len(text)!=0:
    translated_text = translator.translate(text, dest=target_language)
    time.sleep(2)
    return translated_text.text+' '
  else:
    return '\n'

def divide_string(text, chunk_size):
  chunks = []
  while len(text) > chunk_size:
    # Find the last period before the chunk_size limit
    last_period_index = text.rfind('.', 0, chunk_size)

    # If no period is found, just split at chunk_size
    if last_period_index == -1:
      last_period_index = chunk_size

    # Create a chunk that ends with the last period
    chunk = text[:last_period_index + 1].strip()

    # Add the chunk to the list
    chunks.append(chunk)

    # Remove the processed text from the original string
    text = text[last_period_index + 1:].strip()

    # Add the remaining text as the last chunk
  if text:
    chunks.append(text)

  return chunks

#searching and writing the path of each document
for i in range(m,n):

  if i<10:
    if os.path.isfile(path1+'suspicious-document0000'+str(i)+'.txt')==True:
      path3=path1+'suspicious-document0000'+str(i)+'.txt'
    else:
      continue

  if i>9 and i<100:
    if os.path.isfile(path1+'suspicious-document000'+str(i)+'.txt')==True:
      path3=path1+'suspicious-document000'+str(i)+'.txt'
    else:
      continue

  if i>99 and i<1000:
    if os.path.isfile(path1+'suspicious-document00'+str(i)+'.txt')==True:
      path3=path1+'suspicious-document00'+str(i)+'.txt'
    else:
      continue
  if i>999 and i<10000:
    if os.path.isfile(path1+'suspicious-document0'+str(i)+'.txt')==True:
      path3=path1+'suspicious-document0'+str(i)+'.txt'
    else:
      continue

  if i>9999:
    if os.path.isfile(path1+'suspicious-document'+str(i)+'.txt')==True:
      path3=path1+'suspicious-document'+str(i)+'.txt'
    else:
      continue

  path4=path2+'suspicious-translated'+str(i)+'.txt'

#reading a document from a file

  bla=""

  with open(path3,encoding="utf8", errors='ignore') as file:
    for item in file:
      if item!=0:
        bla+=item.strip()
        bla+=' '

  #print("File:",i)

  # Divide the large string into chunks
  text_chunks = divide_string(bla, chunk_size)

  for chunk in text_chunks:
    with open(path4, 'a+') as f:
      f.write(translate_text(chunk))
      #f.write("\n")
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.10/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.7.22)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This code to translate all the documents one by one, this is good when google translate unexpectedly stops, then you wil know from which document it is better to start again.

# %%
# !pip install googletrans==3.1.0a0

import os
import concurrent.futures
import time
from googletrans import Translator
from google.colab import drive

# ... (drive mounting and paths setup)
googledrive = '/content/drive'
drive.mount(googledrive)

# Drive paths
path1 = googledrive + '/MyDrive/PAN2010/source-files/'
path2 = googledrive + '/MyDrive/PAN2010/translated/'

# ... (chunk_size, m, n, and other configurations)
target_language = "kk"
chunk_size = 4040
max_workers = 8
delay_between_chunks = 2

#first and last number of documents
m=1
n=11149

# ... (translate_text and divide_string functions)
# Function for translation
def translate_text(text):
    return translator.translate(text, dest=target_language).text

#function takes care to ensure that chunks end with a complete sentence
def divide_string(text, chunk_size):
  chunks = []
  while len(text) > chunk_size:
    # Find the last period before the chunk_size limit
    last_period_index = text.rfind('.', 0, chunk_size)

    # If no period is found, just split at chunk_size
    if last_period_index == -1:
      last_period_index = chunk_size

    # Create a chunk that ends with the last period
    chunk = text[:last_period_index + 1].strip()

    # Add the chunk to the list
    chunks.append(chunk)

    # Remove the processed text from the original string
    text = text[last_period_index + 1:].strip()

    # Add the remaining text as the last chunk
  if text:
    chunks.append(text)
  return chunks

# Create target directory if not exists
os.makedirs(path2, exist_ok=True)

# Function to translate and save a chunk
def translate_and_save_chunk(chunk, target_path):
    translated_text = translate_text(chunk)
    with open(target_path, 'a+', encoding='utf8') as target_file:
        target_file.write(translated_text + ' ')

def process_document(i):
    # Construct the file number string based on the document index
    if i < 10:
        file_num_str = '0000' + str(i)
    elif i < 100:
        file_num_str = '000' + str(i)
    elif i < 1000:
        file_num_str = '00' + str(i)
    elif i < 10000:
        file_num_str = '0' + str(i)
    elif i < 16000:
        file_num_str = '' + str(i)
    # ... (similar for other cases)

    # Construct the source and target file paths
    source_path = path1 + f'source-document{file_num_str}.txt'
    target_path = path2 + f'source-translated{file_num_str}.txt'

    # Check if the source file exists before processing
    if os.path.isfile(source_path):
        # Open and process the source file
        with open(source_path, encoding="utf8", errors='ignore') as file:
            text = ' '.join(line.strip() for line in file if line.strip())

        text_chunks = divide_string(text, chunk_size)

        # Process each chunk concurrently
        with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
            for chunk in text_chunks:
                executor.submit(translate_and_save_chunk, chunk, target_path)

# Main loop
if __name__ == '__main__':
    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        for i in range(m, n):
            executor.submit(process_document, i)
            time.sleep(delay_between_chunks)
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.10/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.7.22)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Purpose of the Code:**
#
# The code below is used to **organize all pairs of plagiarised texts** extracted from the **PAN corpora**, along with their **Kazakh translations**, into **separate, structured folders**.
#
#
# ### **Background Workflow Summary:**
#
# 1. **Extraction:**
#    Initially, we extracted all plagiarised segments from the **PAN dataset** using the **offset values** provided in the corresponding **PAN XML files**. These segments were saved as **separate `.txt` files** in designated **English folders** (suspicious and source).
#
# 2. **Translation:**
#    Each English snippet was then **translated into Kazakh** using **Google Translate**, and stored in parallel **Kazakh folders**. The **file names** of the Kazakh translations **mirror** their English counterparts, except that they include the prefix **`kz-`**.
#
# 3. **Organization:**
#    The code below automates the process of **grouping corresponding English and Kazakh text pairs** (both suspicious and source) into **individual folders**. These folders are named based on document references and offset values as specified in the original PAN XML files.

# %%
import os
import shutil
import xml.etree.ElementTree as ET
from concurrent.futures import ThreadPoolExecutor, as_completed

# Define directories
suspicious_xml_folder = "/content/drive/MyDrive/updating-pan-xml-files/all-xml-files-with-plagiarism"
eng_suspicious_docs_folder = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised-partitioned-suspicious-and-source-files/su1so1-plagiarised-english-suspicious-parts-with-english-offsets"
eng_source_docs_folder = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised-partitioned-suspicious-and-source-files/su1so1-plagiarised-english-source-parts-with-english-offsets"
kaz_suspicious_docs_folder = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised-partitioned-suspicious-and-source-files/su1so1-plagiarised-kazakh-suspicious-parts-with-english-offsets"
kaz_source_docs_folder = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised-partitioned-suspicious-and-source-files/su1so1-plagiarised-kazakh-source-parts-with-english-offsets"
output_base_folder = "/content/drive/MyDrive/updating-pan-xml-files/su1so1-plagiarised-english-and-kazakh-suspicious-and-source-matched-texts-2"

# Create output directory if it doesn't exist
os.makedirs(output_base_folder, exist_ok=True)

# Define worker tasks
def create_folder_and_return_paths(folder_index, document_ref, this_offset, this_length, source_reference, source_offset, source_length):
    """Create output folder and prepare file paths for processing."""
    try:
        this_end_offset = this_offset + this_length
        source_end_offset = source_offset + source_length

        output_folder = os.path.join(output_base_folder, f"{document_ref.replace('.txt', '')}-{folder_index}")
        os.makedirs(output_folder, exist_ok=True)

        file_paths = {
            "output_folder": output_folder,
            "eng_suspicious": os.path.join(eng_suspicious_docs_folder, f"{document_ref.replace('.txt', '')}-{this_offset}-{this_end_offset}.txt"),
            "kaz_suspicious": os.path.join(kaz_suspicious_docs_folder, f"kz-{document_ref.replace('.txt', '')}-{this_offset}-{this_end_offset}.txt"),
            "eng_source": os.path.join(eng_source_docs_folder, f"{source_reference.replace('.txt', '')}-{source_offset}-{source_end_offset}.txt"),
            "kaz_source": os.path.join(kaz_source_docs_folder, f"kz-{source_reference.replace('.txt', '')}-{source_offset}-{source_end_offset}.txt")
        }

        return file_paths
    except Exception as e:
        print(f"Error creating folder and paths: {e}")
        return None


def copy_file(source_path, destination_folder):
    """Copy a file to the destination folder."""
    try:
        if os.path.isfile(source_path):
            shutil.copy(source_path, destination_folder)
            return True
        else:
            return False
    except Exception as e:
        print(f"Error copying file {source_path}: {e}")
        return False

# Main processing loop
xml_files = [f for f in os.listdir(suspicious_xml_folder) if f.endswith('.xml')]
print(f"Total XML files to process: {len(xml_files)}")

folder_index = 1

with ThreadPoolExecutor(max_workers=5) as executor:
    for xml_filename in xml_files:
        try:
            xml_path = os.path.join(suspicious_xml_folder, xml_filename)
            tree = ET.parse(xml_path)
            root = tree.getroot()

            document_ref = root.attrib.get('reference', '').replace('.xml', '.txt')

            for feature in root.findall(".//feature[@name='plagiarism']"):
                try:
                    this_offset = int(feature.attrib.get("this_offset", -1))
                    this_length = int(feature.attrib.get("this_length", 0))
                    source_offset = int(feature.attrib.get("source_offset", -1))
                    source_length = int(feature.attrib.get("source_length", 0))
                    source_reference = feature.attrib.get("source_reference", "").strip()
                except ValueError:
                    print(f"Invalid feature attributes in {xml_filename}. Skipping.")
                    continue

                if not source_reference or this_length <= 0 or source_length <= 0 or this_offset < 0 or source_offset < 0:
                    print(f"Skipping invalid feature in {xml_filename}")
                    continue

                file_paths = create_folder_and_return_paths(folder_index, document_ref, this_offset, this_length, source_reference, source_offset, source_length)

                if file_paths:
                    futures = []
                    futures.append(executor.submit(copy_file, file_paths["eng_suspicious"], file_paths["output_folder"]))
                    futures.append(executor.submit(copy_file, file_paths["kaz_suspicious"], file_paths["output_folder"]))
                    futures.append(executor.submit(copy_file, file_paths["eng_source"], file_paths["output_folder"]))
                    futures.append(executor.submit(copy_file, file_paths["kaz_source"], file_paths["output_folder"]))

                    # Wait for all futures to complete
                    for future in as_completed(futures):
                        if not future.result():
                            print(f"File missing or failed to copy for folder {file_paths['output_folder']}")

                    print(f"Completed folder: {file_paths['output_folder']}")  # Added print statement to confirm folder completion

                folder_index += 1

        except Exception as e:
            print(f"Error processing file {xml_filename}: {e}")

print("Processing completed.")

# %% [markdown]
# Then we saved all plagiarised pairs of text in csv format

# %%
import os
import pandas as pd

# Define the base directory
base_dir = "/content/drive/MyDrive/updating-pan-xml-files/su1so1-plagiarised-english-and-kazakh-suspicious-and-source-matched-texts-1"

# Initialize a list to store data
data = []

# Iterate over subfolders
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)

    if os.path.isdir(subfolder_path):
        # Extract the core suspicious document identifier
        subfolder_name_parts = subfolder.split("-")
        if len(subfolder_name_parts) >= 2:
            suspicious_doc_id = subfolder_name_parts[0]  # Extract suspicious-document00001 part
        else:
            continue  # Skip if format is unexpected

        # Initialize variables for file content and names
        eng_source_text = eng_suspicious_text = kz_source_text = kz_suspicious_text = ""
        eng_suspicious_filename = eng_source_filename = ""

        # Iterate over files in the subfolder
        for file_name in os.listdir(subfolder_path):
            file_path = os.path.join(subfolder_path, file_name)
            if os.path.isfile(file_path):
                try:
                    with open(file_path, "r", encoding="utf-8") as f:
                        text = f.read().strip()

                    if file_name.startswith("source-document"):
                        eng_source_text = text
                        eng_source_filename = file_name
                    elif file_name.startswith("suspicious-document"):
                        eng_suspicious_text = text
                        eng_suspicious_filename = file_name
                    elif file_name.startswith("kz-source-document"):
                        kz_source_text = text
                    elif file_name.startswith("kz-suspicious-document"):
                        kz_suspicious_text = text
                except Exception as e:
                    print(f"Error reading file {file_path}: {e}")

        # Append the extracted data to the list
        data.append([
            eng_source_text, eng_suspicious_text, kz_source_text, kz_suspicious_text,
            1, eng_suspicious_filename, eng_source_filename, suspicious_doc_id
        ])

# Create a DataFrame
df = pd.DataFrame(data, columns=[
    "english_source_text", "english_suspicious_text", "kazakh_source_text",
    "kazakh_suspicious_text", "label", "english_suspicious_filename",
    "english_source_filename", "subfolder_name"
])

# Define output CSV file path
output_csv_path = "/content/drive/MyDrive/updating-pan-xml-files/su1so1_matched_texts.csv"

# Save DataFrame to CSV
df.to_csv(output_csv_path, index=False, encoding="utf-8")

# Display DataFrame
import ace_tools as tools
tools.display_dataframe_to_user(name="Matched Texts Dataset", dataframe=df)

# %%
import os
import pandas as pd

# Define the base directory
base_dir = "/content/drive/MyDrive/updating-pan-xml-files/su1so1-plagiarised-english-and-kazakh-suspicious-and-source-matched-texts-1"
output_csv = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised_texts_dataset.csv"

# Initialize a list to store data
data = []

# Iterate over subfolders
for subfolder in os.listdir(base_dir):
    subfolder_path = os.path.join(base_dir, subfolder)

    if os.path.isdir(subfolder_path):  # Check if it's a directory
        # Identify file paths
        eng_source_file = None
        eng_suspicious_file = None
        kz_source_file = None
        kz_suspicious_file = None

        for filename in os.listdir(subfolder_path):
            file_path = os.path.join(subfolder_path, filename)

            if filename.startswith("source-document") and not filename.startswith("kz-"):
                eng_source_file = file_path
            elif filename.startswith("suspicious-document") and not filename.startswith("kz-"):
                eng_suspicious_file = file_path
            elif filename.startswith("kz-source-document"):
                kz_source_file = file_path
            elif filename.startswith("kz-suspicious-document"):
                kz_suspicious_file = file_path

        # Ensure all required files exist
        if eng_source_file and eng_suspicious_file and kz_source_file and kz_suspicious_file:
            try:
                with open(eng_source_file, "r", encoding="utf-8") as f:
                    eng_source_text = f.read().strip()

                with open(eng_suspicious_file, "r", encoding="utf-8") as f:
                    eng_suspicious_text = f.read().strip()

                with open(kz_source_file, "r", encoding="utf-8") as f:
                    kz_source_text = f.read().strip()

                with open(kz_suspicious_file, "r", encoding="utf-8") as f:
                    kz_suspicious_text = f.read().strip()

                # Extract file names and subfolder info
                eng_suspicious_filename = os.path.basename(eng_suspicious_file)
                eng_source_filename = os.path.basename(eng_source_file)
                subfolder_name = subfolder.split("-")[0]  # Extract "suspicious-documentXXXX"

                # Append to dataset list
                data.append([
                    eng_source_text, eng_suspicious_text,
                    kz_source_text, kz_suspicious_text,
                    1,  # Label = 1 (Plagiarized)
                    eng_suspicious_filename, eng_source_filename,
                    subfolder_name
                ])
            except Exception as e:
                print(f"Error reading files in {subfolder}: {e}")

# Create a DataFrame and save to CSV
df = pd.DataFrame(data, columns=[
    "english_source_text", "english_suspicious_text",
    "kazakh_source_text", "kazakh_suspicious_text",
    "label", "english_suspicious_filename", "english_source_filename",
    "subfolder_name"
])

df.to_csv(output_csv, index=False, encoding="utf-8")

print(f"✅ Dataset successfully created and saved to {output_csv}")

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised_texts_dataset.csv"

# Load the dataset (only the first row to improve performance)
df = pd.read_csv(dataset_path, nrows=0)

# Get the column names
column_names = df.columns.tolist()

# Print the column names
print("Column Names:", column_names)
# Out:
# Column Names: ['english_source_text', 'english_suspicious_text', 'kazakh_source_text', 'kazakh_suspicious_text', 'label', 'english_suspicious_filename', 'english_source_filename', 'subfolder_name']

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised_texts_dataset.csv"

# Load the dataset
df = pd.read_csv(dataset_path)

# Get the first three rows
first_three_rows = df.head(3)

# Print each row on a new line
for index, row in first_three_rows.iterrows():
    print(f"Row {index + 1}:\n{row.to_string(index=False)}\n{'-'*80}")
# Out:
# Row 1:
# . These provisions, whatever the opinion\nenter...
# the These provisions, whatever the opinion ente...
# Бұл ережелер, мұндай заңдардың даналығына қатыс...
# Бұл ережелер, мұндай жинақтың даналығына қатыст...
#                                                  1
#             suspicious-document00001-1269-4699.txt
#                  source-document07076-422-3872.txt
#                                         suspicious
# --------------------------------------------------------------------------------
# Row 2:
# . And being come to her\nHouse, (to find which ...
# And being come to House, (to find which she of ...
# Оның үйіне келгенде (ол бұрын оған нұсқау берге...
# Үйге келгенде (ол оның нұсқау бергенін білу үші...
#                                                  1
#           suspicious-document08204-21799-22043.txt
#                 source-document09029-2918-3164.txt
#                                         suspicious
# --------------------------------------------------------------------------------
# Row 3:
# . "I must hear none of this. If\ntwo people who...
# "i must hear none of\nthe. As two people who oc...
# «Мен мұның ешқайсысын естуім керек емес. Егер б...
# «Мен ешқайсысын естімеуім керек. Мен онымен пац...
#                                                  1
#           suspicious-document08204-24264-24521.txt
#           source-document01390-1465265-1465524.txt
#                                         suspicious
# --------------------------------------------------------------------------------

# %%
import pandas as pd

dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised_texts_dataset.csv"
df = pd.read_csv(dataset_path)

# Count label distribution
label_counts = df['label'].value_counts()
print("Label Distribution:\n", label_counts)
# Out:
# Label Distribution:
#  label
# 1    38999
# Name: count, dtype: int64

# %% [markdown]
# **Human Evaluation Set:**
# In addition, we prepared a set of **2,000 English–Kazakh text pairs** specifically for **native Kazakh speakers** to evaluate the **quality of plagiarism detection** and the **accuracy of Kazakh translations**. This dataset supports human assessment of the alignment between original and translated texts in the context of plagiarism:

# %%
import os
import shutil
from concurrent.futures import ThreadPoolExecutor

# Define the main folder and the destination folder
main_folder = "/content/drive/MyDrive/updating-pan-xml-files/su1so1-plagiarised-english-and-kazakh-suspicious-and-source-matched-texts-1"
destination_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/kz-eng-1500-similar-files"

# Create the destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Function to calculate the size of a folder
def get_folder_size(folder_path):
    try:
        return sum(
            os.path.getsize(os.path.join(dirpath, filename))
            for dirpath, _, filenames in os.walk(folder_path)
            for filename in filenames
        )
    except Exception as e:
        print(f"Error calculating size for {folder_path}: {e}")
        return 0

# Function to copy a folder
def copy_folder(src, dest):
    try:
        shutil.copytree(src, dest)
        print(f"Copied subfolder: {os.path.basename(src)}")
    except Exception as e:
        print(f"Error copying {src} to {dest}: {e}")

# List all subfolders in the main folder
subfolders = [
    os.path.join(main_folder, subfolder)
    for subfolder in os.listdir(main_folder)
    if os.path.isdir(os.path.join(main_folder, subfolder))
]

# Calculate folder sizes in parallel
print("Calculating folder sizes...")
with ThreadPoolExecutor(max_workers=8) as executor:
    subfolder_sizes = list(executor.map(get_folder_size, subfolders))

# Pair subfolders with their sizes
subfolder_sizes = list(zip(subfolders, subfolder_sizes))

# Sort subfolders by size in ascending order
print("Sorting subfolders by size...")
subfolder_sizes.sort(key=lambda x: x[1])

# Select the first 1500 least sized subfolders
least_sized_subfolders = subfolder_sizes[:1500]

# Copy the selected subfolders in parallel
print("Copying subfolders...")
with ThreadPoolExecutor(max_workers=4) as executor:
    futures = [
        executor.submit(
            copy_folder,
            subfolder,
            os.path.join(destination_folder, os.path.basename(subfolder))
        )
        for subfolder, _ in least_sized_subfolders
    ]
    for future in futures:
        future.result()

print("Process completed. First 1500 least sized subfolders have been copied.")

# %% [markdown]
# **Human Evaluation Setup:**
# We divided the **2,000 English–Kazakh text pairs** among native Kazakh speakers in such a way that **each evaluator received an equal number of plagiarised and non-plagiarised text pairs**, along with their **Kazakh translations**. The dataset was also **shuffled** to prevent evaluators from predicting the labels based on the order or position of the text pairs, ensuring a fair and unbiased evaluation process:

# %%
import os
import shutil

# Define directories
source_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/kz-eng-1500-similar-files"
destination_base = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/sorted-by-obfuscation"

# Create destination subfolders
obfuscation_folders = {
    "high": os.path.join(destination_base, "obfuscation-high"),
    "low": os.path.join(destination_base, "obfuscation-low"),
    "none": os.path.join(destination_base, "obfuscation-none"),
    "absent": os.path.join(destination_base, "obfuscation-absent")
}

for folder in obfuscation_folders.values():
    os.makedirs(folder, exist_ok=True)

# Counters
obfuscation_counts = {
    "high": 0,
    "low": 0,
    "none": 0,
    "absent": 0
}

# Process each subfolder
subfolders = [
    os.path.join(source_folder, subfolder)
    for subfolder in os.listdir(source_folder)
    if os.path.isdir(os.path.join(source_folder, subfolder))
]

for subfolder in subfolders:
    try:
        plagiarism_info_path = os.path.join(subfolder, "plagiarism_info.txt")

        if not os.path.isfile(plagiarism_info_path):
            print(f"plagiarism_info.txt not found in {subfolder}. Skipping.")
            continue

        # Read the file
        with open(plagiarism_info_path, "r", encoding="utf-8") as f:
            content = f.read()

        # Determine obfuscation level
        if "obfuscation: high" in content:
            category = "high"
        elif "obfuscation: low" in content:
            category = "low"
        elif "obfuscation: none" in content:
            category = "none"
        else:
            category = "absent"

        # Copy the subfolder to the appropriate destination
        destination_subfolder = os.path.join(obfuscation_folders[category], os.path.basename(subfolder))
        shutil.copytree(subfolder, destination_subfolder)

        # Increment counter
        obfuscation_counts[category] += 1
        print(f"Copied {subfolder} to {destination_subfolder} (category: {category})")

    except Exception as e:
        print(f"Error processing {subfolder}: {e}")

# Print summary
print("\nSummary:")
print(f"Obfuscation High: {obfuscation_counts['high']}")
print(f"Obfuscation Low: {obfuscation_counts['low']}")
print(f"Obfuscation None: {obfuscation_counts['none']}")
print(f"Obfuscation Absent: {obfuscation_counts['absent']}")

# %%
import os
import shutil

# Define source folders
obfuscation_high_folder = "/content/drive/MyDrive/obfuscation-high"
obfuscation_low_folder = "/content/drive/MyDrive/obfuscation-low"
obfuscation_none_folder = "/content/drive/MyDrive/obfuscation-none"
obfuscation_absent_folder = "/content/drive/MyDrive/obfuscation-absent"
not_similar_folder = "/content/drive/MyDrive/not-similar"

# Define destination base folder
output_base_folder = "/content/drive/MyDrive/distributed-folders"
os.makedirs(output_base_folder, exist_ok=True)

# Create 10 output folders
output_folders = [os.path.join(output_base_folder, f"folder-{i+1}") for i in range(10)]
for folder in output_folders:
    os.makedirs(folder, exist_ok=True)

# Collect subfolders from each source folder
subfolders_high = [os.path.join(obfuscation_high_folder, f) for f in os.listdir(obfuscation_high_folder) if os.path.isdir(os.path.join(obfuscation_high_folder, f))]
subfolders_low = [os.path.join(obfuscation_low_folder, f) for f in os.listdir(obfuscation_low_folder) if os.path.isdir(os.path.join(obfuscation_low_folder, f))]
subfolders_none = [os.path.join(obfuscation_none_folder, f) for f in os.listdir(obfuscation_none_folder) if os.path.isdir(os.path.join(obfuscation_none_folder, f))]
subfolders_absent = [os.path.join(obfuscation_absent_folder, f) for f in os.listdir(obfuscation_absent_folder) if os.path.isdir(os.path.join(obfuscation_absent_folder, f))]
subfolders_not_similar = [os.path.join(not_similar_folder, f) for f in os.listdir(not_similar_folder) if os.path.isdir(os.path.join(not_similar_folder, f))]

# Combine all subfolders in the specified order
all_subfolders = []
while any([subfolders_high, subfolders_low, subfolders_none, subfolders_absent, subfolders_not_similar]):
    if subfolders_high:
        all_subfolders.append(subfolders_high.pop(0))
    if subfolders_low:
        all_subfolders.append(subfolders_low.pop(0))
    if subfolders_none:
        all_subfolders.append(subfolders_none.pop(0))
    if subfolders_absent:
        all_subfolders.append(subfolders_absent.pop(0))
    if subfolders_not_similar:
        all_subfolders.append(subfolders_not_similar.pop(0))

# Distribute subfolders equally into 10 folders
folder_index = 0
for subfolder in all_subfolders:
    destination_folder = output_folders[folder_index]
    destination_subfolder = os.path.join(destination_folder, os.path.basename(subfolder))
    shutil.copytree(subfolder, destination_subfolder)
    print(f"Copied {subfolder} to {destination_folder}")
    folder_index = (folder_index + 1) % 10

print("Distribution completed.")

# %%
import os
import shutil

# Define source folders
obfuscation_high_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-high-365"
obfuscation_low_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-low-365"
obfuscation_none_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-none-365"
obfuscation_absent_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-absent-365"
not_similar_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/not-similar-365"

# Define destination base folder
output_base_folder = "/content/drive/MyDrive/experimental-models/1820-tasks-to-10-people"
os.makedirs(output_base_folder, exist_ok=True)

# Create 10 output folders
output_folders = [os.path.join(output_base_folder, f"folder-{i+1}") for i in range(10)]
for folder in output_folders:
    os.makedirs(folder, exist_ok=True)

# Create example folder for the last 5 subfolders
example_folder = os.path.join(output_base_folder, "example")
os.makedirs(example_folder, exist_ok=True)

# Log file path
log_file_path = os.path.join(output_base_folder, "shared_subfolders_log.txt")

# Initialize log file
with open(log_file_path, "w", encoding="utf-8") as log_file:
    log_file.write("Shared Subfolders Log\n")
    log_file.write("=" * 50 + "\n")

# Collect subfolders from each source folder
subfolders_high = [os.path.join(obfuscation_high_folder, f) for f in os.listdir(obfuscation_high_folder) if os.path.isdir(os.path.join(obfuscation_high_folder, f))]
subfolders_low = [os.path.join(obfuscation_low_folder, f) for f in os.listdir(obfuscation_low_folder) if os.path.isdir(os.path.join(obfuscation_low_folder, f))]
subfolders_none = [os.path.join(obfuscation_none_folder, f) for f in os.listdir(obfuscation_none_folder) if os.path.isdir(os.path.join(obfuscation_none_folder, f))]
subfolders_absent = [os.path.join(obfuscation_absent_folder, f) for f in os.listdir(obfuscation_absent_folder) if os.path.isdir(os.path.join(obfuscation_absent_folder, f))]
subfolders_not_similar = [os.path.join(not_similar_folder, f) for f in os.listdir(not_similar_folder) if os.path.isdir(os.path.join(not_similar_folder, f))]

# Set to track used subfolders
used_subfolders = set()

# Combine all subfolders in the specified order
all_subfolders = []
while any([subfolders_high, subfolders_low, subfolders_none, subfolders_absent, subfolders_not_similar]):
    if subfolders_high:
        subfolder = subfolders_high.pop(0)
        if subfolder not in used_subfolders:
            all_subfolders.append(subfolder)
            used_subfolders.add(subfolder)
    if subfolders_low:
        subfolder = subfolders_low.pop(0)
        if subfolder not in used_subfolders:
            all_subfolders.append(subfolder)
            used_subfolders.add(subfolder)
    if subfolders_none:
        subfolder = subfolders_none.pop(0)
        if subfolder not in used_subfolders:
            all_subfolders.append(subfolder)
            used_subfolders.add(subfolder)
    if subfolders_absent:
        subfolder = subfolders_absent.pop(0)
        if subfolder not in used_subfolders:
            all_subfolders.append(subfolder)
            used_subfolders.add(subfolder)
    if subfolders_not_similar:
        subfolder = subfolders_not_similar.pop(0)
        if subfolder not in used_subfolders:
            all_subfolders.append(subfolder)
            used_subfolders.add(subfolder)

# Distribute first 1800 subfolders equally into 10 folders
print("Distributing the first 1800 subfolders...")
folder_index = 0
for subfolder in all_subfolders[:1800]:
    destination_folder = output_folders[folder_index]
    destination_subfolder = os.path.join(destination_folder, os.path.basename(subfolder))
    shutil.copytree(subfolder, destination_subfolder)
    with open(log_file_path, "a", encoding="utf-8") as log_file:
        log_file.write(f"Copied to {destination_folder}: {subfolder}\n")
    print(f"Copied {subfolder} to {destination_folder}")
    folder_index = (folder_index + 1) % 10

# Prepare remaining 25 subfolders
remaining_subfolders = all_subfolders[1800:]

# Separate 20 shared subfolders
shared_subfolders = remaining_subfolders[:20]

# Add 20 shared subfolders to all 10 folders
print("Adding 20 shared subfolders to each folder...")
for subfolder in shared_subfolders:
    for destination_folder in output_folders:
        destination_subfolder = os.path.join(destination_folder, os.path.basename(subfolder))
        shutil.copytree(subfolder, destination_subfolder)
        with open(log_file_path, "a", encoding="utf-8") as log_file:
            log_file.write(f"Shared with {destination_folder}: {subfolder}\n")
        print(f"Shared {subfolder} with {destination_folder}")

# Add the last 5 subfolders to the "example" folder
print("Saving the last 5 subfolders to the example folder...")
for subfolder in remaining_subfolders[20:]:
    destination_subfolder = os.path.join(example_folder, os.path.basename(subfolder))
    shutil.copytree(subfolder, destination_subfolder)
    with open(log_file_path, "a", encoding="utf-8") as log_file:
        log_file.write(f"Saved to example folder: {subfolder}\n")
    print(f"Saved {subfolder} to example folder")

print("Final distribution completed.")

# %%
import os
import shutil
from math import floor

# Define source folders
obfuscation_high_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-high-365"
obfuscation_low_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-low-365"
obfuscation_none_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-none-365"
obfuscation_absent_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/obfuscation-absent-365"
not_similar_folder = "/content/drive/MyDrive/experimental-models/kz-eng-1500-matched-files/3000-files-with-obfuscation/not-similar-365"

# Define destination base folder
output_base_folder = "/content/drive/MyDrive/experimental-models/distribution-200-tasks-to-10-people"
os.makedirs(output_base_folder, exist_ok=True)

# Create 10 output folders
output_folders = [os.path.join(output_base_folder, f"folder-{i+1}") for i in range(10)]
for folder in output_folders:
    os.makedirs(folder, exist_ok=True)

# Create folders for shared subfolders and example
shared_folder = os.path.join(output_base_folder, "20-shared-matched-folders")
os.makedirs(shared_folder, exist_ok=True)
example_folder = os.path.join(output_base_folder, "example")
os.makedirs(example_folder, exist_ok=True)

# Log file path
log_file_path = os.path.join(output_base_folder, "shared_subfolders_log.txt")

# Initialize log file
with open(log_file_path, "w", encoding="utf-8") as log_file:
    log_file.write("Shared Subfolders Log\n")
    log_file.write("=" * 50 + "\n")

# Collect subfolders from each source folder
subfolders_high = [os.path.join(obfuscation_high_folder, f) for f in os.listdir(obfuscation_high_folder) if os.path.isdir(os.path.join(obfuscation_high_folder, f))]
subfolders_low = [os.path.join(obfuscation_low_folder, f) for f in os.listdir(obfuscation_low_folder) if os.path.isdir(os.path.join(obfuscation_low_folder, f))]
subfolders_none = [os.path.join(obfuscation_none_folder, f) for f in os.listdir(obfuscation_none_folder) if os.path.isdir(os.path.join(obfuscation_none_folder, f))]
subfolders_absent = [os.path.join(obfuscation_absent_folder, f) for f in os.listdir(obfuscation_absent_folder) if os.path.isdir(os.path.join(obfuscation_absent_folder, f))]
subfolders_not_similar = [os.path.join(not_similar_folder, f) for f in os.listdir(not_similar_folder) if os.path.isdir(os.path.join(not_similar_folder, f))]

# Ensure equal distribution
num_folders = 10
subfolders_per_type = floor(180 / 5)  # 36 subfolders of each type per folder

# Function to copy subfolders evenly
remaining_subfolders = []
def distribute_subfolders(subfolders, folder_index):
    distributed = []
    for _ in range(subfolders_per_type):
        if subfolders:
            subfolder = subfolders.pop(0)
            destination_folder = output_folders[folder_index % num_folders]
            destination_subfolder = os.path.join(destination_folder, os.path.basename(subfolder))
            shutil.copytree(subfolder, destination_subfolder)
            distributed.append(subfolder)
            folder_index += 1
    return folder_index, distributed

# Distribute 1800 unique subfolders
folder_index = 0
for subfolder_group in [subfolders_high, subfolders_low, subfolders_none, subfolders_absent, subfolders_not_similar]:
    folder_index, distributed = distribute_subfolders(subfolder_group, folder_index)
    remaining_subfolders.extend(distributed)

# Distribute 20 shared subfolders equally
shared_subfolders = []
for _ in range(4):
    for subfolder_group in [subfolders_high, subfolders_low, subfolders_none, subfolders_absent, subfolders_not_similar]:
        if subfolder_group:
            subfolder = subfolder_group.pop(0)
            shared_subfolders.append(subfolder)
            shared_destination = os.path.join(shared_folder, os.path.basename(subfolder))
            shutil.copytree(subfolder, shared_destination)

# Copy shared subfolders to all 10 folders
for subfolder in shared_subfolders:
    for destination_folder in output_folders:
        destination_subfolder = os.path.join(destination_folder, os.path.basename(subfolder))
        shutil.copytree(subfolder, destination_subfolder)
        with open(log_file_path, "a", encoding="utf-8") as log_file:
            log_file.write(f"Shared with {destination_folder}: {subfolder}\n")

# Save last 5 subfolders to the "example" folder
last_subfolders = subfolders_high + subfolders_low + subfolders_none + subfolders_absent + subfolders_not_similar
for subfolder in last_subfolders[:5]:
    destination_subfolder = os.path.join(example_folder, os.path.basename(subfolder))
    shutil.copytree(subfolder, destination_subfolder)
    with open(log_file_path, "a", encoding="utf-8") as log_file:
        log_file.write(f"Saved to example folder: {subfolder}\n")

print("Final distribution completed.")

# %% [markdown]
# Shuffling all prepared evaluation text for Kazakh speakers

# %%
import os
import random

# Define folders
folder1_path = "/content/drive/MyDrive/experimental-models/200-tasks-for-10/folder-1"
matched_folders_path = "/content/drive/MyDrive/experimental-models/200-tasks-for-10/20-matched-folders"

# Define the obfuscation groups
primary_group = ["obfuscation-high", "obfuscation-low"]
secondary_group = ["obfuscation-none", "obfuscation-absent"]
other_group = ["not-similar"]

# Helper function to determine obfuscation type from plagiarism_info.txt
def get_obfuscation_type(subfolder_path):
    info_file_path = os.path.join(subfolder_path, "plagiarism_info.txt")
    if os.path.isfile(info_file_path):
        try:
            with open(info_file_path, "r", encoding="utf-8") as f:
                lines = f.readlines()
            obfuscation_line = next((line for line in lines if line.startswith("obfuscation:")), None)
            if obfuscation_line:
                if "high" in obfuscation_line:
                    return "obfuscation-high"
                elif "low" in obfuscation_line:
                    return "obfuscation-low"
                elif "none" in obfuscation_line:
                    return "obfuscation-none"
            else:
                return "obfuscation-absent"
        except Exception as e:
            print(f"Error reading {info_file_path}: {e}")
    return "not-similar"

# Collect subfolder names
folder1_subfolders = [f for f in os.listdir(folder1_path) if os.path.isdir(os.path.join(folder1_path, f))]
matched_subfolders = [f for f in os.listdir(matched_folders_path) if os.path.isdir(os.path.join(matched_folders_path, f))]
matched_set = set(matched_subfolders)

# Classify subfolders by obfuscation type
classified_subfolders = {
    "obfuscation-high": [],
    "obfuscation-low": [],
    "obfuscation-none": [],
    "obfuscation-absent": [],
    "not-similar": []
}

for subfolder in folder1_subfolders:
    subfolder_path = os.path.join(folder1_path, subfolder)
    obfuscation_type = get_obfuscation_type(subfolder_path)
    classified_subfolders[obfuscation_type].append(subfolder)

# Initialize counters and renaming logic
regular_index = 1
remaining_index = 181
unprocessed_subfolders = []

# Process folder1 subfolders based on the dynamically shuffled sequence
while any(classified_subfolders.values()):
    sequence = [primary_group, secondary_group, other_group]
    random.shuffle(sequence)  # Shuffle the sequence dynamically for each iteration

    for group in sequence:
        random.shuffle(group)  # Shuffle the group order dynamically
        for obfuscation_type in group:
            if classified_subfolders[obfuscation_type]:
                subfolder = classified_subfolders[obfuscation_type].pop(0)
                if subfolder in matched_set:
                    unprocessed_subfolders.append(subfolder)
                else:
                    subfolder_path = os.path.join(folder1_path, subfolder)
                    new_name = f"{regular_index}-{subfolder}"
                    new_path = os.path.join(folder1_path, new_name)
                    os.rename(subfolder_path, new_path)
                    print(f"Renamed: {subfolder} -> {new_name}")
                    regular_index += 1

# Shuffle the remaining matched subfolders for each iteration
while unprocessed_subfolders:
    random.shuffle(unprocessed_subfolders)
    for subfolder in unprocessed_subfolders[:]:
        subfolder_path = os.path.join(folder1_path, subfolder)
        new_name = f"{remaining_index}-{subfolder}"
        new_path = os.path.join(folder1_path, new_name)
        os.rename(subfolder_path, new_path)
        print(f"Renamed: {subfolder} -> {new_name}")
        remaining_index += 1
        unprocessed_subfolders.remove(subfolder)

print("Processing completed.")

# %% [markdown]
# Based on the evaluation of 2000 plagiarised and not plagiarised Kazakh texts by Kazakh speakers we create a small 2000 CSV dataset.

# %%
import os
import pandas as pd

# Define the base folder path
base_folder = "/content/drive/MyDrive/experimental-models/200-tasks-for-10"
output_csv = "/content/drive/MyDrive/bert_training_dataset_numeric_labels_cleaned.csv"

# Function to clean text
def clean_text(text):
    text = text.strip()  # Remove leading/trailing spaces
    text = text.lstrip(".").lstrip()  # Remove leading dots, then any spaces again
    text = " ".join(text.split())  # Normalize all sequences of spaces to a single space
    return text

# Initialize an empty list to store dataset rows
dataset = []

# Iterate over the 10 subfolders (folder-1 to folder-10)
for folder_name in os.listdir(base_folder):
    folder_path = os.path.join(base_folder, folder_name)

    if os.path.isdir(folder_path):
        # Iterate over the 200 sub-subfolders
        for subfolder_name in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder_name)

            if os.path.isdir(subfolder_path):
                # Check for the existence of plagiarism_info.txt
                info_file_path = os.path.join(subfolder_path, "plagiarism_info.txt")
                label = 1 if os.path.isfile(info_file_path) else 0

                # Locate source and suspicious document files
                source_file = None
                suspicious_file = None

                for file_name in os.listdir(subfolder_path):
                    if file_name.startswith("source-document"):
                        source_file = os.path.join(subfolder_path, file_name)
                    elif file_name.startswith("suspicious-document"):
                        suspicious_file = os.path.join(subfolder_path, file_name)

                # Ensure both source and suspicious files exist
                if source_file and suspicious_file:
                    try:
                        # Read the content of the source and suspicious documents
                        with open(source_file, "r", encoding="utf-8") as src:
                            source_text = clean_text(src.read())
                        with open(suspicious_file, "r", encoding="utf-8") as susp:
                            suspicious_text = clean_text(susp.read())

                        # Append the data to the dataset
                        dataset.append({
                            "source_text": source_text,
                            "suspicious_text": suspicious_text,
                            "label": label
                        })
                    except Exception as e:
                        print(f"Error reading files in {subfolder_path}: {e}")

# Create a DataFrame and remove duplicate rows
df = pd.DataFrame(dataset)
df = df.drop_duplicates()  # Remove duplicate rows

# Save the cleaned dataset to CSV
df.to_csv(output_csv, index=False, encoding="utf-8")

print(f"Cleaned dataset created successfully and saved to {output_csv}")

# %% [markdown]
# **Model Training on Small Dataset:**
# Using the small dataset of **2,000 English–Kazakh text pairs**, we trained two separate BERT-based models for comparison purposes. Specifically:
# - An **English BERT model** was trained on the English portion of the dataset.
# - A **Kazakh BERT model** was trained on the Kazakh translations of the same pairs.
#
# This setup allowed us to assess the performance of language-specific models on a controlled and aligned dataset.

# %%
from datasets import load_dataset
from google.colab import drive
from transformers import TrainingArguments, Trainer, BertTokenizer, BertForSequenceClassification
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# Mount Google Drive
googledrive = "/content/drive"
drive.mount(googledrive)

# Load dataset
dataset = load_dataset('csv', data_files='/content/drive/MyDrive/bert_training_dataset_numeric_labels_cleaned3.csv')

# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenization function
def tokenize_function(examples):
    # Combine source and suspicious texts with a separator
    combined_texts = [s + " [SEP] " + t for s, t in zip(examples['source_text'], examples['suspicious_text'])]
    return tokenizer(combined_texts, padding="max_length", truncation=True)

# Tokenize dataset
tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Add labels to the tokenized dataset
tokenized_datasets = tokenized_datasets.rename_column("label", "labels")

# Split the dataset into training and testing sets
tokenized_datasets = tokenized_datasets['train'].train_test_split(test_size=0.2)

# Initialize model for binary classification
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Define compute_metrics function
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# Define training arguments
training_args = TrainingArguments(
    output_dir='/content/drive/MyDrive/bert-training/results',  # Directory in Google Drive
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='/content/drive/MyDrive/bert-training/logs',  # Log directory
    save_strategy='epoch',  # Save the model after every epoch
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    compute_metrics=compute_metrics,
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()
print("Evaluation Results:", results)

# Save the model and tokenizer
model.save_pretrained('/content/drive/MyDrive/bert-training/saved_model')
tokenizer.save_pretrained('/content/drive/MyDrive/bert-training/saved_model')

# %% [markdown]
# **Generating Negative Samples (Label=0) for the Large Dataset:**
# Our large dataset initially consisted only of **positive examples (label = 1)**—pairs of texts that are similar or plagiarized. To generate **negative examples (label = 0)**, we utilized the **BERT models trained on the small aligned English–Kazakh dataset**.
#
# These trained models were used to evaluate text pairs within the large dataset and identify those that are **dissimilar**. By assigning label = 0 to such pairs, we augmented the dataset with **non-plagiarized examples**, ultimately balancing the dataset for training purposes.

# %%
import pandas as pd
import torch
import re
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import csv

# ✅ Load BERT model & tokenizer
model_path = "/content/drive/MyDrive/bert-training/saved_model"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)
model.eval().to("cuda" if torch.cuda.is_available() else "cpu")

# ✅ Load dataset
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/plagiarised_texts_dataset.csv"
df = pd.read_csv(dataset_path)

# ✅ Set to track already used negative samples
used_negatives = set()

# ✅ Output file path
output_path = "/content/drive/MyDrive/updating-pan-xml-files/en_kz_plagiarism_dataset_balanced1.csv"

# ✅ Define CSV headers
headers = ["english_source_text", "english_suspicious_text", "kazakh_source_text", "kazakh_suspicious_text", "label"]

# ✅ Write headers to file (overwrite mode)
with open(output_path, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(headers)  # Write column headers

# ✅ Text preprocessing function
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Function to classify similarity using BERT
def classify_plagiarism(text1, text2):
    inputs = tokenizer(f"{text1} {tokenizer.sep_token} {text2}",
                       padding="max_length", truncation=True, max_length=512, return_tensors="pt").to("cuda")
    with torch.no_grad():
        outputs = model(**inputs)
        prediction = torch.argmax(outputs.logits, dim=-1).item()
    return prediction  # 1 = Plagiarized, 0 = Not Plagiarized

# ✅ Process dataset row by row
for i in range(len(df)):
    # ✅ Process source texts
    source_text_en = clean_text(df.loc[i, "english_source_text"])
    source_text_kz = df.loc[i, "kazakh_source_text"]

    # ✅ Copy **original positive pairs (label = 1)**
    suspicious_text_en = clean_text(df.loc[i, "english_suspicious_text"])
    suspicious_text_kz = df.loc[i, "kazakh_suspicious_text"]

    # ✅ Append positive sample to CSV
    with open(output_path, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow([source_text_en, suspicious_text_en, source_text_kz, suspicious_text_kz, 1])

    # ✅ 2️⃣ **Find a single unique negative sample**
    source_length = df.loc[i, "english_source_text_length"]
    found_negative = False

    # ✅ Try different word length differences: 0 → 1 → 2 → 3 → 4 → 5
    for length_diff in range(6):
        potential_neg_sample = df.query(
            "(index != @i) & (abs(english_source_text_length - english_suspicious_text_length) <= @length_diff)"
        )

        # ✅ If a candidate is found, break out of the loop
        if not potential_neg_sample.empty:
            neg_row = potential_neg_sample.iloc[0]  # ✅ Pick the first candidate
            neg_suspicious_text_en = clean_text(neg_row["english_suspicious_text"])
            neg_suspicious_text_kz = neg_row["kazakh_suspicious_text"]

            # **Avoid reusing negative samples**
            pair_key = (source_text_en, neg_suspicious_text_en)
            if pair_key in used_negatives:
                continue  # ✅ Skip if already used

            # ✅ Mark as used
            used_negatives.add(pair_key)

            # ✅ Predict label with BERT
            label = classify_plagiarism(source_text_en, neg_suspicious_text_en)

            # ✅ Only add if BERT says it's NOT plagiarized (label=0)
            if label == 0:
                with open(output_path, "a", newline="", encoding="utf-8") as f:
                    writer = csv.writer(f)
                    writer.writerow([source_text_en, neg_suspicious_text_en, source_text_kz, neg_suspicious_text_kz, 0])
                found_negative = True
            break  # ✅ Stop searching once we find a valid negative

    # ✅ If no valid negative is found after checking all length differences, skip

print(f"✅ New balanced dataset saved: {output_path}")

# %% [markdown]
# Removing duplicates if they exist

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_kz_plagiarism_dataset_balanced1.csv"
output_path = "/content/drive/MyDrive/updating-pan-xml-files/en_kz_pan_paragraph_texts_balanced_unique.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function to normalize text for comparison
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text.lower()  # Convert to lowercase for better duplicate detection

# ✅ Apply cleaning to all text columns
df["english_source_text"] = df["english_source_text"].apply(clean_text)
df["english_suspicious_text"] = df["english_suspicious_text"].apply(clean_text)
df["kazakh_source_text"] = df["kazakh_source_text"].apply(clean_text)
df["kazakh_suspicious_text"] = df["kazakh_suspicious_text"].apply(clean_text)

# ✅ Remove duplicate rows
df_unique = df.drop_duplicates()

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_kz_pan_paragraph_texts_balanced_unique.csv"
output_path = "/content/drive/MyDrive/updating-pan-xml-files/en_kz_plagiarised_texts_labelled.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only English texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["english_source_text"] = df["english_source_text"].apply(clean_text)
df["english_suspicious_text"] = df["english_suspicious_text"].apply(clean_text)

# ✅ Remove duplicates **based only on English source & suspicious text pairs**
df_unique = df.drop_duplicates(subset=["english_source_text", "english_suspicious_text"])

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")

# %% [markdown]
# From our previous english-kazakh dataset separating them and creating two separate datasets English and Kazakh

# %%
import pandas as pd

# Load the original dataset
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_kz_pan_unique_paragraph_texts_with_balanced_labels3.csv"
df = pd.read_csv(dataset_path)

# ✅ Create English dataset
english_df = df[['english_source_text', 'english_suspicious_text', 'label']]
english_output_path = "/content/drive/MyDrive/updating-pan-xml-files/en_plagiarism_dataset_60000_paragraphs.csv"
english_df.to_csv(english_output_path, index=False)
print(f"✅ English dataset saved at: {english_output_path}")

# ✅ Create Kazakh dataset
kazakh_df = df[['kazakh_source_text', 'kazakh_suspicious_text', 'label']]
kazakh_output_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs.csv"
kazakh_df.to_csv(kazakh_output_path, index=False)
print(f"✅ Kazakh dataset saved at: {kazakh_output_path}")

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs.csv"
output_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs_updated.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Rename columns
df.columns = ['suspicious_text', 'source_text', 'label']

# ✅ Save the updated dataset
df.to_csv(output_path, index=False)

print(f"✅ Column names updated! New dataset saved at: {output_path}")

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs_updated.csv"
output_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs_update1.csv"

# ✅ Load dataset
df = pd.read_csv(dataset_path)

# ✅ Separate `label=1` and `label=0` rows
df_label_1 = df[df["label"] == 1].reset_index(drop=True)
df_label_0 = df[df["label"] == 0].reset_index(drop=True)

# ✅ Interleave rows: (1,0,1,0,1,0,...)
min_length = min(len(df_label_1), len(df_label_0))
df_interleaved = pd.concat([df_label_1.iloc[:min_length], df_label_0.iloc[:min_length]]).sort_index(kind="merge")

# ✅ Add remaining rows (if any)
remaining_rows = pd.concat([df_label_1.iloc[min_length:], df_label_0.iloc[min_length:]])
df_final = pd.concat([df_interleaved, remaining_rows]).reset_index(drop=True)

# ✅ Save the updated dataset
df_final.to_csv(output_path, index=False)

print(f"✅ Dataset updated! New dataset saved at: {output_path}")

# %% [markdown]
# Shuffling the datasets

# %%
import pandas as pd

# ✅ Define dataset paths
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs_update1.csv"
output_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_plagiarism_dataset_60000_paragraphs9_fully_shuffled.csv"

# ✅ Load dataset
df = pd.read_csv(dataset_path)

# ✅ Shuffle all rows randomly
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)

# ✅ Save shuffled dataset
df_shuffled.to_csv(output_path, index=False)

# ✅ Display shuffled dataset
import ace_tools as tools
tools.display_dataframe_to_user(name="Fully Shuffled Plagiarism Dataset", dataframe=df_shuffled)

print(f"✅ Fully shuffled dataset saved at: {output_path}")

# %%
import pandas as pd

# ✅ Define dataset paths
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_plagiarism_dataset_60000_paragraphs_update1.csv"
output_path = "/content/drive/MyDrive/updating-pan-xml-files/en_plagiarism_dataset_60000_paragraphs_fully_shuffled.csv"

# ✅ Load dataset
df = pd.read_csv(dataset_path)

# ✅ Shuffle all rows randomly
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)

# ✅ Save shuffled dataset
df_shuffled.to_csv(output_path, index=False)

print(f"✅ Fully shuffled dataset saved at: {output_path}")

# %% [markdown]
# Dataset is now balanced:

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60000_paragraphs1.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    30810
# 1    30810
# Name: count, dtype: int64

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60000_paragraphs7.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    30810
# 0    30529
# Name: count, dtype: int64

# %% [markdown]
# Checking for duplication, if they exist removing and making the dataset unique:

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60000_paragraphs1.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique1.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)


# ✅ Remove duplicates **based only on suspicious and source text pairs**
df_unique = df.drop_duplicates(subset=["suspicious_text", "source_text"])

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique1.csv

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60000_paragraphs1.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique3.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)


# ✅ Remove duplicates
df_unique = df.drop_duplicates()

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique3.csv

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60000_paragraphs7.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)

# ✅ Remove duplicates **based only on suspicious and source text pairs**
df_unique = df.drop_duplicates(subset=["suspicious_text", "source_text"])

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique.csv

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60000_paragraphs7.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique2.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)

# ✅ Remove duplicates
df_unique = df.drop_duplicates()

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique2.csv

# %% [markdown]
# Checking again whether the dataset is still balanced or not:

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    30810
# 0    30529
# Name: count, dtype: int64

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique1.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    30810
# 1    30810
# Name: count, dtype: int64

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique2.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    30810
# 0    30529
# Name: count, dtype: int64

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique3.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    30810
# 1    30810
# Name: count, dtype: int64

# %% [markdown]
# Doing the same for english dataset, checking for duplication, making it unique and them checking it for balance

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60000_paragraphs1.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique1.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)

# ✅ Remove duplicates
df_unique = df.drop_duplicates()

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique1.csv

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique1.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    30824
# 1    30824
# Name: count, dtype: int64

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique1.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique2.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)


# ✅ Remove duplicates **based only on suspicious and source text pairs**
df_unique = df.drop_duplicates(subset=["suspicious_text", "source_text"])

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique2.csv

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique2.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    30824
# 1    30824
# Name: count, dtype: int64

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60000_paragraphs7.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique3.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)

# ✅ Remove duplicates
df_unique = df.drop_duplicates()
df_unique = df.drop_duplicates(subset=["suspicious_text", "source_text"])

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique3.csv

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique3.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    30824
# 0    30506
# Name: count, dtype: int64

# %% [markdown]
# ## ✅ **Summary-1:**
#
# ### 🧩 **Plagiarized Text Extraction and Translation**
# We extracted paragraph-level plagiarism cases from the **PAN corpora** using XML metadata (i.e., offset and length values). The identified **English paragraphs** were then **translated into Kazakh** using machine translation, enabling us to build a **bilingual English–Kazakh dataset** for plagiarism and semantic similarity analysis.
#
# ### 👥 **Human Evaluation Set**
# To evaluate the translation quality and plagiarism detection effectiveness, we curated a dataset of **2,000 English–Kazakh text pairs** for **native Kazakh speakers**. Each pair consists of an original English paragraph and its Kazakh translation, labeled as either **plagiarized** or **non-plagiarized**.
#
# ### 📝 **Human Evaluation Setup**
# The 2,000 text pairs were **shuffled** and then **evenly distributed** among evaluators. Each Kazakh-speaking participant received a **balanced mix** of plagiarized and non-plagiarized pairs, ensuring a fair and unbiased evaluation without label-position bias.
#
# ### 🤖 **Model Training on Small Dataset**
# We trained two separate **BERT-based models** on this manually curated dataset:
#
# - 📘 **English BERT** was trained on English text pairs.
# - 📗 **Kazakh BERT** was trained on their Kazakh translations.
#
# This allowed us to **benchmark** the effectiveness of language-specific models in identifying text similarity and plagiarism across both languages.
#
# ### ⚖️ **Generating Negative Samples (Label = 0) for the Large Dataset**
# The original large dataset contained only **positive samples (label = 1)**. We used our trained BERT models to identify **dissimilar pairs**, which were then labeled as **negative examples (label = 0)**. This strategy allowed us to **balance the dataset** and make it suitable for supervised learning.
#
# ### 📦 **Final Training Datasets**
# We cleaned, deduplicated, balanced, and augmented our data to create two final, ready-to-train datasets:
#
# - ✅ `kz_pan_dataset_60K_paragraphs_unique.csv`
# - ✅ `en_pan_dataset_60K_paragraphs_unique3.csv`
#
# These datasets are well-suited for building robust **text similarity and plagiarism detection models** in both **Kazakh** and **English**.

# %% [markdown]
# **Data Augmentation by Swapping Text Pairs**
#
# To enhance the robustness of the model and increase the size of the training data, we applied a simple yet effective data augmentation technique. Specifically, we **swapped the positions of the suspicious and source texts** for each data pair while preserving the original label. For example, the initial dataset consisted of pairs such as:
#
# 1. *(Text-A1, Text-A2, Label = 1)*
# 2. *(Text-B1, Text-B2, Label = 0)*
#
# After augmentation, the dataset became:
#
# 1. *(Text-A1, Text-A2, Label = 1)*
# 2. *(Text-A2, Text-A1, Label = 1)*
# 3. *(Text-B1, Text-B2, Label = 0)*
# 4. *(Text-B2, Text-B1, Label = 0)*
#
# The rationale behind this approach is that if the model is trained to recognize that “hi” is similar to “hello” (Label = 1), it should also learn that “hello” is similar to “hi”. By introducing both directions of the text pair, we help the model generalize better and reinforce the concept of semantic equivalence. This technique effectively **doubles the dataset size** and maintains class balance, thereby supporting better learning of text similarity patterns.

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_pan_dataset_60K_paragraphs_unique.csv"

# Load the dataset
df = pd.read_csv(dataset_path)
print("Original dataset shape:", df.shape)

# Create the swapped DataFrame
swapped_df = pd.DataFrame({
    'suspicious_text': df['source_text'],
    'source_text': df['suspicious_text'],
    'label': df['label']
})

# Concatenate the original and swapped DataFrames
combined_df = pd.concat([df, swapped_df], ignore_index=True)
print("Combined dataset shape before duplicate removal:", combined_df.shape)

# Save the new dataset to a CSV file
output_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_paragraphs.csv"
combined_df.to_csv(output_path, index=False)
print("New dataset saved to:", output_path)
# Out:
# Original dataset shape: (61339, 3)
# Combined dataset shape before duplicate removal: (122678, 3)
# New dataset saved to: /content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_paragraphs.csv

# %% [markdown]
# We can see that our 120K dataset is still balanced, which is good:

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_paragraphs.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    61620
# 0    61058
# Name: count, dtype: int64

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_paragraphs.csv"

# Load the dataset (only the first row to improve performance)
df = pd.read_csv(dataset_path, nrows=0)

# Get the column names
column_names = df.columns.tolist()

# Print the column names
print("Column Names:", column_names)
# Out:
# Column Names: ['suspicious_text', 'source_text', 'label']

# %% [markdown]
# Again checking for duplication, and if duplication exist the code will remove it and save the new dataset which has unique data, means no duplicated datas.

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_paragraphs.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_ready_for_training.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)


# ✅ Remove duplicates **based only on suspicious and source text pairs**
df_unique = df.drop_duplicates(subset=["suspicious_text", "source_text"])
df_unique = df.drop_duplicates()

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_ready_for_training.csv

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_ready_for_training.csv"

# Load the dataset (only the first row to improve performance)
df = pd.read_csv(dataset_path, nrows=0)

# Get the column names
column_names = df.columns.tolist()

# Print the column names
print("Column Names:", column_names)
# Out:
# Column Names: ['suspicious_text', 'source_text', 'label']

# %% [markdown]
# Checking number of labels 1s and 0s, and just to see whether the dataset still balanced or not after deletion of duplicates.

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_ready_for_training.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    61109
# 0    61058
# Name: count, dtype: int64

# %% [markdown]
# This code we used just to see the first 5 rows of data and last three rows of data in the dataset and ensure whether they are shuffled.

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz_dataset_120K_ready_for_training.csv"

# Load the dataset
df = pd.read_csv(dataset_path)

# Function to print each row in a structured format
def print_structured_rows(df_subset, title):
    print(f"\n🔹 {title}")
    for index, row in df_subset.iterrows():
        print(f"Row {index + 1}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for readability

# Print the first 5 rows
print_structured_rows(df.head(5), "First 5 Rows")

# Print the last 5 rows
print_structured_rows(df.tail(5), "Last 5 Rows")
# Out:
# 🔹 First 5 Rows
# Row 1:
#   suspicious_text: Бірақ, көріп тұрсыңдар, ешкім оның құпиясын жасырмады - бәрі оның назарын дұрыс емес бағыттады және әр жолы оның орындауын қате түсіндірді - сондықтан олар оның ақымақ қателіктерін данышпандық шабыт деп қабылдады; олар адал істеді!
#   source_text: Жолбасшымыздың сұр жүзі енді оқуға айналды. оның мұндай төтенше жағдай туралы нұсқауы болмады. бұл сұрақ оның бейшара ақылымен соғысты. бір сәт олар селт еткізіп, жеңілгендерін сезіп, берілмек болды.
#   label: 0
# --------------------------------------------------
# Row 2:
#   suspicious_text: Менің, бірақ басқа жаратылыстардың мойынсұнудан бас тартуы қате болды ма - олар талап ететін бірдеңені істеу керек «адамның менен балама күнкөрісі болмауы мүмкін, ал мен істеуім керек және олар мұны қалай талап етеді. олардың қажеттіліктерінен гөрі өз талғамым мен бейімділігіммен кеңесу керек пе?' содан кейін оның ойына келеді, бұл үлкен заң қалай болғанда да, машинадағы әрбір дұрыс және лайықты орынға кіру үшін шынайы талап қою керек;.
#   source_text: Мен олардың қажеттіліктерінен гөрі өз талғамым мен бейімділігіммен ақылдасып жатқанда, менің құрбыларым меннен күнкөрістерді жасырып, қателесе ме?» сонда оның ойына ұлы заң қандай да бір түрде бағыну керек - адамзат үшін олар талап ететін бірдеңе жасалуы керек және олар талап ететін жерде және қалай жасалуы керек, осылайша әрбір адам өзінің шынайы талабына ие болуы мүмкін. қалғаны. әлеуметтік машинада дұрыс және лайықты орынға кіру қиын болуы мүмкін; бірақ балама жоқ.
#   label: 1
# --------------------------------------------------
# Row 3:
#   suspicious_text: Салыстырмалы түрде жиі бозғылт сұрдан қоңырға дейін, қатты шырынды пайда болатын колониялар бар, олардың азды-көпті кең шеттік аймағының жиегі ойық және мөлдір. олардың беті тегіс, жиі сәулелену жолақтары бар.
#   source_text: Ол ризашылық тақырыбын таңдады және сол күні олардың қолынан көрген қонақжайлылық үшін өзінің толық ризашылығын көрсетудің бір ғана жолы бар екенін айтты: дәлірек айтқанда, сарагоссаға апаратын тас жолдың ортасында ұстау.
#   label: 0
# --------------------------------------------------
# Row 4:
#   suspicious_text: Бірақ, көріп тұрсыңдар, ешкім оның құпиясын жасырмады - бәрі оның назарын дұрыс емес бағыттады және әр жолы оның орындауын қате түсіндірді - сондықтан олар оның ақымақ қателіктерін данышпандық шабыт деп қабылдады; олар адал істеді!
#   source_text: Мен оған менің қолымнан алған жарқыраған ақ сауыт-сайманына қарсы шапаныммен, қылышыммен бәріңнің алдыңда ержүрек отаместі жеңу құрметіне ие болғанымды дәлелдеуге шақырамын.
#   label: 0
# --------------------------------------------------
# Row 5:
#   suspicious_text: Федералды түрде реттелетін қаржы институттары жер сілкінісі кезінде маңызды қызметтерді алға жылжыту мүмкіндігін анықтау үшін бағалауға ұсынылғандарды ұнату үшін жалпы талдаудан өтті.
#   source_text: Достары оған қарап отырып, бұл туынды оның бұрыннан мойындаған, бірақ қазір бүкіл әлем мойындауы тиіс оның көркемдік ұлылығының айғағы деп қуана айғайлады.
#   label: 0
# --------------------------------------------------
#
# 🔹 Last 5 Rows
# Row 122163:
#   suspicious_text: Түнде де, күндіз де, дауылды және қыста, сондай-ақ қалыпты ауа-райында теңдесі жоқ ұзақтық мүмкін болды, бұл есептеудің барлық күшінен тыс екенін дәлелдеді және алдын ала елестету мүмкін емес еді.
#   source_text: Британдық қауымдастық ағынды суларды кәдеге жарату бойынша практикалық және жан-жақты сұрау салу үшін l алды. британдық байланысты жүректеріңізге батасын беріңіз! the herald мұны бұрыннан көрсетті - оның редакциялық мақалалары.
#   label: 0
# --------------------------------------------------
# Row 122164:
#   suspicious_text: Бұл міндеттеме орындалады; басқа міндет, яғни менің дауысымның есептелуін және оның дауыстардың қорытындысында тиісті орнын алуын қамтамасыз ету. әйтпесе, дауыс беру нәтижесі күлкілі болып, сайлаушы өзінің азаптары үшін күлкіге лайық. оның міндеті - өз ар-ожданына сай дауыс беру - анық болды; заңға сәйкес дауысты басқа да дауыстармен қатар сезіну оның міндеті. азаматтың бүкіл міндеті оның дауыс беруімен аяқталмайды; жалпы таңдаудың басымдылығын реттей отырып, тиісті түрде өлшенгенге дейін оны бақылау міндеттемесі қалады. сайлаудың
әлелдейтін бір нәрсе бар екенін көрмедік пе? немесе тағы да сол қаладағы самариялықтардың мәсіхпен сөйлескеннен кейін әйелге айтқан сөздерінде; «сондықтан, иеміз келгенде, біреулер оны ілияс, ал басқалары шомылдыру рәсімін жасаушы жақия өлімнен қайта тірілген деп ойласа, оны еремия деп ойлайтындар болды. . бірінші пайғамбар самуил сияқты, ол да леви руынан еді. туылғаннан бастап діни қызметтерге бағышталған және құдайдың үнемі қатысуымен және рақымымен ұнамды сіз өмір жолында берік болсаңыз, ар-ұждан бұрынғыдан да күшті және ағартушылыққа айналады және ол оның арасындағы қашықтықты түсінеді және айқынырақ сезінеді; өзінің мінез-құлқы, ойлары және кемелділігі [] адамдардың ең данасы және ең қасиеттісі христиандар емес пе? евангелие сенімі туралы сіз өзіңіздің өткен тәжірибеңізбен бір ілімнің ақиқатына куә боласыз; басқа біреудің, оның қателесетін адамдардың тәліміне ғана сәйкес келетінін көру арқылы; мәсіхке деген сеніміңіз бен үмітіңіз үшін күлкіге ұшырамайсыз ба? олар азап шеккенде оның діни қызметкерлігін, тәлім беруде пайғамбарлық қызметін және кереметтерінде оның патшалық билігін көрсетті. енді бұл жауап беруі мүмкін және өте қанағаттанарлық, «евангелиенің ақиқатына, біз ең жақсы көретін және құрметтейтін адамдар оған сенетініне сендіретін ештеңе жоқ па? құдай оны қолдануды сирек қабылдамайды. егер бізде сену үшін жақсы себеп болмаса, кем дегенде бізде сенбеу үшін жақсы себеп жоқ. «киеліліксіз ешкім иемізді көрмейді []; «және оның шынайы, сүйкімді және тазаға деген сүйіспеншілігі құдайдан келген доктринаны мақұлдайды және қабылдайды. бірақ жалғастыру үшін. мұндай адамдар үшін сіз тек дұға ете аласыз; құдай тәкаппарлықты, өзімшілдікті, тәкаппар рухты, менмен мінезді төмендете алады; жалғыз құдай арам ойды жоя алады; ет пен қанды тек құдай ғана жеңе алады. .» мен айтқан сөздердің бәрі мінде ...
#   label: 1
# --------------------------------------------------

# %% [markdown]
# We did the same for english dataset below:

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_pan_dataset_60K_paragraphs_unique3.csv"

# Load the dataset
df = pd.read_csv(dataset_path)
print("Original dataset shape:", df.shape)

# Create the swapped DataFrame
swapped_df = pd.DataFrame({
    'suspicious_text': df['source_text'],
    'source_text': df['suspicious_text'],
    'label': df['label']
})

# Concatenate the original and swapped DataFrames
combined_df = pd.concat([df, swapped_df], ignore_index=True)
print("Combined dataset shape before duplicate removal:", combined_df.shape)

# Save the new dataset to a CSV file
output_path = "/content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_paragraphs.csv"
combined_df.to_csv(output_path, index=False)
print("New dataset saved to:", output_path)
# Out:
# Original dataset shape: (61330, 3)
# Combined dataset shape before duplicate removal: (122660, 3)
# New dataset saved to: /content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_paragraphs.csv

# %% [markdown]
# Cheking the number of labels to ensure they are balanced

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_paragraphs.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 1    61648
# 0    61012
# Name: count, dtype: int64

# %% [markdown]
# Removing the duplicates if they exist, in order to make the dataset with unique datas.

# %%
import pandas as pd
import re

# Define dataset paths
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_paragraphs.csv"
output_path =  "/content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_ready_for_training.csv"

# Load dataset
df = pd.read_csv(dataset_path)

# ✅ Text preprocessing function (clean only texts)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'^\W+|\d+', '', text)  # Remove leading special characters/numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# ✅ Apply cleaning **only to English texts**
df["suspicious_text"] = df["suspicious_text"].apply(clean_text)
df["source_text"] = df["source_text"].apply(clean_text)


# ✅ Remove duplicates **based only on suspicious and source text pairs**
df_unique = df.drop_duplicates(subset=["suspicious_text", "source_text"])
df_unique = df.drop_duplicates()

# ✅ Save new dataset without duplicates
df_unique.to_csv(output_path, index=False)

print(f"✅ Unique dataset saved at: {output_path}")
# Out:
# ✅ Unique dataset saved at: /content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_ready_for_training.csv

# %% [markdown]
# After removing duplicated rows in the dataset we are again checking for its balance, and you can see they were really decreased, but it is still balanced which is good.

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_ready_for_training.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    61010
# 1    58155
# Name: count, dtype: int64

# %% [markdown]
# Here we are ensuring whether the datas are shuffled in the dataset:

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en_dataset_120K_ready_for_training.csv"

# Load the dataset
df = pd.read_csv(dataset_path)

# Function to print each row in a structured format
def print_structured_rows(df_subset, title):
    print(f"\n🔹 {title}")
    for index, row in df_subset.iterrows():
        print(f"Row {index + 1}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for readability

# Print the first 5 rows
print_structured_rows(df.head(5), "First 5 Rows")

# Print the last 5 rows
print_structured_rows(df.tail(5), "Last 5 Rows")
# Out:
# 🔹 First 5 Rows
# Row 1:
#   suspicious_text: Relatively often there are pale gray to brownish, strongly succulent appearing colonies, whose more or less broad marginal zone has a jagged edge and transparent. Their surface is smooth, often radiating striations bear.
#   source_text: On certain occasions he even went out after wood in the daylight, slithering along on all fours towards his objective, and would be fired at until recalled by one of his own officers.
#   label: 0
# --------------------------------------------------
# Row 2:
#   suspicious_text: Relatively often there are pale gray to brownish, strongly succulent appearing colonies, whose more or less broad marginal zone has a jagged edge and transparent. Their surface is smooth, often radiating striations bear.
#   source_text: Do let me see at once, HELENE I [Looks eagerly.] Ah, yes; all gone; nothing visible but one smoke-pipe, three stove-pipe hats, four bits of orange-peel, some pea-nut shells, and thirteen copies of the New-York Ledger.
#   label: 0
# --------------------------------------------------
# Row 3:
#   suspicious_text: The British Association have received L toward a practical and comprehensive inquiry into the utilization of sewage. Bless your British associated hearts! The Herald has demonstrated that long ago--made editorials of it.
#   source_text: They went to work as soon as it git light enough to see how to git 'round; then when twelve o'clock come, they all stops for dinner and don't go back to work 'til two.
#   label: 0
# --------------------------------------------------
# Row 4:
#   suspicious_text: But, you see, nobody was in the fellow's secret--everybody had him focused wrong, and necessarily misinterpreted his performance every time--consequently they took his idiotic blunders for inspirations of genius; they did honestly!
#   source_text: If the pupils had been quick to recognize him, although they had never seen him before, it had been different with the instructor, whose acquaintance with him dated further back.
#   label: 0
# --------------------------------------------------
# Row 5:
#   suspicious_text: I haven't establish out what the trouble, but I know you must have sinned against the woman in some way, or done something tactless, which is worse, and tossed her angry. Or else she felt it was her duty to be angry, and has been living up to it ever since.
#   source_text: I haven't found out what the trouble is, but I know you must have sinned against the girl in some way, or done something tactless, which is worse, and made her angry. Or else she felt it was her duty to be angry, and has been living up to it ever since.
#   label: 1
# --------------------------------------------------
#
# 🔹 Last 5 Rows
# Row 119161:
#   suspicious_text: I AM AMBUSHED AND CAPTURED XLVII. SHIPPED TO ST. HELENA XLVIII. LIFE IN BONAPARTE'S PRISON XLIX. HOW WE BLEW UP AND CAPTURED TRAINS L. HOW WE FED AND CLOTHED COMMANDOS LI. OUR FRIEND THE ENEMY LII. THE FIGHTING BOER AND HIS OFFICER APPENDIX THE AUTHOR TO THE READER. In offering my readers my reminiscences of the late War, I feel that it is necessary to ask their indulgence and to plead extenuating circumstances for many obvious shortcomings. It should be pointed out that the preparation of this work was attended with many difficulties and disabilities, of which the following were only a few:-- () This is my first attempt at writing a book, and as a simple Afrikander I lay no claim to any literary ability. () When captured by the British forces I was deprived of all my notes, and have been compelled to consult and depend largely upon my memory for my facts and data. I would wish to add, however, that the notes and minutiæ they took from me referred only to events and incidents covering six months of the War. Twice before my capture, various diaries I had compiled fell into British hands; and on a third occasion, when our camp at Dalmanutha was burned out by a "grass-fire," other notes were destroyed. () I wrote this book while a prisoner-of-war, fettered, as it were, by the strong chains with which a British "parole" is circumscribed. I was, so to say, bound hand and foot, and always made to feel sensibly the humiliating position to which we, as prisoners-of-war on this island, were reduced. Our unhappy lot was rendered unnecessarily unpleasant by the insulting treatment offered us by Colonel Price, who appeared to me an excellent prototype of Napoleon's custodian, Sir Hudson Lowe. One has only to read Lord Rosebery's work, "The Last Phase of Napoleon," to realise the insults and indignities Sir Hudson Lowe heaped upon a gallant enemy. We Boers experienced similar treatment from our custodian, Colonel Price, who appeared to be possessed with the very demon of distrust and who conjured up about us the same fantastic and mythical plans of escape as Sir Hudson Lowe attributed to Napoleon. It is to his absurd suspic
ness and yet desirableness of perfection, or the beauty of saintliness, or the dangerousness of the world, or the blessedness of self-control, or the glory of virginity, or the answers which God gives to prayer, or the marvellousness and almost miraculousness of his providences, or the comfort of religion in affliction, or the strength given you over your passions in the most holy Sacrament, such persons understand you not at all. They will laugh, they will scoff, at best they will wonder: any how what you say is no evidence to them. You cannot convince them, because you differ from them in first principles; it is not that they start from the same point as you, and afterwards strike off in some wayward direction; but their course is altogether distinct, they have no point in common with you. ...
#   label: 1
# --------------------------------------------------

# %% [markdown]
# **Summary-2**
#
# We have independently prepared **Kazakh** and **English** datasets tailored for text similarity detection tasks. Both datasets are **labeled**, which is a critical requirement for supervised learning. Additionally, they have been carefully processed to ensure they are **balanced**, **unique**, and **shuffled**. As a result, these datasets are now well-suited for training text similarity models.
#
# - `kz_dataset_120K_ready_for_training.csv`
# - `en_dataset_120K_ready_for_training.csv`

# %% [markdown]
# ### **Dataset for Testing Purposes**
#
# Next, we prepared separate **English** and **Kazakh** datasets specifically for **testing purposes**. As with the training datasets, we conducted duplication checks to ensure all entries are **unique**. The datasets were also **shuffled** and **balanced** to support reliable and unbiased evaluation of the models.

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz-3950-sentences-for-testing1.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    1978
# 1    1977
# Name: count, dtype: int64

# %%
import pandas as pd

# Define dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en-4500-sentences-for-testing6.csv"

# Load dataset fully
df = pd.read_csv(dataset_path)

# Count occurrences of each label (1 = Plagiarized, 0 = Not Plagiarized)
label_counts = df["label"].value_counts()

# Print results
print(label_counts)
# Out:
# label
# 0    2268
# 1    2267
# Name: count, dtype: int64

# %%
import pandas as pd

# Define the dataset path
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/kz-3950-sentences-for-testing1.csv"

# Load the dataset (only the first row to improve performance)
df = pd.read_csv(dataset_path, nrows=0)

# Get the column names
column_names = df.columns.tolist()

# Print the column names
print("Column Names:", column_names)
# Out:
# Column Names: ['source_text', 'suspicious_text', 'label']

# %%
import pandas as pd

# Define the dataset path
dataset_path =  "/content/drive/MyDrive/updating-pan-xml-files/en-4500-sentences-for-testing6.csv"

# Load the dataset (only the first row to improve performance)
df = pd.read_csv(dataset_path, nrows=0)

# Get the column names
column_names = df.columns.tolist()

# Print the column names
print("Column Names:", column_names)
# Out:
# Column Names: ['source_text', 'suspicious_text', 'label']

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/kz-3950-sentences-for-testing1.csv"

# Load the dataset
df = pd.read_csv(dataset_path)

# Function to print each row in a structured format
def print_structured_rows(df_subset, title):
    print(f"\n🔹 {title}")
    for index, row in df_subset.iterrows():
        print(f"Row {index + 1}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for readability

# Print the first 5 rows
print_structured_rows(df.head(5), "First 5 Rows")

# Print the last 5 rows
print_structured_rows(df.tail(5), "Last 5 Rows")
# Out:
# 🔹 First 5 Rows
# Row 1:
#   source_text: Медитациядан туындаған алдамшы болғандықтан, ол болғандай, ол армандар еліне кірді.
#   suspicious_text: Алдағы ой жүгіртуден туындаған галлюцинация түрінде, ол болғандықтан, ол армандар саласына кірді.
#   label: 1
# --------------------------------------------------
# Row 2:
#   source_text: Олар үшін олар кәсіпорынды көрсетпейтіндер үшін, кем дегенде, данышпанның аяқ киімін көрсетпейді, бұл дақылдар ешқашан болмайды.
#   suspicious_text: Олар кәсіпорындағы кәсіпорынды аз данышпанның аяқ киімін көрсетпейді, олар ешқашан дақылдардан асып кетпейді.
#   label: 1
# --------------------------------------------------
# Row 3:
#   source_text: Сібір қарағайы, балқарағай және балқарағай тәрізді бірнеше азиялық түрлер, сондай-ақ солтүстік-шығыста өседі, сонымен қатар солтүстік-шығысқа қарай азиаттық далалар мен шөптер өседі.
#   suspicious_text: Екінші жағынан, бірнеше азиялық түрі Сібір қарағайы, балқарағай, балқарағай солтүстік-шығыста еркін өседі, ал азиаттық даладан бірнеше бұталар мен шөптер өсімдіктері оңтүстік-шығыстан өтті.
#   label: 1
# --------------------------------------------------
# Row 4:
#   source_text: Содан кейін құрбаны кездейсоқ ашыңыз, оның бір бетінен аспайтын бір парақты таңдап, кейбір қалған бөліктерде қиялдағы кейіпкерлерді бекітіңіз.
#   suspicious_text: Олар, әдетте, өте қорқынышты, өте қорқынышты ShotSthey, олар өздері жасаған әр түрлі құсты төмен түсірмейді, кейде көздерін жұмып, ең жақсы өсіп келе жатқан бүкіл патшаға жақындап қалды.
#   label: 0
# --------------------------------------------------
# Row 5:
#   source_text: Ол сонымен қатар балаларға арналған іш киім үшін де қолданылады.
#   suspicious_text: Ол сонымен қатар балалар киімдері үшін және сыртта оралғандары үшін қолданылады.
#   label: 1
# --------------------------------------------------
#
# 🔹 Last 5 Rows
# Row 3951:
#   source_text: Ол Вахабиден шабуыл жасауды жоспарлаған кезде, ол одақтастарын Бедуиндер арасында жинап, он мың ер адамның біріккен күшімен бірнеше рет озық.
#   suspicious_text: Оларға Бедуин ретінде мойынсұнған Шерифтер бұйырды, бұл соғыс кезінде өздерінің жетекшісіне бағынады, яғни әдеттегі жаттығуларға дайын емес, олар шерифтен, қаладан шыққан кезде, қайтып оралғанда, Шерифпен бірге жүрді Олардың мылтықтары, араб әдет-ғұрпы бойынша, өте жақсы секіріп.
#   label: 0
# --------------------------------------------------
# Row 3952:
#   source_text: Техас, Калифорния, Флорида, Флорида, Флорида, Флорида және Луизиана есімдері сияқты, олар бірдей ереже, олармен бірдей ереже, олар ұйымдасқан шетелдік қауымдастықтар мүшелеріне тиесілі, олар өздерінің аттарын ағылшын дастарқаның Асимиляциядан алдағы игіліктерден сақтандырды.
#   suspicious_text: Сайлау әрқашан қызықты мәселе болып табылады, көбінесе жарты шардың өсіруші әлемі және соңғы сайлаулар, ал соңғы сайлаулар, ол бұрынғыдан да көп көңіл көтерген.
#   label: 0
# --------------------------------------------------
# Row 3953:
#   source_text: Науылдар менің зұлымдарымдары маған князьдер мен князьдер MEI-ге қарсы жымиып, масқара субъектілерде күлімсіреді Мутинцидтің қатты қолы жазалануы мүмкін, немесе бұл үлкен жүрек кешіре алады.
#   suspicious_text: Ол мұндай испандықтар тыйым салынған дәрежедегідей, олардан жасалған, ал Адель сияқты, ханымның анасы, ал ханымның анасы Ричардтың анасы Ричард пен Могерммуникацияға ұшыраған, егер ленгамның костюмі болса!
#   label: 0
# --------------------------------------------------
# Row 3954:
#   source_text: Бірақ консорессиясыз барлығын жоюға, сонда Англияға дейін, ең алдымен, ең көне, басқа да Нейрондардың салтанатты сенюі.
#   suspicious_text: Бірақ консоракиясыз барлығын жою үшін, бұл Англияға және WYLL-ге бір-біріне дейін, ең жаңа сенбрейді асқазан, басқа да нақарлардың қабірі.
#   label: 1
# --------------------------------------------------
# Row 3955:
#   source_text: Кішкентай ханзада: «Менің анамның көздері өте ауыр, бірақ егер ол бүркіт қауырсыны болса, олар емделеді.
#   suspicious_text: Кішкентай ханзада: «Менің анамның көздері өте ауыр, бірақ егер ол бүркіт қауырсыны болса, олар емделеді.
#   label: 1
# --------------------------------------------------

# %%
import pandas as pd

# Define the dataset path
dataset_path = "/content/drive/MyDrive/updating-pan-xml-files/en-4500-sentences-for-testing6.csv"

# Load the dataset
df = pd.read_csv(dataset_path)

# Function to print each row in a structured format
def print_structured_rows(df_subset, title):
    print(f"\n🔹 {title}")
    for index, row in df_subset.iterrows():
        print(f"Row {index + 1}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for readability

# Print the first 5 rows
print_structured_rows(df.head(5), "First 5 Rows")

# Print the last 5 rows
print_structured_rows(df.tail(5), "Last 5 Rows")
# Out:
# 🔹 First 5 Rows
# Row 1:
#   source_text: This being true it is not necessary to turn needle in to the right firmly but merely far enough to be sure that when turning back to the left, to the notch registering with guide post, that the needle is not more than once around or one turn from its seat.
#   suspicious_text: Model "s" marvel carbureter if the engine idles too fast with throttle closed, the latter may be adjusted by means of the throttle lever adjusting screw.
#   label: 0
# --------------------------------------------------
# Row 2:
#   source_text: Next come descriptions of regions, cities and architectural marvels and then follow articles on the various manners and customs of rural and town life.
#   suspicious_text: After this description of regions, cities and architectural marvels are given then article on the variouss manners and customs of rural and town life is described afterwards.the national arts are treated elaborately and at the end chapter of the latest statistics is given which finishes the survey.
#   label: 1
# --------------------------------------------------
# Row 3:
#   source_text: My companion, a better judge, says to three and it has cost the new farmer two superb scarecrows, and gunpowder enough for a review, to keep off the sparrows.
#   suspicious_text: My companion, a better judge, says to three and it has cost scarecrows death, and gunpowder part, i like these little experiments the to new farmer two superb, even if they be enough for a review, to keep off the sparrows.
#   label: 1
# --------------------------------------------------
# Row 4:
#   source_text: This puts me in mind, said i, of an irish pilot who asked the purser of a ship i formerly belonged to, to spare him an empty barrel to make his pig a hencoop, and he would give him a sack of praters for nothing at all, at all.
#   suspicious_text: On entering, i found a gallon bowl filled with strong punch, with his commission soaking in it, and eight jolly mids sitting at the table in full glee.
#   label: 0
# --------------------------------------------------
# Row 5:
#   source_text: Sorry you considered it to stay behind on my account.
#   suspicious_text: Sorry you considered it necessary to stay behind on my account.
#   label: 1
# --------------------------------------------------
#
# 🔹 Last 5 Rows
# Row 4531:
#   source_text: Thus pauline trauelled in the woorke of the lord, the same being greatlie furthered by the helpe of edwin, in whose presence he baptised a great number of people in the riuer of trent, nere to a towne, which in the old english toong was called tio vulfingacester.
#   suspicious_text: West saith the turne vnto jesus, the same greatlie furthered by the helpe only of, whose presence he baptised a great number of people of stone woorke thus hearty lord.
#   label: 1
# --------------------------------------------------
# Row 4532:
#   source_text: It is now found, so reactive is the bromine atom in this compound, that the estimation may be accurately made by titration with silver nitrate according to volhard's process, the crystals for this purpose being dissolved in dilute alcohol .
#   suspicious_text: Wishing to make investigations under these conditions, the authors have tried several solvents, and, at present, find that chloroform is best suited to the purpose.
#   label: 0
# --------------------------------------------------
# Row 4533:
#   source_text: I did not want to read it was enough to feast one's eyes on their backs, to take down a volume and handle it my old greenjacketed browning, for instance.
#   suspicious_text: I did not want to read it was enough to feast one's eyes on their backs, to take down a volume and handle it my old greenjacketed browning, for instance.
#   label: 1
# --------------------------------------------------
# Row 4534:
#   source_text: She wore an oddly oldfashioned gown of yellow satin, cut square in the neck.
#   suspicious_text: She wore an oddly oldfashioned gown of yellow satin, cut square in the neck.
#   label: 1
# --------------------------------------------------
# Row 4535:
#   source_text: What makes this the more probable, is, that the crows in their depredation seemed by no means bloodthirsty, but intent chiefly on robbing the parties of their traps and horses, thereby disabling them from prosecuting their hunting.
#   suspicious_text: M'tulloch, an agent of the american company, was stationed there with twenty men two boats of fifteen tons burden were lying here but at certain seasons of the year a steamboat can come up to the fort.
#   label: 0
# --------------------------------------------------

# %% [markdown]
# ## 🔍 Conclusion
#
# We created a high-quality **English and Kazakh datasets** for **text similarity and plagiarism detection** by:
#
# - **Extracting** plagiarized text pairs from the PAN corpora using XML offset metadata.
# - **Translating** English text segments into **Kazakh** to build a multilingual dataset.
# - Preparing a **human evaluation set** of 2,000 English–Kazakh pairs, evenly distributed and shuffled, for native Kazakh speakers to assess plagiarism and translation quality.
# - **Training BERT-based models** separately for English and Kazakh using the human-curated dataset.
# - Using the trained models to **generate negative samples** (label = 0) for the larger dataset, ensuring label balance.
# - **Augmenting** the dataset by swapping suspicious and source texts to increase size and improve model generalization.
# - Producing two final labeled, balanced, unique, and shuffled datasets, ready for training and testing:
#
# ### ✅ Final Training Datasets:
# - `kz_dataset_120K_ready_for_training.csv`
# - `en_dataset_120K_ready_for_training.csv`
#
# ### ✅ Final Testing Datasets:
# - `kz-3950-sentences-for-testing1.csv`
# - `en-4500-sentences-for-testing6.csv`
#
# These resources support robust model development in both **Kazakh (low-resource)** and **English**.

# %% [markdown]
# **Note:** The code may not appear flawless due to multiple iterations and repeated attempts during development. We have removed redundant sections and retained only the core, essential parts.
